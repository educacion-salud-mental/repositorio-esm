# %% [markdown]
# # Censos de Población y Vivienda

# %%
# %run limpieza_ccpv.py
# Out:
# Datos del archivo cpv2005_iter_00 se cargaron a la lista 'dataframes'
# Datos del archivo cpyv80_nal_educacion.xlsx se cargaron a la lista 'dataframes'
# /Users/federicocirett/Documents/Master/IngenieriaCaracteristicas/{{ cookiecutter.project_slug }}/notebooks/limpieza_ccpv.py:115: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(file_path)
# Datos del archivo iter_00_cpv2020 se cargaron a la lista 'dataframes'
# Datos del archivo cgp50_nal_educacion.xlsx se cargaron a la lista 'dataframes'
# Datos del archivo iter_00_cpv2010 se cargaron a la lista 'dataframes'
# Datos del archivo CGP60_nal_Educacion.xlsx se cargaron a la lista 'dataframes'
# Datos del archivo cgp70_nal_educacion.xlsx se cargaron a la lista 'dataframes'
# Datos del archivo CPyV90_Nal_Caracteristicas_educativas.xlsx se cargaron a la lista 'dataframes'
# Datos del archivo Cont95Enum_NAL_Caracteristicas_educativas.xlsx se cargaron a la lista 'dataframes'
# /Users/federicocirett/Documents/Master/IngenieriaCaracteristicas/{{ cookiecutter.project_slug }}/notebooks/limpieza_ccpv.py:115: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(file_path)
# Datos del archivo cgpv2000_iter_00 se cargaron a la lista 'dataframes'

# %% [markdown]
# ## Población de 6 a 29 años que asisten a instituciones de enseñanza, por entidad federativa y sexo, según edad(1950)

# %%
#  Población de 6 años y más, por entidad federativa, tamaño de la localidad y grupos de edad, según condición de alfabetismo y sexo

df=dataframes[3]
df.columns
# Out:
# Index(['Estados Unidos Mexicanos', 'Entidad federativa', 'Sexo',
#        'Edad en años de los que asisten a las escuelas de todas clases',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9', 'De 6 a 29 años que no asisten'],
#       dtype='object')

# %%
df.columns.to_list()[3:10]
# Out:
# ['Edad en años de los que asisten a las escuelas de todas clases',
#  'Unnamed: 4',
#  'Unnamed: 5',
#  'Unnamed: 6',
#  'Unnamed: 7',
#  'Unnamed: 8',
#  'Unnamed: 9']

# %%
unnamed_columns=df.columns.to_list()[3:10]
rows_to_drop=[0,1,104,105]

# %%
rename_dictionary={}
for column in unnamed_columns:
    rename_dictionary[column]=df[column][0]

df=df.rename(columns=rename_dictionary)
df=df.drop(rows_to_drop)
df
# Out:
#      Estados Unidos Mexicanos  Entidad federativa     Sexo  6 años  \
# 2    Estados Unidos Mexicanos               Total    Total  143428
# 3    Estados Unidos Mexicanos               Total  Hombres   72324
# 4    Estados Unidos Mexicanos               Total  Mujeres   71104
# 5    Estados Unidos Mexicanos      Aguascalientes    Total    1875
# 6    Estados Unidos Mexicanos      Aguascalientes  Hombres     946
# ..                        ...                 ...      ...     ...
# 99   Estados Unidos Mexicanos           Zacatecas  Hombres    2082
# 100  Estados Unidos Mexicanos           Zacatecas  Mujeres    1997
# 101  Estados Unidos Mexicanos  Complementarios /a    Total      17
# 102  Estados Unidos Mexicanos  Complementarios /a  Hombres      11
# 103  Estados Unidos Mexicanos  Complementarios /a  Mujeres       6
#
#     7 a 12 años 13 y 14 años 15 a 17 años 18 y 19 años 20 a 24 años  \
# 2       1677506       429046       243003        68389        64763
# 3        874913       241004       140274        41505        38566
# 4        802593       188042       102729        26884        26197
# 5         16085         4242         1919          494          361
# 6          8423         2324         1003          273          150
# ..          ...          ...          ...          ...          ...
# 99        20373         5658         2440          510          384
# 100       19158         4350         1690          339          365
# 101         192           63           75           30           11
# 102         123           44           42           16            3
# 103          69           19           33           14            8
#
#     25 a 29 años  De 6 a 29 años que no asisten
# 2          27316                     10299457.0
# 3          14105                      4939015.0
# 4          13211                      5360442.0
# 5            143                        66380.0
# 6             59                        31484.0
# ..           ...                            ...
# 99           189                       138099.0
# 100          192                       143392.0
# 101            2                         6456.0
# 102            2                         1564.0
# 103            0                         4892.0
#
# [102 rows x 11 columns]

# %%
df.head(4)
# Out:
#    Estados Unidos Mexicanos Entidad federativa     Sexo  6 años 7 a 12 años  \
# 2  Estados Unidos Mexicanos              Total    Total  143428     1677506
# 3  Estados Unidos Mexicanos              Total  Hombres   72324      874913
# 4  Estados Unidos Mexicanos              Total  Mujeres   71104      802593
# 5  Estados Unidos Mexicanos     Aguascalientes    Total    1875       16085
#
#   13 y 14 años 15 a 17 años 18 y 19 años 20 a 24 años 25 a 29 años  \
# 2       429046       243003        68389        64763        27316
# 3       241004       140274        41505        38566        14105
# 4       188042       102729        26884        26197        13211
# 5         4242         1919          494          361          143
#
#    De 6 a 29 años que no asisten
# 2                     10299457.0
# 3                      4939015.0
# 4                      5360442.0
# 5                        66380.0

# %%
revision_nulos(df)

# %%
format_columns={'De 6 a 29 años que no asisten':'int'}
for column,format in format_columns.items():
    df[column]=df[column].astype(format)

df
# Out:
#      Estados Unidos Mexicanos  Entidad federativa     Sexo  6 años  \
# 2    Estados Unidos Mexicanos               Total    Total  143428
# 3    Estados Unidos Mexicanos               Total  Hombres   72324
# 4    Estados Unidos Mexicanos               Total  Mujeres   71104
# 5    Estados Unidos Mexicanos      Aguascalientes    Total    1875
# 6    Estados Unidos Mexicanos      Aguascalientes  Hombres     946
# ..                        ...                 ...      ...     ...
# 99   Estados Unidos Mexicanos           Zacatecas  Hombres    2082
# 100  Estados Unidos Mexicanos           Zacatecas  Mujeres    1997
# 101  Estados Unidos Mexicanos  Complementarios /a    Total      17
# 102  Estados Unidos Mexicanos  Complementarios /a  Hombres      11
# 103  Estados Unidos Mexicanos  Complementarios /a  Mujeres       6
#
#     7 a 12 años 13 y 14 años 15 a 17 años 18 y 19 años 20 a 24 años  \
# 2       1677506       429046       243003        68389        64763
# 3        874913       241004       140274        41505        38566
# 4        802593       188042       102729        26884        26197
# 5         16085         4242         1919          494          361
# 6          8423         2324         1003          273          150
# ..          ...          ...          ...          ...          ...
# 99        20373         5658         2440          510          384
# 100       19158         4350         1690          339          365
# 101         192           63           75           30           11
# 102         123           44           42           16            3
# 103          69           19           33           14            8
#
#     25 a 29 años  De 6 a 29 años que no asisten
# 2          27316                       10299457
# 3          14105                        4939015
# 4          13211                        5360442
# 5            143                          66380
# 6             59                          31484
# ..           ...                            ...
# 99           189                         138099
# 100          192                         143392
# 101            2                           6456
# 102            2                           1564
# 103            0                           4892
#
# [102 rows x 11 columns]

# %% [markdown]
# ## Población de 6 años y más, por entidad federativa, área urbana y rural, alfabetismo y sexo, según grupos de edad(1960)

# %%
#  Población de 6 años y más, por entidad federativa, tamaño de la localidad y grupos de edad, según condición de alfabetismo y sexo
df=dataframes[5]
df.head(4)
# Out:
#    Estados Unidos Mexicanos Entidad federativa Área urbana y rural   \
# 0                       NaN                NaN                  NaN
# 1                         !                NaN                  NaN
# 2  Estados Unidos Mexicanos              Total                Total
# 3  Estados Unidos Mexicanos              Total                Total
#
#   Alfabetismo     Sexo  Población de 6 años y más  Edad en años  Unnamed: 7  \
# 0         NaN      NaN                        NaN           6.0         7.0
# 1         NaN      NaN                        NaN           NaN         NaN
# 2       Total    Total                 27987838.0     1143140.0   1071375.0
# 3       Total  Hombres                 13886456.0      578975.0    550878.0
#
#    Unnamed: 8  Unnamed: 9 Grupos de edad (años) Unnamed: 11 Unnamed: 12  \
# 0         8.0         9.0            De 10 a 14  De 15 a 19  De 20 a 24
# 1         NaN         NaN                   NaN         NaN         NaN
# 2   1070475.0    873510.0               4358316     3535265     2947072
# 3    540663.0    442917.0               2234497     1738831     1404868
#
#   Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16  Unnamed: 17  No indicados
# 0  De 25 a 29  De 30 a 39  De 40 a 49  De 50 a 59  De 60 y más           NaN
# 1         NaN         NaN         NaN         NaN          NaN           NaN
# 2     2504892     3972315     2594932     1863258      1939745      113543.0
# 3     1195988     1968245     1284789      932530       948611       64664.0

# %%
# Renombrar columnas
unnamed_columns=df.columns.to_list()[6:18]
rename_dictionary={}
for column in unnamed_columns:
    rename_dictionary[column]=df[column][0]
df=df.rename(columns=rename_dictionary)

df=df.rename(columns={
    6.0:"6",
    7.0:"7",
    8.0:"8",
    9.0:"9",
})

extra_columns=df.columns.to_list()[6:18]
rename_dictionary={}
for column in extra_columns:
    rename_dictionary[column]=f"{column} años"
    df=df.rename(columns=rename_dictionary)

# Remover registros 
rows_to_drop=[0,1,893]
df=df.drop(rows_to_drop)


# Formatear columnas
format_columns={'No indicados':'int',
                'Población de 6 años y más':'int',
                '6 años':'int',
                '7 años':'int',
                '8 años':'int',
                '9 años':'int'}
for column,format in format_columns.items():
    df[column]=df[column].astype(format)

# %%
df
# Out:
#      Estados Unidos Mexicanos Entidad federativa Área urbana y rural   \
# 2    Estados Unidos Mexicanos              Total                Total
# 3    Estados Unidos Mexicanos              Total                Total
# 4    Estados Unidos Mexicanos              Total                Total
# 5    Estados Unidos Mexicanos              Total                Total
# 6    Estados Unidos Mexicanos              Total                Total
# ..                        ...                ...                  ...
# 888  Estados Unidos Mexicanos          Zacatecas                Rural
# 889  Estados Unidos Mexicanos          Zacatecas                Rural
# 890  Estados Unidos Mexicanos          Zacatecas                Rural
# 891  Estados Unidos Mexicanos          Zacatecas                Rural
# 892  Estados Unidos Mexicanos          Zacatecas                Rural
#
#      Alfabetismo     Sexo  Población de 6 años y más     6 años     7 años  \
# 2          Total    Total                 27987838.0  1143140.0  1071375.0
# 3          Total  Hombres                 13886456.0   578975.0   550878.0
# 4          Total  Mujeres                 14101382.0   564165.0   520497.0
# 5      Alfabetos    Total                 17414675.0   152126.0   373413.0
# 6      Alfabetos  Hombres                  9102747.0    82375.0   197834.0
# ..           ...      ...                        ...        ...        ...
# 888    Alfabetos  Hombres                   148065.0      836.0     2189.0
# 889    Alfabetos  Mujeres                   135998.0      802.0     2108.0
# 890  Analfabetos    Total                   185289.0    19797.0    14483.0
# 891  Analfabetos  Hombres                    91989.0    10273.0     7435.0
# 892  Analfabetos  Mujeres                    93300.0     9524.0     7048.0
#
#         8 años    9 años De 10 a 14 años De 15 a 19 años De 20 a 24 años  \
# 2    1070475.0  873510.0         4358316         3535265         2947072
# 3     540663.0  442917.0         2234497         1738831         1404868
# 4     529812.0  430593.0         2123819         1796434         1542204
# 5     510128.0  530355.0         3120551         2618396         2121437
# 6     258422.0  269272.0         1600557         1310764         1064896
# ..         ...       ...             ...             ...             ...
# 888     3692.0    3968.0           26431           23311           18515
# 889     3615.0    3812.0           25517           22967           18422
# 890    12772.0    7735.0           26312           16272           11783
# 891     6575.0    3985.0           14070            8450            5010
# 892     6197.0    3750.0           12242            7822            6773
#
#     De 25 a 29 años De 30 a 39 años De 40 a 49 años De 50 a 59 años  \
# 2           2504892         3972315         2594932         1863258
# 3           1195988         1968245         1284789          932530
# 4           1308904         2004070         1310143          930728
# 5           1723647         2649266         1609947         1025960
# 6            883172         1426032          887555          581805
# ..              ...             ...             ...             ...
# 888           16164           22925           13108            8918
# 889           15791           19727           11196            6627
# 890            7752           19414           14521           14876
# 891            3344            8705            6519            7057
# 892            4408           10709            8002            7819
#
#     De 60 y más años  No indicados
# 2            1939745        113543
# 3             948611         64664
# 4             991134         48879
# 5             930854         48595
# 6             511520         28543
# ..               ...           ...
# 888             7808           200
# 889             5251           163
# 890            17362          2210
# 891             8655          1911
# 892             8707           299
#
# [891 rows x 19 columns]

# %% [markdown]
# ## Población de 6 años y más, por entidad federativa, tamaño de la localidad y grupos de edad, según condición de alfabetismo y sexo (1970)

# %%
df=dataframes[6]
df.head(5)
# Out:
#    Estados Unidos Mexicanos Entidad federativa Tamaño de la localidad  \
# 0                       NaN                NaN                    NaN
# 1                       NaN                NaN                    NaN
# 2  Estados Unidos Mexicanos              Total                  Total
# 3  Estados Unidos Mexicanos              Total                  Total
# 4  Estados Unidos Mexicanos              Total                  Total
#
#     Grupos de edad Población de 6 años y más Unnamed: 5 Unnamed: 6  \
# 0              NaN         Hombres y mujeres    Hombres    Mujeres
# 1              NaN                       NaN        NaN        NaN
# 2            Total                  38370438   19049853   19320585
# 3    De 6 a 9 años                   6035706    3070485    2965221
# 4  De 10 a 14 años                   6396174    3271115    3125059
#
#   Saben leer y escribir Unnamed: 8 Unnamed: 9 No saben leer y escribir  \
# 0     Hombres y mujeres    Hombres    Mujeres        Hombres y mujeres
# 1                   NaN        NaN        NaN                      NaN
# 2              27513751   14133236   13380515                 10856687
# 3               2856092    1431702    1424390                  3179614
# 4               5412807    2766280    2646527                   983367
#
#   Unnamed: 11 Unnamed: 12
# 0     Hombres     Mujeres
# 1         NaN         NaN
# 2     4916617     5940070
# 3     1638783     1540831
# 4      504835      478532

# %%
df.columns.to_list()[4:7]
# Out:
# ['Población de 6 años y más', 'Unnamed: 5', 'Unnamed: 6']

# %%
df.columns.to_list()[:4]+df.columns.to_list()[7:]
# Out:
# ['Estados Unidos Mexicanos',
#  'Entidad federativa',
#  'Tamaño de la localidad',
#  'Grupos de edad',
#  'Saben leer y escribir',
#  'Unnamed: 8',
#  'Unnamed: 9',
#  'No saben leer y escribir',
#  'Unnamed: 11',
#  'Unnamed: 12']

# %%
df=df[df.columns.to_list()[:4]+df.columns.to_list()[7:]]

# %%
df.columns.to_list()[4:]
# Out:
# ['Saben leer y escribir',
#  'Unnamed: 8',
#  'Unnamed: 9',
#  'No saben leer y escribir',
#  'Unnamed: 11',
#  'Unnamed: 12']

# %%
# Renombrar columnas
unnamed_columns=df.columns.to_list()[4:]
rename_dictionary={}
for column in unnamed_columns[:2]:
    rename_dictionary[column]=f"Saben leer y escribir :{df[column][0]}"
for column in unnamed_columns[2:]:
    rename_dictionary[column]=f"No saben leer y escribir :{df[column][0]}"
    
df=df.rename(columns=rename_dictionary)



# Remover registros 
rows_to_drop=[0,1,1964]
df=df.drop(rows_to_drop)


# Formatear columnas
format_columns={}
for column,format in format_columns.items():
    df[column]=df[column].astype(format)

# %%
df
# Out:
#       Estados Unidos Mexicanos Entidad federativa      Tamaño de la localidad  \
# 2     Estados Unidos Mexicanos              Total                       Total
# 3     Estados Unidos Mexicanos              Total                       Total
# 4     Estados Unidos Mexicanos              Total                       Total
# 5     Estados Unidos Mexicanos              Total                       Total
# 6     Estados Unidos Mexicanos              Total                       Total
# ...                        ...                ...                         ...
# 1959  Estados Unidos Mexicanos          Zacatecas  De 50 000 habitantes y más
# 1960  Estados Unidos Mexicanos          Zacatecas  De 50 000 habitantes y más
# 1961  Estados Unidos Mexicanos          Zacatecas  De 50 000 habitantes y más
# 1962  Estados Unidos Mexicanos          Zacatecas  De 50 000 habitantes y más
# 1963  Estados Unidos Mexicanos          Zacatecas  De 50 000 habitantes y más
#
#         Grupos de edad Saben leer y escribir :Hombres y mujeres  \
# 2                Total                                 27513751
# 3        De 6 a 9 años                                  2856092
# 4      De 10 a 14 años                                  5412807
# 5      De 15 a 19 años                                  4294533
# 6      De 20 a 24 años                                  3306028
# ...                ...                                      ...
# 1959   De 20 a 24 años                                     4029
# 1960   De 25 a 29 años                                     2831
# 1961   De 30 a 34 años                                     2228
# 1962   De 35 a 39 años                                     2036
# 1963  De 40 años y más                                     6837
#
#      Saben leer y escribir :Hombres No saben leer y escribir :Mujeres  \
# 2                          14133236                          13380515
# 3                           1431702                           1424390
# 4                           2766280                           2646527
# 5                           2144318                           2150215
# 6                           1635300                           1670728
# ...                             ...                               ...
# 1959                           1934                              2095
# 1960                           1350                              1481
# 1961                           1095                              1133
# 1962                            990                              1046
# 1963                           3355                              3482
#
#      No saben leer y escribir :Hombres y mujeres  \
# 2                                       10856687
# 3                                        3179614
# 4                                         983367
# 5                                         759858
# 6                                         726313
# ...                                          ...
# 1959                                         350
# 1960                                         234
# 1961                                         235
# 1962                                         297
# 1963                                        1591
#
#      No saben leer y escribir :Hombres No saben leer y escribir :Mujeres
# 2                              4916617                           5940070
# 3                              1638783                           1540831
# 4                               504835                            478532
# 5                               346729                            413129
# 6                               295000                            431313
# ...                                ...                               ...
# 1959                               162                               188
# 1960                                80                               154
# 1961                                82                               153
# 1962                                97                               200
# 1963                               595                               996
#
# [1962 rows x 10 columns]

# %% [markdown]
# ## Población de 15 años y más, por entidad federativa, tamaño de localidad y grupos quinquenales de edad, según condición de alfabetismo y sexo (1980)

# %%
df=dataframes[1]
df
# Out:
#       Estados Unidos Mexicanos Entidad federativa Tamaño de la localidad  \
# 0                          NaN                NaN                    NaN
# 1                          NaN                NaN                    NaN
# 2     Estados Unidos Mexicanos              Total                  Total
# 3     Estados Unidos Mexicanos              Total                  Total
# 4     Estados Unidos Mexicanos              Total                  Total
# ...                        ...                ...                    ...
# 3177  Estados Unidos Mexicanos      32  Zacatecas   50 000 a 99 999 hab.
# 3178  Estados Unidos Mexicanos      32  Zacatecas   50 000 a 99 999 hab.
# 3179  Estados Unidos Mexicanos      32  Zacatecas   50 000 a 99 999 hab.
# 3180  Estados Unidos Mexicanos      32  Zacatecas    100 000  y más hab.
# 3181                         !                NaN                    NaN
#
#      Grupos quinquenales de edad  Población de 15 años y más Alfabetas  \
# 0                            NaN                         NaN     Total
# 1                            NaN                         NaN       NaN
# 2                          Total                  37927410.0  31475670
# 3                   15 a 19 años                   7656539.0   7114592
# 4                   20 a 24 años                   6154527.0   5584296
# ...                          ...                         ...       ...
# 3177                55 a 59 años                      2936.0      2493
# 3178                60 a 64 años                      1959.0      1607
# 3179               65 y más años                      4879.0      3662
# 3180                       Total                         0.0         0
# 3181                         NaN                         NaN       NaN
#
#      Unnamed: 6 Unnamed: 7 Analfabetas Unnamed: 9 Unnamed: 10
# 0       Hombres    Mujeres       Total    Hombres     Mujeres
# 1           NaN        NaN         NaN        NaN         NaN
# 2      15955272   15520398     6451740    2545171     3906569
# 3       3527308    3587284      541947     239380      302567
# 4       2745709    2838587      570231     226465      343766
# ...         ...        ...         ...        ...         ...
# 3177       1263       1230         443        148         295
# 3178        737        870         352        118         234
# 3179       1659       2003        1217        442         775
# 3180          0          0           0          0           0
# 3181        NaN        NaN         NaN        NaN         NaN
#
# [3182 rows x 11 columns]

# %%
df.columns.to_list()[5:]
# Out:
# ['Alfabetas',
#  'Unnamed: 6',
#  'Unnamed: 7',
#  'Analfabetas',
#  'Unnamed: 9',
#  'Unnamed: 10']

# %%
# Renombrar columnas
unnamed_columns=df.columns.to_list()[5:]
rename_dictionary={}
for column in unnamed_columns[:2]:
    rename_dictionary[column]=f"Alfabetas :{df[column][0]}"
for column in unnamed_columns[2:]:
    rename_dictionary[column]=f"Analfabetas :{df[column][0]}"
    
df=df.rename(columns=rename_dictionary)



# Remover registros 
rows_to_drop=[0,1,3181]
df=df.drop(rows_to_drop)


# Formatear columnas
format_columns={"Población de 15 años y más":"int"}
for column,format in format_columns.items():
    df[column]=df[column].astype(format)

# %%
df
# Out:
#       Estados Unidos Mexicanos Entidad federativa Tamaño de la localidad  \
# 2     Estados Unidos Mexicanos              Total                  Total
# 3     Estados Unidos Mexicanos              Total                  Total
# 4     Estados Unidos Mexicanos              Total                  Total
# 5     Estados Unidos Mexicanos              Total                  Total
# 6     Estados Unidos Mexicanos              Total                  Total
# ...                        ...                ...                    ...
# 3176  Estados Unidos Mexicanos      32  Zacatecas   50 000 a 99 999 hab.
# 3177  Estados Unidos Mexicanos      32  Zacatecas   50 000 a 99 999 hab.
# 3178  Estados Unidos Mexicanos      32  Zacatecas   50 000 a 99 999 hab.
# 3179  Estados Unidos Mexicanos      32  Zacatecas   50 000 a 99 999 hab.
# 3180  Estados Unidos Mexicanos      32  Zacatecas    100 000  y más hab.
#
#      Grupos quinquenales de edad  Población de 15 años y más Alfabetas :Total  \
# 2                          Total                    37927410         31475670
# 3                   15 a 19 años                     7656539          7114592
# 4                   20 a 24 años                     6154527          5584296
# 5                   25 a 29 años                     4804392          4219010
# 6                   30 a 34 años                     3838059          3274644
# ...                          ...                         ...              ...
# 3176                50 a 54 años                        3581             3072
# 3177                55 a 59 años                        2936             2493
# 3178                60 a 64 años                        1959             1607
# 3179               65 y más años                        4879             3662
# 3180                       Total                           0                0
#
#      Alfabetas :Hombres Analfabetas :Mujeres Analfabetas :Total  \
# 2              15955272             15520398            6451740
# 3               3527308              3587284             541947
# 4               2745709              2838587             570231
# 5               2096665              2122345             585382
# 6               1664840              1609804             563415
# ...                 ...                  ...                ...
# 3176               1494                 1578                509
# 3177               1263                 1230                443
# 3178                737                  870                352
# 3179               1659                 2003               1217
# 3180                  0                    0                  0
#
#      Analfabetas :Hombres Analfabetas :Mujeres
# 2                 2545171              3906569
# 3                  239380               302567
# 4                  226465               343766
# 5                  228395               356987
# 6                  220788               342627
# ...                   ...                  ...
# 3176                  149                  360
# 3177                  148                  295
# 3178                  118                  234
# 3179                  442                  775
# 3180                    0                    0
#
# [3179 rows x 11 columns]

# %% [markdown]
# ## Población de 6 a 14 años por entidad federativa y edad desplegada según aptitud para leer y escribir y sexo (1990)

# %%
df=dataframes[7]
df
# Out:
#     según aptitud para leer y escribir y sexo          Unnamed: 1  \
# 0                    Estados Unidos Mexicanos  Entidad Federativa
# 1                                         NaN                 NaN
# 2                                         NaN                 NaN
# 3                                         NaN                 NaN
# 4                    Estados Unidos Mexicanos      Total Nacional
# ..                                        ...                 ...
# 330                  Estados Unidos Mexicanos        32 Zacatecas
# 331                  Estados Unidos Mexicanos        32 Zacatecas
# 332                  Estados Unidos Mexicanos        32 Zacatecas
# 333                  Estados Unidos Mexicanos        32 Zacatecas
# 334                                         !                 NaN
#
#           Unnamed: 2                Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0    Edad desplegada  Población de 6 a 14 años        NaN        NaN
# 1                NaN                     Total    Hombres    Mujeres
# 2                NaN                       NaN        NaN        NaN
# 3                NaN                       NaN        NaN        NaN
# 4     De 6 a 14 años                  18835378    9494321    9341057
# ..               ...                       ...        ...        ...
# 330          11 años                     34871      17476      17395
# 331          12 años                     38857      19778      19079
# 332          13 años                     36367      18128      18239
# 333          14 años                     37170      18308      18862
# 334              NaN                       NaN        NaN        NaN
#
#                Unnamed: 6 Unnamed: 7 Unnamed: 8               Unnamed: 9  \
# 0    Sabe leer y escribir        NaN        NaN  No sabe leer y escribir
# 1                   Total    Hombres    Mujeres                    Total
# 2                     NaN        NaN        NaN                      NaN
# 3                     NaN        NaN        NaN                      NaN
# 4                16405382    8246147    8159235                  2322125
# ..                    ...        ...        ...                      ...
# 330                 33849      16846      17003                      965
# 331                 37820      19144      18676                     1001
# 332                 35414      17539      17875                      924
# 333                 36092      17655      18437                     1034
# 334                   NaN        NaN        NaN                      NaN
#
#     Unnamed: 10 Unnamed: 11      Unnamed: 12 Unnamed: 13 Unnamed: 14
# 0           NaN         NaN  No especificado         NaN         NaN
# 1       Hombres     Mujeres            Total     Hombres     Mujeres
# 2           NaN         NaN              NaN         NaN         NaN
# 3           NaN         NaN              NaN         NaN         NaN
# 4       1193112     1129013           107871       55062       52809
# ..          ...         ...              ...         ...         ...
# 330         596         369               57          34          23
# 331         615         386               36          19          17
# 332         575         349               29          14          15
# 333         630         404               44          23          21
# 334         NaN         NaN              NaN         NaN         NaN
#
# [335 rows x 15 columns]

# %%
df.iloc[0,4] ='unnamed4'
df.iloc[0,5] ='unnamed5'
df.iloc[0,7] ='unnamed7'
df.iloc[0,8] ='unnamed8'
df.iloc[0,10] ='unnamed10'
df.iloc[0,11] ='unnamed11'
df.iloc[0,13] ='unnamed13'
df.iloc[0,14] ='unnamed14'
df.columns=df.iloc[0]
df=df.drop(0)
df=df.reset_index(drop=True)

# %%
df.columns
# Out:
# Index(['Estados Unidos Mexicanos', 'Entidad Federativa', 'Edad desplegada',
#        'Población de 6 a 14 años', 'unnamed4', 'unnamed5',
#        'Sabe leer y escribir', 'unnamed7', 'unnamed8',
#        'No sabe leer y escribir', 'unnamed10', 'unnamed11', 'No especificado',
#        'unnamed13', 'unnamed14'],
#       dtype='object', name=0)

# %%
df.columns.to_list()[3:]
# Out:
# ['Población de 6 a 14 años',
#  'unnamed4',
#  'unnamed5',
#  'Sabe leer y escribir',
#  'unnamed7',
#  'unnamed8',
#  'No sabe leer y escribir',
#  'unnamed10',
#  'unnamed11',
#  'No especificado',
#  'unnamed13',
#  'unnamed14']

# %%
df
# Out:
# 0    Estados Unidos Mexicanos Entidad Federativa Edad desplegada  \
# 0                         NaN                NaN             NaN
# 1                         NaN                NaN             NaN
# 2                         NaN                NaN             NaN
# 3    Estados Unidos Mexicanos     Total Nacional  De 6 a 14 años
# 4    Estados Unidos Mexicanos     Total Nacional          6 años
# ..                        ...                ...             ...
# 329  Estados Unidos Mexicanos       32 Zacatecas         11 años
# 330  Estados Unidos Mexicanos       32 Zacatecas         12 años
# 331  Estados Unidos Mexicanos       32 Zacatecas         13 años
# 332  Estados Unidos Mexicanos       32 Zacatecas         14 años
# 333                         !                NaN             NaN
#
# 0   Población de 6 a 14 años:Total Población de 6 a 14 años:Hombres  \
# 0                            Total                          Hombres
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                         18835378                          9494321
# 4                          2115168                          1062813
# ..                             ...                              ...
# 329                          34871                            17476
# 330                          38857                            19778
# 331                          36367                            18128
# 332                          37170                            18308
# 333                            NaN                              NaN
#
# 0   Población de 6 a 14 años:Mujeres Sabe leer y escribir :Total  \
# 0                            Mujeres                       Total
# 1                                NaN                         NaN
# 2                                NaN                         NaN
# 3                            9341057                    16405382
# 4                            1052355                      844438
# ..                               ...                         ...
# 329                            17395                       33849
# 330                            19079                       37820
# 331                            18239                       35414
# 332                            18862                       36092
# 333                              NaN                         NaN
#
# 0   Sabe leer y escribir :Hombres Sabe leer y escribir :Mujeres  \
# 0                         Hombres                       Mujeres
# 1                             NaN                           NaN
# 2                             NaN                           NaN
# 3                         8246147                       8159235
# 4                          412893                        431545
# ..                            ...                           ...
# 329                         16846                         17003
# 330                         19144                         18676
# 331                         17539                         17875
# 332                         17655                         18437
# 333                           NaN                           NaN
#
# 0   No sabe leer y escribir :Total No sabe leer y escribir :Hombres  \
# 0                            Total                          Hombres
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                          2322125                          1193112
# 4                          1222353                           625182
# ..                             ...                              ...
# 329                            965                              596
# 330                           1001                              615
# 331                            924                              575
# 332                           1034                              630
# 333                            NaN                              NaN
#
# 0   No sabe leer y escribir :Mujeres No especificado :Total  \
# 0                            Mujeres                  Total
# 1                                NaN                    NaN
# 2                                NaN                    NaN
# 3                            1129013                 107871
# 4                             597171                  48377
# ..                               ...                    ...
# 329                              369                     57
# 330                              386                     36
# 331                              349                     29
# 332                              404                     44
# 333                              NaN                    NaN
#
# 0   No especificado :Hombres No especificado :Mujeres
# 0                    Hombres                  Mujeres
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                      55062                    52809
# 4                      24738                    23639
# ..                       ...                      ...
# 329                       34                       23
# 330                       19                       17
# 331                       14                       15
# 332                       23                       21
# 333                      NaN                      NaN
#
# [334 rows x 15 columns]

# %%
# Renombrar columnas
unnamed_columns=df.columns.to_list()[3:]
rename_dictionary={}
for column in unnamed_columns[:3]:
    rename_dictionary[column]=f"Población de 6 a 14 años:{df[column][0]}"
for column in unnamed_columns[3:6]:
    rename_dictionary[column]=f"Sabe leer y escribir :{df[column][0]}"
for column in unnamed_columns[6:9]:
    rename_dictionary[column]=f"No sabe leer y escribir :{df[column][0]}"
for column in unnamed_columns[9:]:
    rename_dictionary[column]=f"No especificado :{df[column][0]}"


df=df.rename(columns=rename_dictionary)
print(" Columnas renombradas correctamente!")


# Remover registros 
rows_to_drop=[0,1,2,333]
df=df.drop(rows_to_drop)


# Formatear columnas
format_columns={}
for column,format in format_columns.items():
    df[column]=df[column].astype(format)
# Out:
#  Columnas renombradas correctamente!

# %%
df
# Out:
# 0    Estados Unidos Mexicanos Entidad Federativa Edad desplegada  \
# 3    Estados Unidos Mexicanos     Total Nacional  De 6 a 14 años
# 4    Estados Unidos Mexicanos     Total Nacional          6 años
# 5    Estados Unidos Mexicanos     Total Nacional          7 años
# 6    Estados Unidos Mexicanos     Total Nacional          8 años
# 7    Estados Unidos Mexicanos     Total Nacional          9 años
# ..                        ...                ...             ...
# 328  Estados Unidos Mexicanos       32 Zacatecas         10 años
# 329  Estados Unidos Mexicanos       32 Zacatecas         11 años
# 330  Estados Unidos Mexicanos       32 Zacatecas         12 años
# 331  Estados Unidos Mexicanos       32 Zacatecas         13 años
# 332  Estados Unidos Mexicanos       32 Zacatecas         14 años
#
# 0   Población de 6 a 14 años:Total Población de 6 a 14 años:Hombres  \
# 3                         18835378                          9494321
# 4                          2115168                          1062813
# 5                          2089506                          1059395
# 6                          2189467                          1105859
# 7                          2052145                          1035596
# ..                             ...                              ...
# 328                          37517                            19039
# 329                          34871                            17476
# 330                          38857                            19778
# 331                          36367                            18128
# 332                          37170                            18308
#
# 0   Población de 6 a 14 años:Mujeres Sabe leer y escribir :Total  \
# 3                            9341057                    16405382
# 4                            1052355                      844438
# 5                            1030111                     1727270
# 6                            1083608                     1977928
# 7                            1016549                     1925625
# ..                               ...                         ...
# 328                            18478                       36269
# 329                            17395                       33849
# 330                            19079                       37820
# 331                            18239                       35414
# 332                            18862                       36092
#
# 0   Sabe leer y escribir :Hombres Sabe leer y escribir :Mujeres  \
# 3                         8246147                       8159235
# 4                          412893                        431545
# 5                          869848                        857422
# 6                          995732                        982196
# 7                          969996                        955629
# ..                            ...                           ...
# 328                         18315                         17954
# 329                         16846                         17003
# 330                         19144                         18676
# 331                         17539                         17875
# 332                         17655                         18437
#
# 0   No sabe leer y escribir :Total No sabe leer y escribir :Hombres  \
# 3                          2322125                          1193112
# 4                          1222353                           625182
# 5                           344334                           180345
# 6                           200691                           104619
# 7                           117721                            61116
# ..                             ...                              ...
# 328                           1198                              695
# 329                            965                              596
# 330                           1001                              615
# 331                            924                              575
# 332                           1034                              630
#
# 0   No sabe leer y escribir :Mujeres No especificado :Total  \
# 3                            1129013                 107871
# 4                             597171                  48377
# 5                             163989                  17902
# 6                              96072                  10848
# 7                              56605                   8799
# ..                               ...                    ...
# 328                              503                     50
# 329                              369                     57
# 330                              386                     36
# 331                              349                     29
# 332                              404                     44
#
# 0   No especificado :Hombres No especificado :Mujeres
# 3                      55062                    52809
# 4                      24738                    23639
# 5                       9202                     8700
# 6                       5508                     5340
# 7                       4484                     4315
# ..                       ...                      ...
# 328                       29                       21
# 329                       34                       23
# 330                       19                       17
# 331                       14                       15
# 332                       23                       21
#
# [330 rows x 15 columns]

# %% [markdown]
# ## Población de 6 a 14 años por entidad federativa y edad desplegada según aptitud para leer y escribir y sexo (1995)

# %%
df=dataframes[8]
df
# Out:
#     según aptitud para leer y escribir y sexo          Unnamed: 1  \
# 0                    Estados Unidos Mexicanos  Entidad federativa
# 1                                         NaN                 NaN
# 2                                         NaN                 NaN
# 3                                         NaN                 NaN
# 4                                         NaN                 NaN
# ..                                        ...                 ...
# 331                  Estados Unidos Mexicanos        32 Zacatecas
# 332                  Estados Unidos Mexicanos        32 Zacatecas
# 333                  Estados Unidos Mexicanos        32 Zacatecas
# 334                  Estados Unidos Mexicanos        32 Zacatecas
# 335                                         !                 NaN
#
#           Unnamed: 2                Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0    Edad desplegada  Población de 6 a 14 años        NaN        NaN
# 1                NaN                       NaN        NaN        NaN
# 2                NaN                     Total    Hombres    Mujeres
# 3                NaN                       NaN        NaN        NaN
# 4                NaN                       NaN        NaN        NaN
# ..               ...                       ...        ...        ...
# 331          11 años                     33056      16911      16145
# 332          12 años                     36422      18624      17798
# 333          13 años                     34112      17196      16916
# 334          14 años                     33163      16533      16630
# 335              NaN                       NaN        NaN        NaN
#
#                Unnamed: 6 Unnamed: 7 Unnamed: 8               Unnamed: 9  \
# 0    Sabe leer y escribir        NaN        NaN  No sabe leer y escribir
# 1                     NaN        NaN        NaN                      NaN
# 2                   Total    Hombres    Mujeres                    Total
# 3                     NaN        NaN        NaN                      NaN
# 4                     NaN        NaN        NaN                      NaN
# ..                    ...        ...        ...                      ...
# 331                 32327      16439      15888                      694
# 332                 35662      18144      17518                      721
# 333                 33335      16726      16609                      747
# 334                 32271      15995      16276                      861
# 335                   NaN        NaN        NaN                      NaN
#
#     Unnamed: 10 Unnamed: 11      Unnamed: 12 Enumeración Unnamed: 14
# 0           NaN         NaN  No especificado         NaN         NaN
# 1           NaN         NaN              NaN         NaN         NaN
# 2       Hombres     Mujeres            Total     Hombres     Mujeres
# 3           NaN         NaN              NaN         NaN         NaN
# 4           NaN         NaN              NaN         NaN         NaN
# ..          ...         ...              ...         ...         ...
# 331         452         242               35          20          15
# 332         460         261               39          20          19
# 333         455         292               30          15          15
# 334         523         338               31          15          16
# 335         NaN         NaN              NaN         NaN         NaN
#
# [336 rows x 15 columns]

# %%
df.iloc[0,4] ='unnamed4'
df.iloc[0,5] ='unnamed5'
df.iloc[0,7] ='unnamed7'
df.iloc[0,8] ='unnamed8'
df.iloc[0,10] ='unnamed10'
df.iloc[0,11] ='unnamed11'
df.iloc[0,13] ='unnamed13'
df.iloc[0,14] ='unnamed14'
df.columns=df.iloc[0]
df=df.drop([0,1])
df=df.reset_index(drop=True)

# %%
df
# Out:
# 0    Estados Unidos Mexicanos Entidad federativa Edad desplegada  \
# 0                         NaN                NaN             NaN
# 1                         NaN                NaN             NaN
# 2                         NaN                NaN             NaN
# 3    Estados Unidos Mexicanos     Total Nacional           Total
# 4    Estados Unidos Mexicanos     Total Nacional          6 años
# ..                        ...                ...             ...
# 329  Estados Unidos Mexicanos       32 Zacatecas         11 años
# 330  Estados Unidos Mexicanos       32 Zacatecas         12 años
# 331  Estados Unidos Mexicanos       32 Zacatecas         13 años
# 332  Estados Unidos Mexicanos       32 Zacatecas         14 años
# 333                         !                NaN             NaN
#
# 0   Población de 6 a 14 años unnamed4 unnamed5 Sabe leer y escribir unnamed7  \
# 0                      Total  Hombres  Mujeres                Total  Hombres
# 1                        NaN      NaN      NaN                  NaN      NaN
# 2                        NaN      NaN      NaN                  NaN      NaN
# 3                   19332243  9796181  9536062             16624651  8390006
# 4                    2169899  1095777  1074122               814078   405471
# ..                       ...      ...      ...                  ...      ...
# 329                    33056    16911    16145                32327    16439
# 330                    36422    18624    17798                35662    18144
# 331                    34112    17196    16916                33335    16726
# 332                    33163    16533    16630                32271    15995
# 333                      NaN      NaN      NaN                  NaN      NaN
#
# 0   unnamed8 No sabe leer y escribir unnamed10 unnamed11 No especificado  \
# 0    Mujeres                   Total   Hombres   Mujeres           Total
# 1        NaN                     NaN       NaN       NaN             NaN
# 2        NaN                     NaN       NaN       NaN             NaN
# 3    8234645                 2663835   1383850   1279985           43757
# 4     408607                 1340916    682648    658268           14905
# ..       ...                     ...       ...       ...             ...
# 329    15888                     694       452       242              35
# 330    17518                     721       460       261              39
# 331    16609                     747       455       292              30
# 332    16276                     861       523       338              31
# 333      NaN                     NaN       NaN       NaN             NaN
#
# 0   unnamed13 unnamed14
# 0     Hombres   Mujeres
# 1         NaN       NaN
# 2         NaN       NaN
# 3       22325     21432
# 4        7658      7247
# ..        ...       ...
# 329        20        15
# 330        20        19
# 331        15        15
# 332        15        16
# 333       NaN       NaN
#
# [334 rows x 15 columns]

# %%
df.columns.to_list()[3:]
# Out:
# ['Población de 6 a 14 años',
#  'unnamed4',
#  'unnamed5',
#  'Sabe leer y escribir',
#  'unnamed7',
#  'unnamed8',
#  'No sabe leer y escribir',
#  'unnamed10',
#  'unnamed11',
#  'No especificado',
#  'unnamed13',
#  'unnamed14']

# %%
# Renombrar columnas
unnamed_columns=df.columns.to_list()[3:]
rename_dictionary={}
for column in unnamed_columns[:3]:
    rename_dictionary[column]=f"Población de 6 a 14 años:{df[column][0]}"
for column in unnamed_columns[3:6]:
    rename_dictionary[column]=f"Sabe leer y escribir :{df[column][0]}"
for column in unnamed_columns[6:9]:
    rename_dictionary[column]=f"No sabe leer y escribir :{df[column][0]}"
for column in unnamed_columns[9:]:
    rename_dictionary[column]=f"No especificado :{df[column][0]}"


df=df.rename(columns=rename_dictionary)
print(" Columnas renombradas correctamente!")


# Remover registros 
rows_to_drop=[0,1,2,333]
df=df.drop(rows_to_drop)


# Formatear columnas
format_columns={}
for column,format in format_columns.items():
    df[column]=df[column].astype(format)
# Out:
#  Columnas renombradas correctamente!

# %%
df
# Out:
# 0    Estados Unidos Mexicanos Entidad federativa Edad desplegada  \
# 3    Estados Unidos Mexicanos     Total Nacional           Total
# 4    Estados Unidos Mexicanos     Total Nacional          6 años
# 5    Estados Unidos Mexicanos     Total Nacional          7 años
# 6    Estados Unidos Mexicanos     Total Nacional          8 años
# 7    Estados Unidos Mexicanos     Total Nacional          9 años
# ..                        ...                ...             ...
# 328  Estados Unidos Mexicanos       32 Zacatecas         10 años
# 329  Estados Unidos Mexicanos       32 Zacatecas         11 años
# 330  Estados Unidos Mexicanos       32 Zacatecas         12 años
# 331  Estados Unidos Mexicanos       32 Zacatecas         13 años
# 332  Estados Unidos Mexicanos       32 Zacatecas         14 años
#
# 0   Población de 6 a 14 años:Total Población de 6 a 14 años:Hombres  \
# 3                         19332243                          9796181
# 4                          2169899                          1095777
# 5                          2108583                          1075246
# 6                          2268118                          1151177
# 7                          2115595                          1069720
# ..                             ...                              ...
# 328                          36783                            18706
# 329                          33056                            16911
# 330                          36422                            18624
# 331                          34112                            17196
# 332                          33163                            16533
#
# 0   Población de 6 a 14 años:Mujeres Sabe leer y escribir :Total  \
# 3                            9536062                    16624651
# 4                            1074122                      814078
# 5                            1033337                     1618640
# 6                            1116941                     1992823
# 7                            1045875                     1963844
# ..                               ...                         ...
# 328                            18077                       35679
# 329                            16145                       32327
# 330                            17798                       35662
# 331                            16916                       33335
# 332                            16630                       32271
#
# 0   Sabe leer y escribir :Hombres Sabe leer y escribir :Mujeres  \
# 3                         8390006                       8234645
# 4                          405471                        408607
# 5                          816001                        802639
# 6                         1004568                        988255
# 7                          988622                        975222
# ..                            ...                           ...
# 328                         18019                         17660
# 329                         16439                         15888
# 330                         18144                         17518
# 331                         16726                         16609
# 332                         15995                         16276
#
# 0   No sabe leer y escribir :Total No sabe leer y escribir :Hombres  \
# 3                          2663835                          1383850
# 4                          1340916                           682648
# 5                           484569                           256488
# 6                           270923                           144375
# 7                           147131                            78756
# ..                             ...                              ...
# 328                           1062                              668
# 329                            694                              452
# 330                            721                              460
# 331                            747                              455
# 332                            861                              523
#
# 0   No sabe leer y escribir :Mujeres No especificado :Total  \
# 3                            1279985                  43757
# 4                             658268                  14905
# 5                             228081                   5374
# 6                             126548                   4372
# 7                              68375                   4620
# ..                               ...                    ...
# 328                              394                     42
# 329                              242                     35
# 330                              261                     39
# 331                              292                     30
# 332                              338                     31
#
# 0   No especificado :Hombres No especificado :Mujeres
# 3                      22325                    21432
# 4                       7658                     7247
# 5                       2757                     2617
# 6                       2234                     2138
# 7                       2342                     2278
# ..                       ...                      ...
# 328                       19                       23
# 329                       20                       15
# 330                       20                       19
# 331                       15                       15
# 332                       15                       16
#
# [330 rows x 15 columns]

# %% [markdown]
# ## 2000

# %%
df=dataframes[9]
dictionary_df=diccionarios_de_datos[3]

# %%
columns=[
    'Clave de entidad federativa',
 'Nombre de la entidad',
 'Clave de municipio o delegación',
 'Nombre del municipio o delegación',
 'Clave de localidad',
 'Nombre de la localidad',
 'Longitud',
 'Latitud',
 'Altitud',
 'Población total',
 'Población masculina',
 'Población femenina',
 'Población de 0 a 4 años',
 'Población de 5 años y más',
 'Población de 6 a 14 años',
 'Población de 12 años y más',
 'Población de 15 años y más',
 'Población de 15 a 17 años',
 'Población de 15 a 24 años',
 'Po blación femenina de 15 a 49 años',
 'Población de 18 años y más',
 'Población masculina de 18 años y más',
 'Población femenina de 18 años y más',
 'Población de 6 a 14 años que sabe leer y escribir',
 'Población de 6 a 14 años que no sabe leer y escribir',
 'Población de 15 años y más alfabeta',
 'Población de 15 años y más analfabeta',
 'Población de 5 años que asiste a la escuela',
 'Población de 5 años que no asiste a la escuela',
 'Población de 6 a 14 años que asiste a la escuela',
 'Población de 6 a 14 años que no asiste a la escuela',
 'Población de 15 a 17 años que asiste a la escuela',
 'Población de 15 a 24 años que asiste a la escuela',
 'Población de 15 a 24 años que no asiste a la escuela',
 'Población de 15 años y más sin instrucción',
 'Población de 15 años y más con primaria incompleta',
 'Población de 15 años y más con primaria completa',
 'Población de 15 años y más con instrucción posprimaria',
 'Población de 15 años y más con secundaria incompleta',
 'Población de 15 años y más con secundaria completa',
 'Población de 15 años y más sin instrucción posprimaria',
 'Población de 15 años y más con instrucción secundaria o estudios técnicos o comerciales con primaria terminada',
 'Población de 15 años y más con instrucción media superior o superior',
 'Población de 18 años y más sin instrucción media superior',
 'Población de 18 años y más con instrucción media superior',
 'Población de 18 años y más con instrucción superior',
 'Grado promedio de escolaridad',
]

string_columns=[
 'Clave de entidad federativa',
 'Nombre de la entidad',
 'Clave de municipio o delegación',
 'Nombre del municipio o delegación',
 'Clave de localidad',
 'Nombre de la localidad',]
float_columns=[
 'Grado promedio de escolaridad','Longitud',
 'Latitud',
 'Altitud',]
integer_columns=['Población total',
 'Población masculina',
 'Población femenina',
 'Población de 0 a 4 años',
 'Población de 5 años y más',
 'Población de 6 a 14 años',
 'Población de 12 años y más',
 'Población de 15 años y más',
 'Población de 15 a 17 años',
 'Población de 15 a 24 años',
 'Po blación femenina de 15 a 49 años',
 'Población de 18 años y más',
 'Población masculina de 18 años y más',
 'Población femenina de 18 años y más',
 'Población de 6 a 14 años que sabe leer y escribir',
 'Población de 6 a 14 años que no sabe leer y escribir',
 'Población de 15 años y más alfabeta',
 'Población de 15 años y más analfabeta',
 'Población de 5 años que asiste a la escuela',
 'Población de 5 años que no asiste a la escuela',
 'Población de 6 a 14 años que asiste a la escuela',
 'Población de 6 a 14 años que no asiste a la escuela',
 'Población de 15 a 17 años que asiste a la escuela',
 'Población de 15 a 24 años que asiste a la escuela',
 'Población de 15 a 24 años que no asiste a la escuela',
 'Población de 15 años y más sin instrucción',
 'Población de 15 años y más con primaria incompleta',
 'Población de 15 años y más con primaria completa',
 'Población de 15 años y más con instrucción posprimaria',
 'Población de 15 años y más con secundaria incompleta',
 'Población de 15 años y más con secundaria completa',
 'Población de 15 años y más sin instrucción posprimaria',
 'Población de 15 años y más con instrucción secundaria o estudios técnicos o comerciales con primaria terminada',
 'Población de 15 años y más con instrucción media superior o superior',
 'Población de 18 años y más sin instrucción media superior',
 'Población de 18 años y más con instrucción media superior',
 'Población de 18 años y más con instrucción superior',]

format_columns={
    'string_columns':string_columns,
    'float_columns':float_columns,
    'integer_columns':integer_columns
}

# %%
df=filtro_columnas(df,dictionary_df,columns)

# %%
revision_nulos(df)
# Out:
# 3.0581% de los registros en Longitud son nulos
# 3.0581% de los registros en Latitud son nulos
# 3.0581% de los registros en Altitud son nulos
# 0.001% de los registros en Grado promedio de escolaridad son nulos

# %%
errores=formato_columnas(df,format_columns)
# Out:
# 45.0% de los registros en Grado promedio de escolaridad son *
# Se omitieron los registros erroneos en Grado promedio de escolaridad exitosamente!
# 0.0% de los registros en Longitud son , LA (R
# Se omitieron los registros erroneos en Longitud exitosamente!
# 45.0% de los registros en Población masculina son *
# Se omitieron los registros erroneos en Población masculina exitosamente!
# 45.0% de los registros en Población femenina son *
# Se omitieron los registros erroneos en Población femenina exitosamente!
# 45.0% de los registros en Población de 0 a 4 años son *
# Se omitieron los registros erroneos en Población de 0 a 4 años exitosamente!
# 45.0% de los registros en Población de 5 años y más son *
# Se omitieron los registros erroneos en Población de 5 años y más exitosamente!
# 45.0% de los registros en Población de 6 a 14 años son *
# Se omitieron los registros erroneos en Población de 6 a 14 años exitosamente!
# 45.0% de los registros en Población de 12 años y más son *
# Se omitieron los registros erroneos en Población de 12 años y más exitosamente!
# 45.0% de los registros en Población de 15 años y más son *
# Se omitieron los registros erroneos en Población de 15 años y más exitosamente!
# 45.0% de los registros en Población de 15 a 17 años son *
# Se omitieron los registros erroneos en Población de 15 a 17 años exitosamente!
# 45.0% de los registros en Población de 15 a 24 años son *
# Se omitieron los registros erroneos en Población de 15 a 24 años exitosamente!
# 45.0% de los registros en Po blación femenina de 15 a 49 años son *
# Se omitieron los registros erroneos en Po blación femenina de 15 a 49 años exitosamente!
# 45.0% de los registros en Población de 18 años y más son *
# Se omitieron los registros erroneos en Población de 18 años y más exitosamente!
# 45.0% de los registros en Población masculina de 18 años y más son *
# Se omitieron los registros erroneos en Población masculina de 18 años y más exitosamente!
# 45.0% de los registros en Población femenina de 18 años y más son *
# Se omitieron los registros erroneos en Población femenina de 18 años y más exitosamente!
# 45.0% de los registros en Población de 6 a 14 años que sabe leer y escribir son *
# Se omitieron los registros erroneos en Población de 6 a 14 años que sabe leer y escribir exitosamente!
# 45.0% de los registros en Población de 6 a 14 años que no sabe leer y escribir son *
# Se omitieron los registros erroneos en Población de 6 a 14 años que no sabe leer y escribir exitosamente!
# 45.0% de los registros en Población de 15 años y más alfabeta son *
# Se omitieron los registros erroneos en Población de 15 años y más alfabeta exitosamente!
# 45.0% de los registros en Población de 15 años y más analfabeta son *
# Se omitieron los registros erroneos en Población de 15 años y más analfabeta exitosamente!
# 45.0% de los registros en Población de 5 años que asiste a la escuela son *
# Se omitieron los registros erroneos en Población de 5 años que asiste a la escuela exitosamente!
# 45.0% de los registros en Población de 5 años que no asiste a la escuela son *
# Se omitieron los registros erroneos en Población de 5 años que no asiste a la escuela exitosamente!
# 45.0% de los registros en Población de 6 a 14 años que asiste a la escuela son *
# Se omitieron los registros erroneos en Población de 6 a 14 años que asiste a la escuela exitosamente!
# 45.0% de los registros en Población de 6 a 14 años que no asiste a la escuela son *
# Se omitieron los registros erroneos en Población de 6 a 14 años que no asiste a la escuela exitosamente!
# 45.0% de los registros en Población de 15 a 17 años que asiste a la escuela son *
# Se omitieron los registros erroneos en Población de 15 a 17 años que asiste a la escuela exitosamente!
# 45.0% de los registros en Población de 15 a 24 años que asiste a la escuela son *
# Se omitieron los registros erroneos en Población de 15 a 24 años que asiste a la escuela exitosamente!
# 45.0% de los registros en Población de 15 a 24 años que no asiste a la escuela son *
# Se omitieron los registros erroneos en Población de 15 a 24 años que no asiste a la escuela exitosamente!
# 45.0% de los registros en Población de 15 años y más sin instrucción son *
# Se omitieron los registros erroneos en Población de 15 años y más sin instrucción exitosamente!
# 45.0% de los registros en Población de 15 años y más con primaria incompleta son *
# Se omitieron los registros erroneos en Población de 15 años y más con primaria incompleta exitosamente!
# 45.0% de los registros en Población de 15 años y más con primaria completa son *
# Se omitieron los registros erroneos en Población de 15 años y más con primaria completa exitosamente!
# 45.0% de los registros en Población de 15 años y más con instrucción posprimaria son *
# Se omitieron los registros erroneos en Población de 15 años y más con instrucción posprimaria exitosamente!
# 45.0% de los registros en Población de 15 años y más con secundaria incompleta son *
# Se omitieron los registros erroneos en Población de 15 años y más con secundaria incompleta exitosamente!
# 45.0% de los registros en Población de 15 años y más con secundaria completa son *
# Se omitieron los registros erroneos en Población de 15 años y más con secundaria completa exitosamente!
# 45.0% de los registros en Población de 15 años y más sin instrucción posprimaria son *
# Se omitieron los registros erroneos en Población de 15 años y más sin instrucción posprimaria exitosamente!
# 45.0% de los registros en Población de 15 años y más con instrucción secundaria o estudios técnicos o comerciales con primaria terminada son *
# Se omitieron los registros erroneos en Población de 15 años y más con instrucción secundaria o estudios técnicos o comerciales con primaria terminada exitosamente!
# 45.0% de los registros en Población de 15 años y más con instrucción media superior o superior son *
# Se omitieron los registros erroneos en Población de 15 años y más con instrucción media superior o superior exitosamente!
# 45.0% de los registros en Población de 18 años y más sin instrucción media superior son *
# Se omitieron los registros erroneos en Población de 18 años y más sin instrucción media superior exitosamente!
# 45.0% de los registros en Población de 18 años y más con instrucción media superior son *
# Se omitieron los registros erroneos en Población de 18 años y más con instrucción media superior exitosamente!
# 45.0% de los registros en Población de 18 años y más con instrucción superior son *
# Se omitieron los registros erroneos en Población de 18 años y más con instrucción superior exitosamente!

# %%
df=df[~(df['Grado promedio de escolaridad']=='*')]
# Out:
#        Clave de entidad federativa Nombre de la entidad  \
# 0                                0       Total nacional
# 1                                0       Total nacional
# 2                                0       Total nacional
# 3                                1       Aguascalientes
# 4                                1       Aguascalientes
# ...                            ...                  ...
# 205666                          32            Zacatecas
# 205667                          32            Zacatecas
# 205671                          32            Zacatecas
# 205679                          32            Zacatecas
# 205680                          32            Zacatecas
#
#        Clave de municipio o delegación   Nombre del municipio o delegación  \
# 0                                    0                      Total nacional
# 1                                    0                      Total nacional
# 2                                    0                      Total nacional
# 3                                    0  Total de la entidad Aguascalientes
# 4                                    0  Total de la entidad Aguascalientes
# ...                                ...                                 ...
# 205666                              57                            Trancoso
# 205667                              57                            Trancoso
# 205671                              57                            Trancoso
# 205679                              57                            Trancoso
# 205680                              57                            Trancoso
#
#        Clave de localidad                   Nombre de la localidad   Longitud  \
# 0                       0                           TOTAL NACIONAL        NaN
# 1                    9999             LOCALIDADES DE DOS VIVIENDAS        NaN
# 2                    9998              LOCALIDADES DE UNA VIVIENDA        NaN
# 3                       0                      TOTAL DE LA ENTIDAD        NaN
# 4                    9998              LOCALIDADES DE UNA VIVIENDA        NaN
# ...                   ...                                      ...        ...
# 205666                 28                      SAN JOSE DEL CARMEN  1021625.0
# 205667                 29                   SAN SALVADOR DEL BAJIO  1021700.0
# 205671                 34  SIN NOMBRE (RESTAURANTE LAS MARGARITAS)  1022029.0
# 205679               9998              LOCALIDADES DE UNA VIVIENDA        NaN
# 205680               9999             LOCALIDADES DE DOS VIVIENDAS        NaN
#
#          Latitud  Altitud  Población total  ...  \
# 0            NaN      NaN         97483412  ...
# 1            NaN      NaN           212010  ...
# 2            NaN      NaN           313698  ...
# 3            NaN      NaN           944285  ...
# 4            NaN      NaN             4400  ...
# ...          ...      ...              ...  ...
# 205666  224607.0   2080.0              807  ...
# 205667  224755.0   2060.0              166  ...
# 205671  224406.0   2150.0               14  ...
# 205679       NaN      NaN               48  ...
# 205680       NaN      NaN               21  ...
#
#        Población de 15 años y más con instrucción posprimaria  \
# 0                                                32535609
# 1                                                   24768
# 2                                                   45244
# 3                                                  328100
# 4                                                     807
# ...                                                   ...
# 205666                                                 86
# 205667                                                 18
# 205671                                                  0
# 205679                                                  3
# 205680                                                  1
#
#        Población de 15 años y más con secundaria incompleta  \
# 0                                                 3205083
# 1                                                    5174
# 2                                                   10013
# 3                                                   29697
# 4                                                     138
# ...                                                   ...
# 205666                                                 18
# 205667                                                  7
# 205671                                                  0
# 205679                                                  0
# 205680                                                  1
#
#        Población de 15 años y más con secundaria completa  \
# 0                                                11603530
# 1                                                   11524
# 2                                                   20266
# 3                                                  115879
# 4                                                     369
# ...                                                   ...
# 205666                                                 66
# 205667                                                  8
# 205671                                                  0
# 205679                                                  2
# 205680                                                  0
#
#        Población de 15 años y más sin instrucción posprimaria  \
# 0                                                29757418
# 1                                                  102330
# 2                                                  159126
# 3                                                  262560
# 4                                                    1878
# ...                                                   ...
# 205666                                                332
# 205667                                                 80
# 205671                                                  6
# 205679                                                 24
# 205680                                                 11
#
#        Población de 15 años y más con instrucción secundaria o estudios técnicos o comerciales con primaria terminada  \
# 0                                                15210653
# 1                                                   16827
# 2                                                   30531
# 3                                                  152476
# 4                                                     515
# ...                                                   ...
# 205666                                                 84
# 205667                                                 15
# 205671                                                  0
# 205679                                                  2
# 205680                                                  1
#
#        Población de 15 años y más con instrucción media superior o superior  \
# 0                                                17324956
# 1                                                    7941
# 2                                                   14713
# 3                                                  175624
# 4                                                     292
# ...                                                   ...
# 205666                                                  2
# 205667                                                  3
# 205671                                                  0
# 205679                                                  1
# 205680                                                  0
#
#        Población de 18 años y más sin instrucción media superior  \
# 0                                                40335005
# 1                                                  106671
# 2                                                  171116
# 3                                                  369544
# 4                                                    2094
# ...                                                   ...
# 205666                                                365
# 205667                                                 80
# 205671                                                  6
# 205679                                                 22
# 205680                                                 11
#
#        Población de 18 años y más con instrucción media superior  \
# 0                                                 8999238
# 1                                                    4733
# 2                                                    9085
# 3                                                   89349
# 4                                                     186
# ...                                                   ...
# 205666                                                  0
# 205667                                                  3
# 205671                                                  0
# 205679                                                  1
# 205680                                                  0
#
#        Población de 18 años y más con instrucción superior  \
# 0                                                 6861605
# 1                                                    2361
# 2                                                    4256
# 3                                                   70672
# 4                                                      80
# ...                                                   ...
# 205666                                                  0
# 205667                                                  0
# 205671                                                  0
# 205679                                                  0
# 205680                                                  0
#
#        Grado promedio de escolaridad
# 0                                  7
# 1                                NaN
# 2                                NaN
# 3                                  8
# 4                                  5
# ...                              ...
# 205666                             4
# 205667                             4
# 205671                             4
# 205679                             3
# 205680                             3
#
# [113833 rows x 47 columns]

# %%
formato_columnas(df,format_columns)
# Out:
# 1.0% de los registros en Grado promedio de escolaridad son N/D
# Se omitieron los registros erroneos en Grado promedio de escolaridad exitosamente!
# 0.0% de los registros en Longitud son , LA (R
# Se omitieron los registros erroneos en Longitud exitosamente!
# 1.0% de los registros en Población de 0 a 4 años son N/D
# Se omitieron los registros erroneos en Población de 0 a 4 años exitosamente!
# 1.0% de los registros en Población de 5 años y más son N/D
# Se omitieron los registros erroneos en Población de 5 años y más exitosamente!
# 1.0% de los registros en Población de 6 a 14 años son N/D
# Se omitieron los registros erroneos en Población de 6 a 14 años exitosamente!
# 1.0% de los registros en Población de 12 años y más son N/D
# Se omitieron los registros erroneos en Población de 12 años y más exitosamente!
# 1.0% de los registros en Población de 15 años y más son N/D
# Se omitieron los registros erroneos en Población de 15 años y más exitosamente!
# 1.0% de los registros en Población de 15 a 17 años son N/D
# Se omitieron los registros erroneos en Población de 15 a 17 años exitosamente!
# 1.0% de los registros en Población de 15 a 24 años son N/D
# Se omitieron los registros erroneos en Población de 15 a 24 años exitosamente!
# 1.0% de los registros en Po blación femenina de 15 a 49 años son N/D
# Se omitieron los registros erroneos en Po blación femenina de 15 a 49 años exitosamente!
# 1.0% de los registros en Población de 18 años y más son N/D
# Se omitieron los registros erroneos en Población de 18 años y más exitosamente!
# 1.0% de los registros en Población masculina de 18 años y más son N/D
# Se omitieron los registros erroneos en Población masculina de 18 años y más exitosamente!
# 1.0% de los registros en Población femenina de 18 años y más son N/D
# Se omitieron los registros erroneos en Población femenina de 18 años y más exitosamente!
# 1.0% de los registros en Población de 6 a 14 años que sabe leer y escribir son N/D
# Se omitieron los registros erroneos en Población de 6 a 14 años que sabe leer y escribir exitosamente!
# 1.0% de los registros en Población de 6 a 14 años que no sabe leer y escribir son N/D
# Se omitieron los registros erroneos en Población de 6 a 14 años que no sabe leer y escribir exitosamente!
# 1.0% de los registros en Población de 15 años y más alfabeta son N/D
# Se omitieron los registros erroneos en Población de 15 años y más alfabeta exitosamente!
# 1.0% de los registros en Población de 15 años y más analfabeta son N/D
# Se omitieron los registros erroneos en Población de 15 años y más analfabeta exitosamente!
# 1.0% de los registros en Población de 5 años que asiste a la escuela son N/D
# Se omitieron los registros erroneos en Población de 5 años que asiste a la escuela exitosamente!
# 1.0% de los registros en Población de 5 años que no asiste a la escuela son N/D
# Se omitieron los registros erroneos en Población de 5 años que no asiste a la escuela exitosamente!
# 1.0% de los registros en Población de 6 a 14 años que asiste a la escuela son N/D
# Se omitieron los registros erroneos en Población de 6 a 14 años que asiste a la escuela exitosamente!
# 1.0% de los registros en Población de 6 a 14 años que no asiste a la escuela son N/D
# Se omitieron los registros erroneos en Población de 6 a 14 años que no asiste a la escuela exitosamente!
# 1.0% de los registros en Población de 15 a 17 años que asiste a la escuela son N/D
# Se omitieron los registros erroneos en Población de 15 a 17 años que asiste a la escuela exitosamente!
# 1.0% de los registros en Población de 15 a 24 años que asiste a la escuela son N/D
# Se omitieron los registros erroneos en Población de 15 a 24 años que asiste a la escuela exitosamente!
# 1.0% de los registros en Población de 15 a 24 años que no asiste a la escuela son N/D
# Se omitieron los registros erroneos en Población de 15 a 24 años que no asiste a la escuela exitosamente!
# 1.0% de los registros en Población de 15 años y más sin instrucción son N/D
# Se omitieron los registros erroneos en Población de 15 años y más sin instrucción exitosamente!
# 1.0% de los registros en Población de 15 años y más con primaria incompleta son N/D
# Se omitieron los registros erroneos en Población de 15 años y más con primaria incompleta exitosamente!
# 1.0% de los registros en Población de 15 años y más con primaria completa son N/D
# Se omitieron los registros erroneos en Población de 15 años y más con primaria completa exitosamente!
# 1.0% de los registros en Población de 15 años y más con instrucción posprimaria son N/D
# Se omitieron los registros erroneos en Población de 15 años y más con instrucción posprimaria exitosamente!
# 1.0% de los registros en Población de 15 años y más con secundaria incompleta son N/D
# Se omitieron los registros erroneos en Población de 15 años y más con secundaria incompleta exitosamente!
# 1.0% de los registros en Población de 15 años y más con secundaria completa son N/D
# Se omitieron los registros erroneos en Población de 15 años y más con secundaria completa exitosamente!
# 1.0% de los registros en Población de 15 años y más sin instrucción posprimaria son N/D
# Se omitieron los registros erroneos en Población de 15 años y más sin instrucción posprimaria exitosamente!
# 1.0% de los registros en Población de 15 años y más con instrucción secundaria o estudios técnicos o comerciales con primaria terminada son N/D
# Se omitieron los registros erroneos en Población de 15 años y más con instrucción secundaria o estudios técnicos o comerciales con primaria terminada exitosamente!
# 1.0% de los registros en Población de 15 años y más con instrucción media superior o superior son N/D
# Se omitieron los registros erroneos en Población de 15 años y más con instrucción media superior o superior exitosamente!
# 1.0% de los registros en Población de 18 años y más sin instrucción media superior son N/D
# Se omitieron los registros erroneos en Población de 18 años y más sin instrucción media superior exitosamente!
# 1.0% de los registros en Población de 18 años y más con instrucción media superior son N/D
# Se omitieron los registros erroneos en Población de 18 años y más con instrucción media superior exitosamente!
# 1.0% de los registros en Población de 18 años y más con instrucción superior son N/D
# Se omitieron los registros erroneos en Población de 18 años y más con instrucción superior exitosamente!
# [['Grado promedio de escolaridad', 'N/D'],
#  ['Longitud', ', LA (R'],
#  ['Población de 0 a 4 años', 'N/D'],
#  ['Población de 5 años y más', 'N/D'],
#  ['Población de 6 a 14 años', 'N/D'],
#  ['Población de 12 años y más', 'N/D'],
#  ['Población de 15 años y más', 'N/D'],
#  ['Población de 15 a 17 años', 'N/D'],
#  ['Población de 15 a 24 años', 'N/D'],
#  ['Po blación femenina de 15 a 49 años', 'N/D'],
#  ['Población de 18 años y más', 'N/D'],
#  ['Población masculina de 18 años y más', 'N/D'],
#  ['Población femenina de 18 años y más', 'N/D'],
#  ['Población de 6 a 14 años que sabe leer y escribir', 'N/D'],
#  ['Población de 6 a 14 años que no sabe leer y escribir', 'N/D'],
#  ['Población de 15 años y más alfabeta', 'N/D'],
#  ['Población de 15 años y más analfabeta', 'N/D'],
#  ['Población de 5 años que asiste a la escuela', 'N/D'],
#  ['Población de 5 años que no asiste a la escuela', 'N/D'],
#  ['Población de 6 a 14 años que asiste a la escuela', 'N/D'],
#  ['Población de 6 a 14 años que no asiste a la escuela', 'N/D'],
#  ['Población de 15 a 17 años que asiste a la escuela', 'N/D'],
#  ['Población de 15 a 24 años que asiste a la escuela', 'N/D'],
#  ['Población de 15 a 24 años que no asiste a la escuela', 'N/D'],
#  ['Población de 15 años y más sin instrucción', 'N/D'],
#  ['Población de 15 años y más con primaria incompleta', 'N/D'],
#  ['Población de 15 años y más con primaria completa', 'N/D'],
#  ['Población de 15 años y más con instrucción posprimaria', 'N/D'],
#  ['Población de 15 años y más con secundaria incompleta', 'N/D'],
#  ['Población de 15 años y más con secundaria completa', 'N/D'],
#  ['Población de 15 años y más sin instrucción posprimaria', 'N/D'],
#  ['Población de 15 años y más con instrucción secundaria o estudios técnicos o comerciales con primaria terminada',
#   'N/D'],
#  ['Población de 15 años y más con instrucción media superior o superior',
#   'N/D'],
#  ['Población de 18 años y más sin instrucción media superior', 'N/D'],
#  ['Población de 18 años y más con instrucción media superior', 'N/D'],
#  ['Población de 18 años y más con instrucción superior', 'N/D']]

# %% [markdown]
# ## 2005

# %%
df=dataframes[0]
dictionary_df=diccionarios_de_datos[0]

# %%
columns=[
       'Entidad Federativa',
       'Clave del Municipio',
       'Municipio',
       'Clave de Localidad',
       'Localidad', 'Longitud', 'Latitud', 'Altitud', 
       'Población total','Población masculina', 'Población femenina',
       # Columnas relacionadas con la educacion
       'Población de 8 a 14 años que no sabe leer y escribir',
       'Población masculina de 8 a 14 años que no sabe leer y escribir',
       'Población femenina de 8 a 14 años que no sabe leer y escribir',
       'Población de 15 años y más analfabeta',
       'Población masculina de 15 años y más analfabeta',
       'Población femenina de 15 años y más analfabeta',
       'Población de 5 años que no asiste a la escuela',
       'Población masculina de 5 años que no asiste a la escuela',
       'Población femenina de 5 años que no asiste a la escuela',
       'Población de 6 a 11 años que no asiste a la escuela',
       'Población de 6 a 14 años que no asiste a la escuela',
       'Población masculina de 6 a 14 años que no asiste a la escuela',
       'Población femenina de 6 a 14 años que no asiste a la escuela',
       'Población de 12 a 14 años que no asiste a la escuela',
       'Población de 15 a 24 años que asiste a la escuela',
       'Población masculina de 15 a 24 años que asiste a la escuela',
       'Población femenina de 15 a 24 años que asiste a la escuela',
       'Población de 15 años y más sin escolaridad',
       'Población masculina de 15 años y más sin escolaridad',
       'Población femenina de 15 años y más sin escolaridad',
       'Población de 15 años y más con educación básica incompleta',
       'Población masculina de 15 años y más con educación básica incompleta',
       'Población femenina de 15 años y más con educación básica incompleta',
       'Población de 15 años y más con educación básica completa',
       'Población masculina de 15 años y más con educación básica completa',
       'Población femenina de 15 años y más con educación básica completa',
       'Población de 15 años y más con educación posbásica',
       'Población masculina de 15 años y más con educación posbásica',
       'Población femenina de 15 años y más con educación posbásica',
       'Grado promedio de escolaridad',
       'Grado promedio de escolaridad de la población masculina',
       'Grado promedio de escolaridad de la población femenina',
         ]

string_columns=[
       'Entidad Federativa',
       'Clave del Municipio',
       'Municipio',
       'Clave de Localidad',
       'Localidad',
]
float_columns=[
    'Longitud', 'Latitud', 'Altitud',
    'Grado promedio de escolaridad',
    'Grado promedio de escolaridad de la población masculina',
    'Grado promedio de escolaridad de la población femenina',

]

integer_columns=[
       'Población total','Población masculina', 'Población femenina',
       'Población de 8 a 14 años que no sabe leer y escribir',
       'Población masculina de 8 a 14 años que no sabe leer y escribir',
       'Población femenina de 8 a 14 años que no sabe leer y escribir',
       'Población de 15 años y más analfabeta',
       'Población masculina de 15 años y más analfabeta',
       'Población femenina de 15 años y más analfabeta',
       'Población de 5 años que no asiste a la escuela',
       'Población masculina de 5 años que no asiste a la escuela',
       'Población femenina de 5 años que no asiste a la escuela',
       'Población de 6 a 11 años que no asiste a la escuela',
       'Población de 6 a 14 años que no asiste a la escuela',
       'Población masculina de 6 a 14 años que no asiste a la escuela',
       'Población femenina de 6 a 14 años que no asiste a la escuela',
       'Población de 12 a 14 años que no asiste a la escuela',
       'Población de 15 a 24 años que asiste a la escuela',
       'Población masculina de 15 a 24 años que asiste a la escuela',
       'Población femenina de 15 a 24 años que asiste a la escuela',
       'Población de 15 años y más sin escolaridad',
       'Población masculina de 15 años y más sin escolaridad',
       'Población femenina de 15 años y más sin escolaridad',
       'Población de 15 años y más con educación básica incompleta',
       'Población masculina de 15 años y más con educación básica incompleta',
       'Población femenina de 15 años y más con educación básica incompleta',
       'Población de 15 años y más con educación básica completa',
       'Población masculina de 15 años y más con educación básica completa',
       'Población femenina de 15 años y más con educación básica completa',
       'Población de 15 años y más con educación posbásica',
       'Población masculina de 15 años y más con educación posbásica',
       'Población femenina de 15 años y más con educación posbásica',
    
]

format_columns={
    'string_columns':string_columns,
    'float_columns':float_columns,
    'integer_columns':integer_columns
}

# %%
df=filtro_columnas(df,dictionary_df,columns)

# %%
revision_nulos(df)
# Out:
# 3.2405% de los registros en Longitud son nulos
# 3.2405% de los registros en Latitud son nulos
# 3.2389% de los registros en Altitud son nulos

# %%
formato_columnas(df,format_columns)
# Out:
# 43.0% de los registros en Grado promedio de escolaridad son *
# Se omitieron los registros erroneos en Grado promedio de escolaridad exitosamente!
# 43.0% de los registros en Grado promedio de escolaridad de la población masculina son *
# Se omitieron los registros erroneos en Grado promedio de escolaridad de la población masculina exitosamente!
# 43.0% de los registros en Grado promedio de escolaridad de la población femenina son *
# Se omitieron los registros erroneos en Grado promedio de escolaridad de la población femenina exitosamente!
# 43.0% de los registros en Población masculina son *
# Se omitieron los registros erroneos en Población masculina exitosamente!
# 43.0% de los registros en Población femenina son *
# Se omitieron los registros erroneos en Población femenina exitosamente!
# 43.0% de los registros en Población de 8 a 14 años que no sabe leer y escribir son *
# Se omitieron los registros erroneos en Población de 8 a 14 años que no sabe leer y escribir exitosamente!
# 43.0% de los registros en Población masculina de 8 a 14 años que no sabe leer y escribir son *
# Se omitieron los registros erroneos en Población masculina de 8 a 14 años que no sabe leer y escribir exitosamente!
# 43.0% de los registros en Población femenina de 8 a 14 años que no sabe leer y escribir son *
# Se omitieron los registros erroneos en Población femenina de 8 a 14 años que no sabe leer y escribir exitosamente!
# 43.0% de los registros en Población de 15 años y más analfabeta son *
# Se omitieron los registros erroneos en Población de 15 años y más analfabeta exitosamente!
# 43.0% de los registros en Población masculina de 15 años y más analfabeta son *
# Se omitieron los registros erroneos en Población masculina de 15 años y más analfabeta exitosamente!
# 43.0% de los registros en Población femenina de 15 años y más analfabeta son *
# Se omitieron los registros erroneos en Población femenina de 15 años y más analfabeta exitosamente!
# 43.0% de los registros en Población de 5 años que no asiste a la escuela son *
# Se omitieron los registros erroneos en Población de 5 años que no asiste a la escuela exitosamente!
# 43.0% de los registros en Población masculina de 5 años que no asiste a la escuela son *
# Se omitieron los registros erroneos en Población masculina de 5 años que no asiste a la escuela exitosamente!
# 43.0% de los registros en Población femenina de 5 años que no asiste a la escuela son *
# Se omitieron los registros erroneos en Población femenina de 5 años que no asiste a la escuela exitosamente!
# 43.0% de los registros en Población de 6 a 11 años que no asiste a la escuela son *
# Se omitieron los registros erroneos en Población de 6 a 11 años que no asiste a la escuela exitosamente!
# 43.0% de los registros en Población de 6 a 14 años que no asiste a la escuela son *
# Se omitieron los registros erroneos en Población de 6 a 14 años que no asiste a la escuela exitosamente!
# 43.0% de los registros en Población masculina de 6 a 14 años que no asiste a la escuela son *
# Se omitieron los registros erroneos en Población masculina de 6 a 14 años que no asiste a la escuela exitosamente!
# 43.0% de los registros en Población femenina de 6 a 14 años que no asiste a la escuela son *
# Se omitieron los registros erroneos en Población femenina de 6 a 14 años que no asiste a la escuela exitosamente!
# 43.0% de los registros en Población de 12 a 14 años que no asiste a la escuela son *
# Se omitieron los registros erroneos en Población de 12 a 14 años que no asiste a la escuela exitosamente!
# 43.0% de los registros en Población de 15 a 24 años que asiste a la escuela son *
# Se omitieron los registros erroneos en Población de 15 a 24 años que asiste a la escuela exitosamente!
# 43.0% de los registros en Población masculina de 15 a 24 años que asiste a la escuela son *
# Se omitieron los registros erroneos en Población masculina de 15 a 24 años que asiste a la escuela exitosamente!
# 43.0% de los registros en Población femenina de 15 a 24 años que asiste a la escuela son *
# Se omitieron los registros erroneos en Población femenina de 15 a 24 años que asiste a la escuela exitosamente!
# 43.0% de los registros en Población de 15 años y más sin escolaridad son *
# Se omitieron los registros erroneos en Población de 15 años y más sin escolaridad exitosamente!
# 43.0% de los registros en Población masculina de 15 años y más sin escolaridad son *
# Se omitieron los registros erroneos en Población masculina de 15 años y más sin escolaridad exitosamente!
# 43.0% de los registros en Población femenina de 15 años y más sin escolaridad son *
# Se omitieron los registros erroneos en Población femenina de 15 años y más sin escolaridad exitosamente!
# 43.0% de los registros en Población de 15 años y más con educación básica incompleta son *
# Se omitieron los registros erroneos en Población de 15 años y más con educación básica incompleta exitosamente!
# 43.0% de los registros en Población masculina de 15 años y más con educación básica incompleta son *
# Se omitieron los registros erroneos en Población masculina de 15 años y más con educación básica incompleta exitosamente!
# 43.0% de los registros en Población femenina de 15 años y más con educación básica incompleta son *
# Se omitieron los registros erroneos en Población femenina de 15 años y más con educación básica incompleta exitosamente!
# 43.0% de los registros en Población de 15 años y más con educación básica completa son *
# Se omitieron los registros erroneos en Población de 15 años y más con educación básica completa exitosamente!
# 43.0% de los registros en Población masculina de 15 años y más con educación básica completa son *
# Se omitieron los registros erroneos en Población masculina de 15 años y más con educación básica completa exitosamente!
# 43.0% de los registros en Población femenina de 15 años y más con educación básica completa son *
# Se omitieron los registros erroneos en Población femenina de 15 años y más con educación básica completa exitosamente!
# 43.0% de los registros en Población de 15 años y más con educación posbásica son *
# Se omitieron los registros erroneos en Población de 15 años y más con educación posbásica exitosamente!
# 43.0% de los registros en Población masculina de 15 años y más con educación posbásica son *
# Se omitieron los registros erroneos en Población masculina de 15 años y más con educación posbásica exitosamente!
# 43.0% de los registros en Población femenina de 15 años y más con educación posbásica son *
# Se omitieron los registros erroneos en Población femenina de 15 años y más con educación posbásica exitosamente!
# [['Grado promedio de escolaridad', '*'],
#  ['Grado promedio de escolaridad de la población masculina', '*'],
#  ['Grado promedio de escolaridad de la población femenina', '*'],
#  ['Población masculina', '*'],
#  ['Población femenina', '*'],
#  ['Población de 8 a 14 años que no sabe leer y escribir', '*'],
#  ['Población masculina de 8 a 14 años que no sabe leer y escribir', '*'],
#  ['Población femenina de 8 a 14 años que no sabe leer y escribir', '*'],
#  ['Población de 15 años y más analfabeta', '*'],
#  ['Población masculina de 15 años y más analfabeta', '*'],
#  ['Población femenina de 15 años y más analfabeta', '*'],
#  ['Población de 5 años que no asiste a la escuela', '*'],
#  ['Población masculina de 5 años que no asiste a la escuela', '*'],
#  ['Población femenina de 5 años que no asiste a la escuela', '*'],
#  ['Población de 6 a 11 años que no asiste a la escuela', '*'],
#  ['Población de 6 a 14 años que no asiste a la escuela', '*'],
#  ['Población masculina de 6 a 14 años que no asiste a la escuela', '*'],
#  ['Población femenina de 6 a 14 años que no asiste a la escuela', '*'],
#  ['Población de 12 a 14 años que no asiste a la escuela', '*'],
#  ['Población de 15 a 24 años que asiste a la escuela', '*'],
#  ['Población masculina de 15 a 24 años que asiste a la escuela', '*'],
#  ['Población femenina de 15 a 24 años que asiste a la escuela', '*'],
#  ['Población de 15 años y más sin escolaridad', '*'],
#  ['Población masculina de 15 años y más sin escolaridad', '*'],
#  ['Población femenina de 15 años y más sin escolaridad', '*'],
#  ['Población de 15 años y más con educación básica incompleta', '*'],
#  ['Población masculina de 15 años y más con educación básica incompleta', '*'],
#  ['Población femenina de 15 años y más con educación básica incompleta', '*'],
#  ['Población de 15 años y más con educación básica completa', '*'],
#  ['Población masculina de 15 años y más con educación básica completa', '*'],
#  ['Población femenina de 15 años y más con educación básica completa', '*'],
#  ['Población de 15 años y más con educación posbásica', '*'],
#  ['Población masculina de 15 años y más con educación posbásica', '*'],
#  ['Población femenina de 15 años y más con educación posbásica', '*']]

# %%
df=df[~(df['Grado promedio de escolaridad']=='*')]

# %%
formato_columnas(df,format_columns)
# Out:
# 0.0% de los registros en Grado promedio de escolaridad de la población masculina son *
# Se omitieron los registros erroneos en Grado promedio de escolaridad de la población masculina exitosamente!
# 0.0% de los registros en Grado promedio de escolaridad de la población femenina son *
# Se omitieron los registros erroneos en Grado promedio de escolaridad de la población femenina exitosamente!
# [['Grado promedio de escolaridad de la población masculina', '*'],
#  ['Grado promedio de escolaridad de la población femenina', '*']]

# %%
df
# Out:
#        Entidad Federativa Clave del Municipio  \
# 0          Total nacional                   0
# 1          Total nacional                   0
# 2          Total nacional                   0
# 3          Aguascalientes                   0
# 4          Aguascalientes                   0
# ...                   ...                 ...
# 194224          Zacatecas                  58
# 194225          Zacatecas                  58
# 194226          Zacatecas                  58
# 194228          Zacatecas                  58
# 194230          Zacatecas                  58
#
#                                  Municipio Clave de Localidad  \
# 0                           Total nacional                  0
# 1                           Total nacional               9998
# 2                           Total nacional               9999
# 3       Total de la entidad Aguascalientes                  0
# 4       Total de la entidad Aguascalientes               9998
# ...                                    ...                ...
# 194224               Santa María de la Paz                 33
# 194225               Santa María de la Paz                 35
# 194226               Santa María de la Paz                 37
# 194228               Santa María de la Paz                 41
# 194230               Santa María de la Paz               9998
#
#                               Localidad   Longitud   Latitud  Altitud  \
# 0                        Total nacional        NaN       NaN      0.0
# 1           Localidades de una vivienda        NaN       NaN      0.0
# 2          Localidades de dos viviendas        NaN       NaN      0.0
# 3                   Total de la Entidad        NaN       NaN      NaN
# 4           Localidades de una vivienda        NaN       NaN      NaN
# ...                                 ...        ...       ...      ...
# 194224                     Los Horcones  1031604.0  212958.0   2100.0
# 194225  Los Trigos (Mesa de los Trigos)  1031355.0  212946.0   2500.0
# 194226                      Mesa Grande  1032458.0  213304.0   1940.0
# 194228            San Miguel Tepetitlán  1032007.0  213014.0   2000.0
# 194230      Localidades de una vivienda        NaN       NaN      NaN
#
#         Población total  Población masculina  ...  \
# 0             103263388             50249955  ...
# 1                275182               159663  ...
# 2                179318                97802  ...
# 3               1065416               515364  ...
# 4                  3729                 2062  ...
# ...                 ...                  ...  ...
# 194224               30                   17  ...
# 194225              116                   62  ...
# 194226              179                   84  ...
# 194228               89                   46  ...
# 194230               28                   14  ...
#
#         Población femenina de 15 años y más con educación básica incompleta  \
# 0                                                13418938
# 1                                                   40959
# 2                                                   28161
# 3                                                  136707
# 4                                                     557
# ...                                                   ...
# 194224                                                  8
# 194225                                                 26
# 194226                                                 34
# 194228                                                 20
# 194230                                                  5
#
#         Población de 15 años y más con educación básica completa  \
# 0                                                14533348
# 1                                                   25287
# 2                                                   15411
# 3                                                  161719
# 4                                                     445
# ...                                                   ...
# 194224                                                  0
# 194225                                                 19
# 194226                                                 23
# 194228                                                 20
# 194230                                                  6
#
#         Población masculina de 15 años y más con educación básica completa  \
# 0                                                 7179086
# 1                                                   15889
# 2                                                    8980
# 3                                                   77324
# 4                                                     260
# ...                                                   ...
# 194224                                                  0
# 194225                                                 12
# 194226                                                  7
# 194228                                                  8
# 194230                                                  1
#
#         Población femenina de 15 años y más con educación básica completa  \
# 0                                                 7354262
# 1                                                    9398
# 2                                                    6431
# 3                                                   84395
# 4                                                     185
# ...                                                   ...
# 194224                                                  0
# 194225                                                  7
# 194226                                                 16
# 194228                                                 12
# 194230                                                  5
#
#         Población de 15 años y más con educación posbásica  \
# 0                                                22063108
# 1                                                   19344
# 2                                                   11006
# 3                                                  234587
# 4                                                     419
# ...                                                   ...
# 194224                                                  0
# 194225                                                  3
# 194226                                                  7
# 194228                                                  5
# 194230                                                  2
#
#         Población masculina de 15 años y más con educación posbásica  \
# 0                                                10900960
# 1                                                   12098
# 2                                                    6639
# 3                                                  113444
# 4                                                     247
# ...                                                   ...
# 194224                                                  0
# 194225                                                  1
# 194226                                                  3
# 194228                                                  3
# 194230                                                  1
#
#         Población femenina de 15 años y más con educación posbásica  \
# 0                                                11162148
# 1                                                    7246
# 2                                                    4367
# 3                                                  121143
# 4                                                     172
# ...                                                   ...
# 194224                                                  0
# 194225                                                  2
# 194226                                                  4
# 194228                                                  2
# 194230                                                  1
#
#         Grado promedio de escolaridad  \
# 0                                8.14
# 1                                4.98
# 2                                4.81
# 3                                8.70
# 4                                6.16
# ...                               ...
# 194224                           3.62
# 194225                           5.53
# 194226                           5.26
# 194228                           5.62
# 194230                           5.12
#
#         Grado promedio de escolaridad de la población masculina  \
# 0                                                    8.37
# 1                                                    5.11
# 2                                                    4.98
# 3                                                    8.84
# 4                                                    6.16
# ...                                                   ...
# 194224                                               3.55
# 194225                                               5.69
# 194226                                               4.98
# 194228                                               5.49
# 194230                                               4.64
#
#         Grado promedio de escolaridad de la población femenina
# 0                                                    7.93
# 1                                                    4.79
# 2                                                    4.60
# 3                                                    8.58
# 4                                                    6.15
# ...                                                   ...
# 194224                                               3.70
# 194225                                               5.34
# 194226                                               5.49
# 194228                                               5.76
# 194230                                               5.50
#
# [109965 rows x 43 columns]

# %% [markdown]
# ## 2010

# %%
df=dataframes[4]
dictionary_df=diccionarios_de_datos[2]

# %%
columns=[
       'Clave de entidad federativa',
 'Entidad federativa',
 'Clave de municipio ó delegación',
 'Municipio ó delegación',
 'Clave de localidad',
 'Localidad',
 'Longitud',
 'Latitud',
 'Altitud',
 'Población total',
 'Población masculina',
 'Población femenina',
 'Población de 0 a 2 años ',
 'Población masculina de 0 a 2 años',
 'Población femenina de 0 a 2 años',
 'Población de  3 años y más',
 'Población masculina de 3 años y más',
 'Población femenina de 3 años y más',
 'Población de  5 años y más',
 'Población masculina de 5 años y más',
 'Población femenina de 5 años y más',
 'Población de 12 años y más',
 'Población masculina de 12 años y más',
 'Población femenina de 12 años y más',
 'Población de 15 años y más',
 'Población masculina de 15 años y más',
 'Población femenina de 15 años y más',
 'Población de 18 años y más',
 'Población masculina de 18 años y más',
 'Población femenina de 18 años y más',
 'Población de 3 a 5 años',
 'Población masculina de 3 a 5 años',
 'Población femenina de 3 a 5 años',
 'Población de 6 a 11 años',
 'Población masculina de 6 a 11 años',
 'Población femenina de 6 a 11 años',
 'Población de 8 a 14 años',
 'Población masculina de 8 a 14 años',
 'Población femenina de 8 a 14 años',
 'Población de 12 a 14 años',
 'Población masculina de 12 a 14 años',
 'Población femenina de 12 a 14 años',
 'Población de 15 a 17 años',
 'Población masculina de 15 a 17 años',
 'Población femenina de 15 a 17 años',
 'Población de 18 a 24 años',
 'Población masculina de 18 a 24 años',
 'Población femenina de 18 a 24 años',
 'Población femenina de 15 a 49 años\xa0',
 'Población de 60 años y más',
 'Población masculina de 60 años y más',
 'Población femenina de 60 años y más',
 'Relación hombres-mujeres',
 'Población de cero a 14 años',
 'Población de 15 a 64 años',
 'Población con limitación en la actividad',
 'Población con limitación para caminar o moverse, subir o bajar',
 'Población con limitación para ver, aún usando lentes',
 'Población con limitación para hablar, comunicarse o conversar',
 'Población con limitación para escuchar',
 'Población con limitación para vestirse, bañarse o comer',
 'Población con limitación para poner atención o aprender cosas sencillas',
 'Población con limitación mental',
 'Población sin limitación en la actividad',
 'Población de 3 a 5 años que no asiste a la escuela ',
 'Población masculina de 3 a 5 años que no asiste a la escuela ',
 'Población femenina de 3 a 5 años que no asiste a la escuela ',
 'Población de 6 a 11 años que no asiste a la escuela',
 'Población masculina de 6 a 11 años que no asiste a la escuela',
 'Población femenina de 6 a 11 años que no asiste a la escuela',
 'Población de 12 a 14 años que no asiste a la escuela',
 'Población masculina de 12 a 14 años que no asiste a la escuela',
 'Población femenina de 12 a 14 años que no asiste a la escuela',
 'Población de 15 a 17 años que asiste a la escuela',
 'Población masculina de 15 a 17 años que asiste a la escuela',
 'Población femenina de 15 a 17 años que asiste a la escuela',
 'Población de 18 a 24 años que asiste a la escuela',
 'Población masculina de 18 a 24 años que asiste a la escuela',
 'Población femenina de 18 a 24 años que asiste a la escuela',
 'Población de 8 a 14 años que no saben leer y escribir',
 'Población masculina de 8 a 14 años que no saben leer y escribir',
 'Población femenina  de 8 a 14 años que no saben leer y escribir',
 'Población de 15 años y más analfabeta',
 'Población masculina de 15 años y más analfabeta',
 'Población femenina de 15 años y más analfabeta',
 'Población de 15 años y más sin escolaridad',
 'Población masculina de 15 años y más sin escolaridad',
 'Población femenina de 15 años y más sin escolaridad',
 'Población de 15 años y más con primaria incompleta',
 'Población masculina de 15 años y más con primaria incompleta',
 'Población femenina de 15 años y más con primaria incompleta',
 'Población de 15 años y más con primaria completa',
 'Población masculina de 15 años y más con primaria completa',
 'Población femenina de 15 años y más con primaria completa',
 'Población de 15 años y más con secundaria incompleta',
 'Población masculina de 15 años y más con secundaria incompleta',
 'Población femenina de 15 años y más con secundaria incompleta',
 'Población de 15 años y más con secundaria completa',
 'Población masculina de 15 años y más con secundaria completa',
 'Población femenina de 15 años y más con secundaria completa',
 'Población de 18 años y más con educación pos-básica',
 'Población masculina de 18 años y más con educación pos-básica',
 'Población femenina de 18 años y más con educación pos-básica',
 'Grado promedio de escolaridad',
 'Grado promedio de escolaridad de la población masculina',
 'Grado promedio de escolaridad de la población femenina',
       
         ]

string_columns=[
    'Clave de entidad federativa',
 'Entidad federativa',
 'Clave de municipio ó delegación',
 'Municipio ó delegación',
 'Clave de localidad',
 'Localidad',
     
]
float_columns=[
 'Longitud',
 'Latitud',
 'Altitud',
 'Grado promedio de escolaridad',
 'Grado promedio de escolaridad de la población masculina',
 'Grado promedio de escolaridad de la población femenina',
    
    

]

integer_columns=[
     'Población total',
 'Población masculina',
 'Población femenina',
 'Población de 0 a 2 años ',
 'Población masculina de 0 a 2 años',
 'Población femenina de 0 a 2 años',
 'Población de  3 años y más',
 'Población masculina de 3 años y más',
 'Población femenina de 3 años y más',
 'Población de  5 años y más',
 'Población masculina de 5 años y más',
 'Población femenina de 5 años y más',
 'Población de 12 años y más',
 'Población masculina de 12 años y más',
 'Población femenina de 12 años y más',
 'Población de 15 años y más',
 'Población masculina de 15 años y más',
 'Población femenina de 15 años y más',
 'Población de 18 años y más',
 'Población masculina de 18 años y más',
 'Población femenina de 18 años y más',
 'Población de 3 a 5 años',
 'Población masculina de 3 a 5 años',
 'Población femenina de 3 a 5 años',
 'Población de 6 a 11 años',
 'Población masculina de 6 a 11 años',
 'Población femenina de 6 a 11 años',
 'Población de 8 a 14 años',
 'Población masculina de 8 a 14 años',
 'Población femenina de 8 a 14 años',
 'Población de 12 a 14 años',
 'Población masculina de 12 a 14 años',
 'Población femenina de 12 a 14 años',
 'Población de 15 a 17 años',
 'Población masculina de 15 a 17 años',
 'Población femenina de 15 a 17 años',
 'Población de 18 a 24 años',
 'Población masculina de 18 a 24 años',
 'Población femenina de 18 a 24 años',
 'Población femenina de 15 a 49 años\xa0',
 'Población de 60 años y más',
 'Población masculina de 60 años y más',
 'Población femenina de 60 años y más',
 'Relación hombres-mujeres',
 'Población de cero a 14 años',
 'Población de 15 a 64 años',
 'Población con limitación en la actividad',
 'Población con limitación para caminar o moverse, subir o bajar',
 'Población con limitación para ver, aún usando lentes',
 'Población con limitación para hablar, comunicarse o conversar',
 'Población con limitación para escuchar',
 'Población con limitación para vestirse, bañarse o comer',
 'Población con limitación para poner atención o aprender cosas sencillas',
 'Población con limitación mental',
 'Población sin limitación en la actividad',
 'Población de 3 a 5 años que no asiste a la escuela ',
 'Población masculina de 3 a 5 años que no asiste a la escuela ',
 'Población femenina de 3 a 5 años que no asiste a la escuela ',
 'Población de 6 a 11 años que no asiste a la escuela',
 'Población masculina de 6 a 11 años que no asiste a la escuela',
 'Población femenina de 6 a 11 años que no asiste a la escuela',
 'Población de 12 a 14 años que no asiste a la escuela',
 'Población masculina de 12 a 14 años que no asiste a la escuela',
 'Población femenina de 12 a 14 años que no asiste a la escuela',
 'Población de 15 a 17 años que asiste a la escuela',
 'Población masculina de 15 a 17 años que asiste a la escuela',
 'Población femenina de 15 a 17 años que asiste a la escuela',
 'Población de 18 a 24 años que asiste a la escuela',
 'Población masculina de 18 a 24 años que asiste a la escuela',
 'Población femenina de 18 a 24 años que asiste a la escuela',
 'Población de 8 a 14 años que no saben leer y escribir',
 'Población masculina de 8 a 14 años que no saben leer y escribir',
 'Población femenina  de 8 a 14 años que no saben leer y escribir',
 'Población de 15 años y más analfabeta',
 'Población masculina de 15 años y más analfabeta',
 'Población femenina de 15 años y más analfabeta',
 'Población de 15 años y más sin escolaridad',
 'Población masculina de 15 años y más sin escolaridad',
 'Población femenina de 15 años y más sin escolaridad',
 'Población de 15 años y más con primaria incompleta',
 'Población masculina de 15 años y más con primaria incompleta',
 'Población femenina de 15 años y más con primaria incompleta',
 'Población de 15 años y más con primaria completa',
 'Población masculina de 15 años y más con primaria completa',
 'Población femenina de 15 años y más con primaria completa',
 'Población de 15 años y más con secundaria incompleta',
 'Población masculina de 15 años y más con secundaria incompleta',
 'Población femenina de 15 años y más con secundaria incompleta',
 'Población de 15 años y más con secundaria completa',
 'Población masculina de 15 años y más con secundaria completa',
 'Población femenina de 15 años y más con secundaria completa',
 'Población de 18 años y más con educación pos-básica',
 'Población masculina de 18 años y más con educación pos-básica',
 'Población femenina de 18 años y más con educación pos-básica',
]

format_columns={
    'string_columns':string_columns,
    'float_columns':float_columns,
    'integer_columns':integer_columns
}

# %%
dictionary_df['mnemonico'][1]='nom_ent'
dictionary_df['mnemonico'][3]='nom_mun'
dictionary_df['mnemonico'][5]='nom_loc'
dictionary_df['mnemonico'][6]='longitud'
dictionary_df['mnemonico'][18]='p_5ymas'
dictionary_df['mnemonico'][100]='p15a17a'
dictionary_df['mnemonico'][103]='p18a24a'
dictionary_df['mnemonico'][131]='graproes_m'
dictionary_df['mnemonico'][146]='pder_ss'
dictionary_df['mnemonico'][147]='pder_imss'
dictionary_df['mnemonico'][180]='vph_3ymasc'
dictionary_df['mnemonico'][195]='vph_pc'
# Out:
# /var/folders/m5/26l5nfs54r94_664jm4k6zvr0000gn/T/ipykernel_10840/2613084681.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dictionary_df['mnemonico'][1]='nom_ent'
# /var/folders/m5/26l5nfs54r94_664jm4k6zvr0000gn/T/ipykernel_10840/2613084681.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dictionary_df['mnemonico'][3]='nom_mun'
# /var/folders/m5/26l5nfs54r94_664jm4k6zvr0000gn/T/ipykernel_10840/2613084681.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dictionary_df['mnemonico'][5]='nom_loc'
# /var/folders/m5/26l5nfs54r94_664jm4k6zvr0000gn/T/ipykernel_10840/2613084681.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dictionary_df['mnemonico'][6]='longitud'
# /var/folders/m5/26l5nfs54r94_664jm4k6zvr0000gn/T/ipykernel_10840/2613084681.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dictionary_df['mnemonico'][18]='p_5ymas'
# /var/folders/m5/26l5nfs54r94_664jm4k6zvr0000gn/T/ipykernel_10840/2613084681.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dictionary_df['mnemonico'][100]='p15a17a'
# /var/folders/m5/26l5nfs54r94_664jm4k6zvr0000gn/T/ipykernel_10840/2613084681.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dictionary_df['mnemonico'][103]='p18a24a'
# /var/folders/m5/26l5nfs54r94_664jm4k6zvr0000gn/T/ipykernel_10840/2613084681.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dictionary_df['mnemonico'][131]='graproes_m'
# /var/folders/m5/26l5nfs54r94_664jm4k6zvr0000gn/T/ipykernel_10840/2613084681.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dictionary_df['mnemonico'][146]='pder_ss'
# /var/folders/m5/26l5nfs54r94_664jm4k6zvr0000gn/T/ipykernel_10840/2613084681.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dictionary_df['mnemonico'][147]='pder_imss'
# /var/folders/m5/26l5nfs54r94_664jm4k6zvr0000gn/T/ipykernel_10840/2613084681.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dictionary_df['mnemonico'][180]='vph_3ymasc'
# /var/folders/m5/26l5nfs54r94_664jm4k6zvr0000gn/T/ipykernel_10840/2613084681.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dictionary_df['mnemonico'][195]='vph_pc'

# %%
df=filtro_columnas(df,dictionary_df,columns)

# %%
formato_columnas(df,format_columns)
# Out:
# 44.0% de los registros en Grado promedio de escolaridad son *
# Se omitieron los registros erroneos en Grado promedio de escolaridad exitosamente!
# 44.0% de los registros en Grado promedio de escolaridad de la población masculina son *
# Se omitieron los registros erroneos en Grado promedio de escolaridad de la población masculina exitosamente!
# 44.0% de los registros en Grado promedio de escolaridad de la población femenina son *
# Se omitieron los registros erroneos en Grado promedio de escolaridad de la población femenina exitosamente!
# 43.0% de los registros en Población masculina son *
# Se omitieron los registros erroneos en Población masculina exitosamente!
# 43.0% de los registros en Población femenina son *
# Se omitieron los registros erroneos en Población femenina exitosamente!
# 43.0% de los registros en Población de 0 a 2 años  son *
# Se omitieron los registros erroneos en Población de 0 a 2 años  exitosamente!
# 43.0% de los registros en Población masculina de 0 a 2 años son *
# Se omitieron los registros erroneos en Población masculina de 0 a 2 años exitosamente!
# 43.0% de los registros en Población femenina de 0 a 2 años son *
# Se omitieron los registros erroneos en Población femenina de 0 a 2 años exitosamente!
# 43.0% de los registros en Población de  3 años y más son *
# Se omitieron los registros erroneos en Población de  3 años y más exitosamente!
# 43.0% de los registros en Población masculina de 3 años y más son *
# Se omitieron los registros erroneos en Población masculina de 3 años y más exitosamente!
# 43.0% de los registros en Población femenina de 3 años y más son *
# Se omitieron los registros erroneos en Población femenina de 3 años y más exitosamente!
# 43.0% de los registros en Población de  5 años y más son *
# Se omitieron los registros erroneos en Población de  5 años y más exitosamente!
# 43.0% de los registros en Población masculina de 5 años y más son *
# Se omitieron los registros erroneos en Población masculina de 5 años y más exitosamente!
# 43.0% de los registros en Población femenina de 5 años y más son *
# Se omitieron los registros erroneos en Población femenina de 5 años y más exitosamente!
# 43.0% de los registros en Población de 12 años y más son *
# Se omitieron los registros erroneos en Población de 12 años y más exitosamente!
# 43.0% de los registros en Población masculina de 12 años y más son *
# Se omitieron los registros erroneos en Población masculina de 12 años y más exitosamente!
# 43.0% de los registros en Población femenina de 12 años y más son *
# Se omitieron los registros erroneos en Población femenina de 12 años y más exitosamente!
# 43.0% de los registros en Población de 15 años y más son *
# Se omitieron los registros erroneos en Población de 15 años y más exitosamente!
# 43.0% de los registros en Población masculina de 15 años y más son *
# Se omitieron los registros erroneos en Población masculina de 15 años y más exitosamente!
# 43.0% de los registros en Población femenina de 15 años y más son *
# Se omitieron los registros erroneos en Población femenina de 15 años y más exitosamente!
# 43.0% de los registros en Población de 18 años y más son *
# Se omitieron los registros erroneos en Población de 18 años y más exitosamente!
# 43.0% de los registros en Población masculina de 18 años y más son *
# Se omitieron los registros erroneos en Población masculina de 18 años y más exitosamente!
# 43.0% de los registros en Población femenina de 18 años y más son *
# Se omitieron los registros erroneos en Población femenina de 18 años y más exitosamente!
# 43.0% de los registros en Población de 3 a 5 años son *
# Se omitieron los registros erroneos en Población de 3 a 5 años exitosamente!
# 43.0% de los registros en Población masculina de 3 a 5 años son *
# Se omitieron los registros erroneos en Población masculina de 3 a 5 años exitosamente!
# 43.0% de los registros en Población femenina de 3 a 5 años son *
# Se omitieron los registros erroneos en Población femenina de 3 a 5 años exitosamente!
# 43.0% de los registros en Población de 6 a 11 años son *
# Se omitieron los registros erroneos en Población de 6 a 11 años exitosamente!
# 43.0% de los registros en Población masculina de 6 a 11 años son *
# Se omitieron los registros erroneos en Población masculina de 6 a 11 años exitosamente!
# 43.0% de los registros en Población femenina de 6 a 11 años son *
# Se omitieron los registros erroneos en Población femenina de 6 a 11 años exitosamente!
# 43.0% de los registros en Población de 8 a 14 años son *
# Se omitieron los registros erroneos en Población de 8 a 14 años exitosamente!
# 43.0% de los registros en Población masculina de 8 a 14 años son *
# Se omitieron los registros erroneos en Población masculina de 8 a 14 años exitosamente!
# 43.0% de los registros en Población femenina de 8 a 14 años son *
# Se omitieron los registros erroneos en Población femenina de 8 a 14 años exitosamente!
# 43.0% de los registros en Población de 12 a 14 años son *
# Se omitieron los registros erroneos en Población de 12 a 14 años exitosamente!
# 43.0% de los registros en Población masculina de 12 a 14 años son *
# Se omitieron los registros erroneos en Población masculina de 12 a 14 años exitosamente!
# 43.0% de los registros en Población femenina de 12 a 14 años son *
# Se omitieron los registros erroneos en Población femenina de 12 a 14 años exitosamente!
# 43.0% de los registros en Población de 15 a 17 años son *
# Se omitieron los registros erroneos en Población de 15 a 17 años exitosamente!
# 43.0% de los registros en Población masculina de 15 a 17 años son *
# Se omitieron los registros erroneos en Población masculina de 15 a 17 años exitosamente!
# 43.0% de los registros en Población femenina de 15 a 17 años son *
# Se omitieron los registros erroneos en Población femenina de 15 a 17 años exitosamente!
# 43.0% de los registros en Población de 18 a 24 años son *
# Se omitieron los registros erroneos en Población de 18 a 24 años exitosamente!
# 43.0% de los registros en Población masculina de 18 a 24 años son *
# Se omitieron los registros erroneos en Población masculina de 18 a 24 años exitosamente!
# 43.0% de los registros en Población femenina de 18 a 24 años son *
# Se omitieron los registros erroneos en Población femenina de 18 a 24 años exitosamente!
# 43.0% de los registros en Población femenina de 15 a 49 años  son *
# Se omitieron los registros erroneos en Población femenina de 15 a 49 años  exitosamente!
# 43.0% de los registros en Población de 60 años y más son *
# Se omitieron los registros erroneos en Población de 60 años y más exitosamente!
# 43.0% de los registros en Población masculina de 60 años y más son *
# Se omitieron los registros erroneos en Población masculina de 60 años y más exitosamente!
# 43.0% de los registros en Población femenina de 60 años y más son *
# Se omitieron los registros erroneos en Población femenina de 60 años y más exitosamente!
# 0.0% de los registros en Relación hombres-mujeres son 95.43
# Se omitieron los registros erroneos en Relación hombres-mujeres exitosamente!
# 43.0% de los registros en Población de cero a 14 años son *
# Se omitieron los registros erroneos en Población de cero a 14 años exitosamente!
# 43.0% de los registros en Población de 15 a 64 años son *
# Se omitieron los registros erroneos en Población de 15 a 64 años exitosamente!
# 43.0% de los registros en Población con limitación en la actividad son *
# Se omitieron los registros erroneos en Población con limitación en la actividad exitosamente!
# 43.0% de los registros en Población con limitación para caminar o moverse, subir o bajar son *
# Se omitieron los registros erroneos en Población con limitación para caminar o moverse, subir o bajar exitosamente!
# 43.0% de los registros en Población con limitación para ver, aún usando lentes son *
# Se omitieron los registros erroneos en Población con limitación para ver, aún usando lentes exitosamente!
# 43.0% de los registros en Población con limitación para hablar, comunicarse o conversar son *
# Se omitieron los registros erroneos en Población con limitación para hablar, comunicarse o conversar exitosamente!
# 43.0% de los registros en Población con limitación para escuchar son *
# Se omitieron los registros erroneos en Población con limitación para escuchar exitosamente!
# 43.0% de los registros en Población con limitación para vestirse, bañarse o comer son *
# Se omitieron los registros erroneos en Población con limitación para vestirse, bañarse o comer exitosamente!
# 43.0% de los registros en Población con limitación para poner atención o aprender cosas sencillas son *
# Se omitieron los registros erroneos en Población con limitación para poner atención o aprender cosas sencillas exitosamente!
# 43.0% de los registros en Población con limitación mental son *
# Se omitieron los registros erroneos en Población con limitación mental exitosamente!
# 43.0% de los registros en Población sin limitación en la actividad son *
# Se omitieron los registros erroneos en Población sin limitación en la actividad exitosamente!
# 43.0% de los registros en Población de 3 a 5 años que no asiste a la escuela  son *
# Se omitieron los registros erroneos en Población de 3 a 5 años que no asiste a la escuela  exitosamente!
# 43.0% de los registros en Población masculina de 3 a 5 años que no asiste a la escuela  son *
# Se omitieron los registros erroneos en Población masculina de 3 a 5 años que no asiste a la escuela  exitosamente!
# 43.0% de los registros en Población femenina de 3 a 5 años que no asiste a la escuela  son *
# Se omitieron los registros erroneos en Población femenina de 3 a 5 años que no asiste a la escuela  exitosamente!
# 43.0% de los registros en Población de 6 a 11 años que no asiste a la escuela son *
# Se omitieron los registros erroneos en Población de 6 a 11 años que no asiste a la escuela exitosamente!
# 43.0% de los registros en Población masculina de 6 a 11 años que no asiste a la escuela son *
# Se omitieron los registros erroneos en Población masculina de 6 a 11 años que no asiste a la escuela exitosamente!
# 43.0% de los registros en Población femenina de 6 a 11 años que no asiste a la escuela son *
# Se omitieron los registros erroneos en Población femenina de 6 a 11 años que no asiste a la escuela exitosamente!
# 43.0% de los registros en Población de 12 a 14 años que no asiste a la escuela son *
# Se omitieron los registros erroneos en Población de 12 a 14 años que no asiste a la escuela exitosamente!
# 43.0% de los registros en Población masculina de 12 a 14 años que no asiste a la escuela son *
# Se omitieron los registros erroneos en Población masculina de 12 a 14 años que no asiste a la escuela exitosamente!
# 43.0% de los registros en Población femenina de 12 a 14 años que no asiste a la escuela son *
# Se omitieron los registros erroneos en Población femenina de 12 a 14 años que no asiste a la escuela exitosamente!
# 43.0% de los registros en Población de 15 a 17 años que asiste a la escuela son *
# Se omitieron los registros erroneos en Población de 15 a 17 años que asiste a la escuela exitosamente!
# 43.0% de los registros en Población masculina de 15 a 17 años que asiste a la escuela son *
# Se omitieron los registros erroneos en Población masculina de 15 a 17 años que asiste a la escuela exitosamente!
# 43.0% de los registros en Población femenina de 15 a 17 años que asiste a la escuela son *
# Se omitieron los registros erroneos en Población femenina de 15 a 17 años que asiste a la escuela exitosamente!
# 43.0% de los registros en Población de 18 a 24 años que asiste a la escuela son *
# Se omitieron los registros erroneos en Población de 18 a 24 años que asiste a la escuela exitosamente!
# 43.0% de los registros en Población masculina de 18 a 24 años que asiste a la escuela son *
# Se omitieron los registros erroneos en Población masculina de 18 a 24 años que asiste a la escuela exitosamente!
# 43.0% de los registros en Población femenina de 18 a 24 años que asiste a la escuela son *
# Se omitieron los registros erroneos en Población femenina de 18 a 24 años que asiste a la escuela exitosamente!
# 43.0% de los registros en Población de 8 a 14 años que no saben leer y escribir son *
# Se omitieron los registros erroneos en Población de 8 a 14 años que no saben leer y escribir exitosamente!
# 43.0% de los registros en Población masculina de 8 a 14 años que no saben leer y escribir son *
# Se omitieron los registros erroneos en Población masculina de 8 a 14 años que no saben leer y escribir exitosamente!
# 43.0% de los registros en Población femenina  de 8 a 14 años que no saben leer y escribir son *
# Se omitieron los registros erroneos en Población femenina  de 8 a 14 años que no saben leer y escribir exitosamente!
# 43.0% de los registros en Población de 15 años y más analfabeta son *
# Se omitieron los registros erroneos en Población de 15 años y más analfabeta exitosamente!
# 43.0% de los registros en Población masculina de 15 años y más analfabeta son *
# Se omitieron los registros erroneos en Población masculina de 15 años y más analfabeta exitosamente!
# 43.0% de los registros en Población femenina de 15 años y más analfabeta son *
# Se omitieron los registros erroneos en Población femenina de 15 años y más analfabeta exitosamente!
# 43.0% de los registros en Población de 15 años y más sin escolaridad son *
# Se omitieron los registros erroneos en Población de 15 años y más sin escolaridad exitosamente!
# 43.0% de los registros en Población masculina de 15 años y más sin escolaridad son *
# Se omitieron los registros erroneos en Población masculina de 15 años y más sin escolaridad exitosamente!
# 43.0% de los registros en Población femenina de 15 años y más sin escolaridad son *
# Se omitieron los registros erroneos en Población femenina de 15 años y más sin escolaridad exitosamente!
# 43.0% de los registros en Población de 15 años y más con primaria incompleta son *
# Se omitieron los registros erroneos en Población de 15 años y más con primaria incompleta exitosamente!
# 43.0% de los registros en Población masculina de 15 años y más con primaria incompleta son *
# Se omitieron los registros erroneos en Población masculina de 15 años y más con primaria incompleta exitosamente!
# 43.0% de los registros en Población femenina de 15 años y más con primaria incompleta son *
# Se omitieron los registros erroneos en Población femenina de 15 años y más con primaria incompleta exitosamente!
# 43.0% de los registros en Población de 15 años y más con primaria completa son *
# Se omitieron los registros erroneos en Población de 15 años y más con primaria completa exitosamente!
# 43.0% de los registros en Población masculina de 15 años y más con primaria completa son *
# Se omitieron los registros erroneos en Población masculina de 15 años y más con primaria completa exitosamente!
# 43.0% de los registros en Población femenina de 15 años y más con primaria completa son *
# Se omitieron los registros erroneos en Población femenina de 15 años y más con primaria completa exitosamente!
# 43.0% de los registros en Población de 15 años y más con secundaria incompleta son *
# Se omitieron los registros erroneos en Población de 15 años y más con secundaria incompleta exitosamente!
# 43.0% de los registros en Población masculina de 15 años y más con secundaria incompleta son *
# Se omitieron los registros erroneos en Población masculina de 15 años y más con secundaria incompleta exitosamente!
# 43.0% de los registros en Población femenina de 15 años y más con secundaria incompleta son *
# Se omitieron los registros erroneos en Población femenina de 15 años y más con secundaria incompleta exitosamente!
# 43.0% de los registros en Población de 15 años y más con secundaria completa son *
# Se omitieron los registros erroneos en Población de 15 años y más con secundaria completa exitosamente!
# 43.0% de los registros en Población masculina de 15 años y más con secundaria completa son *
# Se omitieron los registros erroneos en Población masculina de 15 años y más con secundaria completa exitosamente!
# 43.0% de los registros en Población femenina de 15 años y más con secundaria completa son *
# Se omitieron los registros erroneos en Población femenina de 15 años y más con secundaria completa exitosamente!
# 43.0% de los registros en Población de 18 años y más con educación pos-básica son *
# Se omitieron los registros erroneos en Población de 18 años y más con educación pos-básica exitosamente!
# 43.0% de los registros en Población masculina de 18 años y más con educación pos-básica son *
# Se omitieron los registros erroneos en Población masculina de 18 años y más con educación pos-básica exitosamente!
# 43.0% de los registros en Población femenina de 18 años y más con educación pos-básica son *
# Se omitieron los registros erroneos en Población femenina de 18 años y más con educación pos-básica exitosamente!
# [['Grado promedio de escolaridad', '*'],
#  ['Grado promedio de escolaridad de la población masculina', '*'],
#  ['Grado promedio de escolaridad de la población femenina', '*'],
#  ['Población masculina', '*'],
#  ['Población femenina', '*'],
#  ['Población de 0 a 2 años ', '*'],
#  ['Población masculina de 0 a 2 años', '*'],
#  ['Población femenina de 0 a 2 años', '*'],
#  ['Población de  3 años y más', '*'],
#  ['Población masculina de 3 años y más', '*'],
#  ['Población femenina de 3 años y más', '*'],
#  ['Población de  5 años y más', '*'],
#  ['Población masculina de 5 años y más', '*'],
#  ['Población femenina de 5 años y más', '*'],
#  ['Población de 12 años y más', '*'],
#  ['Población masculina de 12 años y más', '*'],
#  ['Población femenina de 12 años y más', '*'],
#  ['Población de 15 años y más', '*'],
#  ['Población masculina de 15 años y más', '*'],
#  ['Población femenina de 15 años y más', '*'],
#  ['Población de 18 años y más', '*'],
#  ['Población masculina de 18 años y más', '*'],
#  ['Población femenina de 18 años y más', '*'],
#  ['Población de 3 a 5 años', '*'],
#  ['Población masculina de 3 a 5 años', '*'],
#  ['Población femenina de 3 a 5 años', '*'],
#  ['Población de 6 a 11 años', '*'],
#  ['Población masculina de 6 a 11 años', '*'],
#  ['Población femenina de 6 a 11 años', '*'],
#  ['Población de 8 a 14 años', '*'],
#  ['Población masculina de 8 a 14 años', '*'],
#  ['Población femenina de 8 a 14 años', '*'],
#  ['Población de 12 a 14 años', '*'],
#  ['Población masculina de 12 a 14 años', '*'],
#  ['Población femenina de 12 a 14 años', '*'],
#  ['Población de 15 a 17 años', '*'],
#  ['Población masculina de 15 a 17 años', '*'],
#  ['Población femenina de 15 a 17 años', '*'],
#  ['Población de 18 a 24 años', '*'],
#  ['Población masculina de 18 a 24 años', '*'],
#  ['Población femenina de 18 a 24 años', '*'],
#  ['Población femenina de 15 a 49 años\xa0', '*'],
#  ['Población de 60 años y más', '*'],
#  ['Población masculina de 60 años y más', '*'],
#  ['Población femenina de 60 años y más', '*'],
#  ['Relación hombres-mujeres', '95.43'],
#  ['Población de cero a 14 años', '*'],
#  ['Población de 15 a 64 años', '*'],
#  ['Población con limitación en la actividad', '*'],
#  ['Población con limitación para caminar o moverse, subir o bajar', '*'],
#  ['Población con limitación para ver, aún usando lentes', '*'],
#  ['Población con limitación para hablar, comunicarse o conversar', '*'],
#  ['Población con limitación para escuchar', '*'],
#  ['Población con limitación para vestirse, bañarse o comer', '*'],
#  ['Población con limitación para poner atención o aprender cosas sencillas',
#   '*'],
#  ['Población con limitación mental', '*'],
#  ['Población sin limitación en la actividad', '*'],
#  ['Población de 3 a 5 años que no asiste a la escuela ', '*'],
#  ['Población masculina de 3 a 5 años que no asiste a la escuela ', '*'],
#  ['Población femenina de 3 a 5 años que no asiste a la escuela ', '*'],
#  ['Población de 6 a 11 años que no asiste a la escuela', '*'],
#  ['Población masculina de 6 a 11 años que no asiste a la escuela', '*'],
#  ['Población femenina de 6 a 11 años que no asiste a la escuela', '*'],
#  ['Población de 12 a 14 años que no asiste a la escuela', '*'],
#  ['Población masculina de 12 a 14 años que no asiste a la escuela', '*'],
#  ['Población femenina de 12 a 14 años que no asiste a la escuela', '*'],
#  ['Población de 15 a 17 años que asiste a la escuela', '*'],
#  ['Población masculina de 15 a 17 años que asiste a la escuela', '*'],
#  ['Población femenina de 15 a 17 años que asiste a la escuela', '*'],
#  ['Población de 18 a 24 años que asiste a la escuela', '*'],
#  ['Población masculina de 18 a 24 años que asiste a la escuela', '*'],
#  ['Población femenina de 18 a 24 años que asiste a la escuela', '*'],
#  ['Población de 8 a 14 años que no saben leer y escribir', '*'],
#  ['Población masculina de 8 a 14 años que no saben leer y escribir', '*'],
#  ['Población femenina  de 8 a 14 años que no saben leer y escribir', '*'],
#  ['Población de 15 años y más analfabeta', '*'],
#  ['Población masculina de 15 años y más analfabeta', '*'],
#  ['Población femenina de 15 años y más analfabeta', '*'],
#  ['Población de 15 años y más sin escolaridad', '*'],
#  ['Población masculina de 15 años y más sin escolaridad', '*'],
#  ['Población femenina de 15 años y más sin escolaridad', '*'],
#  ['Población de 15 años y más con primaria incompleta', '*'],
#  ['Población masculina de 15 años y más con primaria incompleta', '*'],
#  ['Población femenina de 15 años y más con primaria incompleta', '*'],
#  ['Población de 15 años y más con primaria completa', '*'],
#  ['Población masculina de 15 años y más con primaria completa', '*'],
#  ['Población femenina de 15 años y más con primaria completa', '*'],
#  ['Población de 15 años y más con secundaria incompleta', '*'],
#  ['Población masculina de 15 años y más con secundaria incompleta', '*'],
#  ['Población femenina de 15 años y más con secundaria incompleta', '*'],
#  ['Población de 15 años y más con secundaria completa', '*'],
#  ['Población masculina de 15 años y más con secundaria completa', '*'],
#  ['Población femenina de 15 años y más con secundaria completa', '*'],
#  ['Población de 18 años y más con educación pos-básica', '*'],
#  ['Población masculina de 18 años y más con educación pos-básica', '*'],
#  ['Población femenina de 18 años y más con educación pos-básica', '*']]

# %%
df=df[~(df['Grado promedio de escolaridad']=='*')]

# %%
formato_columnas(df,format_columns)
# Out:
# 0.0% de los registros en Grado promedio de escolaridad son N/D
# Se omitieron los registros erroneos en Grado promedio de escolaridad exitosamente!
# 0.0% de los registros en Grado promedio de escolaridad de la población masculina son N/D
# Se omitieron los registros erroneos en Grado promedio de escolaridad de la población masculina exitosamente!
# 0.0% de los registros en Grado promedio de escolaridad de la población femenina son N/D
# Se omitieron los registros erroneos en Grado promedio de escolaridad de la población femenina exitosamente!
# 0.0% de los registros en Población de 0 a 2 años  son N/D
# Se omitieron los registros erroneos en Población de 0 a 2 años  exitosamente!
# 0.0% de los registros en Población masculina de 0 a 2 años son N/D
# Se omitieron los registros erroneos en Población masculina de 0 a 2 años exitosamente!
# 0.0% de los registros en Población femenina de 0 a 2 años son N/D
# Se omitieron los registros erroneos en Población femenina de 0 a 2 años exitosamente!
# 0.0% de los registros en Población de  3 años y más son N/D
# Se omitieron los registros erroneos en Población de  3 años y más exitosamente!
# 0.0% de los registros en Población masculina de 3 años y más son N/D
# Se omitieron los registros erroneos en Población masculina de 3 años y más exitosamente!
# 0.0% de los registros en Población femenina de 3 años y más son N/D
# Se omitieron los registros erroneos en Población femenina de 3 años y más exitosamente!
# 0.0% de los registros en Población de  5 años y más son N/D
# Se omitieron los registros erroneos en Población de  5 años y más exitosamente!
# 0.0% de los registros en Población masculina de 5 años y más son N/D
# Se omitieron los registros erroneos en Población masculina de 5 años y más exitosamente!
# 0.0% de los registros en Población femenina de 5 años y más son N/D
# Se omitieron los registros erroneos en Población femenina de 5 años y más exitosamente!
# 0.0% de los registros en Población de 12 años y más son N/D
# Se omitieron los registros erroneos en Población de 12 años y más exitosamente!
# 0.0% de los registros en Población masculina de 12 años y más son N/D
# Se omitieron los registros erroneos en Población masculina de 12 años y más exitosamente!
# 0.0% de los registros en Población femenina de 12 años y más son N/D
# Se omitieron los registros erroneos en Población femenina de 12 años y más exitosamente!
# 0.0% de los registros en Población de 15 años y más son N/D
# Se omitieron los registros erroneos en Población de 15 años y más exitosamente!
# 0.0% de los registros en Población masculina de 15 años y más son N/D
# Se omitieron los registros erroneos en Población masculina de 15 años y más exitosamente!
# 0.0% de los registros en Población femenina de 15 años y más son N/D
# Se omitieron los registros erroneos en Población femenina de 15 años y más exitosamente!
# 0.0% de los registros en Población de 18 años y más son N/D
# Se omitieron los registros erroneos en Población de 18 años y más exitosamente!
# 0.0% de los registros en Población masculina de 18 años y más son N/D
# Se omitieron los registros erroneos en Población masculina de 18 años y más exitosamente!
# 0.0% de los registros en Población femenina de 18 años y más son N/D
# Se omitieron los registros erroneos en Población femenina de 18 años y más exitosamente!
# 0.0% de los registros en Población de 3 a 5 años son N/D
# Se omitieron los registros erroneos en Población de 3 a 5 años exitosamente!
# 0.0% de los registros en Población masculina de 3 a 5 años son N/D
# Se omitieron los registros erroneos en Población masculina de 3 a 5 años exitosamente!
# 0.0% de los registros en Población femenina de 3 a 5 años son N/D
# Se omitieron los registros erroneos en Población femenina de 3 a 5 años exitosamente!
# 0.0% de los registros en Población de 6 a 11 años son N/D
# Se omitieron los registros erroneos en Población de 6 a 11 años exitosamente!
# 0.0% de los registros en Población masculina de 6 a 11 años son N/D
# Se omitieron los registros erroneos en Población masculina de 6 a 11 años exitosamente!
# 0.0% de los registros en Población femenina de 6 a 11 años son N/D
# Se omitieron los registros erroneos en Población femenina de 6 a 11 años exitosamente!
# 0.0% de los registros en Población de 8 a 14 años son N/D
# Se omitieron los registros erroneos en Población de 8 a 14 años exitosamente!
# 0.0% de los registros en Población masculina de 8 a 14 años son N/D
# Se omitieron los registros erroneos en Población masculina de 8 a 14 años exitosamente!
# 0.0% de los registros en Población femenina de 8 a 14 años son N/D
# Se omitieron los registros erroneos en Población femenina de 8 a 14 años exitosamente!
# 0.0% de los registros en Población de 12 a 14 años son N/D
# Se omitieron los registros erroneos en Población de 12 a 14 años exitosamente!
# 0.0% de los registros en Población masculina de 12 a 14 años son N/D
# Se omitieron los registros erroneos en Población masculina de 12 a 14 años exitosamente!
# 0.0% de los registros en Población femenina de 12 a 14 años son N/D
# Se omitieron los registros erroneos en Población femenina de 12 a 14 años exitosamente!
# 0.0% de los registros en Población de 15 a 17 años son N/D
# Se omitieron los registros erroneos en Población de 15 a 17 años exitosamente!
# 0.0% de los registros en Población masculina de 15 a 17 años son N/D
# Se omitieron los registros erroneos en Población masculina de 15 a 17 años exitosamente!
# 0.0% de los registros en Población femenina de 15 a 17 años son N/D
# Se omitieron los registros erroneos en Población femenina de 15 a 17 años exitosamente!
# 0.0% de los registros en Población de 18 a 24 años son N/D
# Se omitieron los registros erroneos en Población de 18 a 24 años exitosamente!
# 0.0% de los registros en Población masculina de 18 a 24 años son N/D
# Se omitieron los registros erroneos en Población masculina de 18 a 24 años exitosamente!
# 0.0% de los registros en Población femenina de 18 a 24 años son N/D
# Se omitieron los registros erroneos en Población femenina de 18 a 24 años exitosamente!
# 0.0% de los registros en Población femenina de 15 a 49 años  son N/D
# Se omitieron los registros erroneos en Población femenina de 15 a 49 años  exitosamente!
# 0.0% de los registros en Población de 60 años y más son N/D
# Se omitieron los registros erroneos en Población de 60 años y más exitosamente!
# 0.0% de los registros en Población masculina de 60 años y más son N/D
# Se omitieron los registros erroneos en Población masculina de 60 años y más exitosamente!
# 0.0% de los registros en Población femenina de 60 años y más son N/D
# Se omitieron los registros erroneos en Población femenina de 60 años y más exitosamente!
# 0.0% de los registros en Relación hombres-mujeres son 95.43
# Se omitieron los registros erroneos en Relación hombres-mujeres exitosamente!
# 0.0% de los registros en Población de cero a 14 años son N/D
# Se omitieron los registros erroneos en Población de cero a 14 años exitosamente!
# 0.0% de los registros en Población de 15 a 64 años son N/D
# Se omitieron los registros erroneos en Población de 15 a 64 años exitosamente!
# 0.0% de los registros en Población con limitación en la actividad son N/D
# Se omitieron los registros erroneos en Población con limitación en la actividad exitosamente!
# 0.0% de los registros en Población con limitación para caminar o moverse, subir o bajar son N/D
# Se omitieron los registros erroneos en Población con limitación para caminar o moverse, subir o bajar exitosamente!
# 0.0% de los registros en Población con limitación para ver, aún usando lentes son N/D
# Se omitieron los registros erroneos en Población con limitación para ver, aún usando lentes exitosamente!
# 0.0% de los registros en Población con limitación para hablar, comunicarse o conversar son N/D
# Se omitieron los registros erroneos en Población con limitación para hablar, comunicarse o conversar exitosamente!
# 0.0% de los registros en Población con limitación para escuchar son N/D
# Se omitieron los registros erroneos en Población con limitación para escuchar exitosamente!
# 0.0% de los registros en Población con limitación para vestirse, bañarse o comer son N/D
# Se omitieron los registros erroneos en Población con limitación para vestirse, bañarse o comer exitosamente!
# 0.0% de los registros en Población con limitación para poner atención o aprender cosas sencillas son N/D
# Se omitieron los registros erroneos en Población con limitación para poner atención o aprender cosas sencillas exitosamente!
# 0.0% de los registros en Población con limitación mental son N/D
# Se omitieron los registros erroneos en Población con limitación mental exitosamente!
# 0.0% de los registros en Población sin limitación en la actividad son N/D
# Se omitieron los registros erroneos en Población sin limitación en la actividad exitosamente!
# 0.0% de los registros en Población de 3 a 5 años que no asiste a la escuela  son N/D
# Se omitieron los registros erroneos en Población de 3 a 5 años que no asiste a la escuela  exitosamente!
# 0.0% de los registros en Población masculina de 3 a 5 años que no asiste a la escuela  son N/D
# Se omitieron los registros erroneos en Población masculina de 3 a 5 años que no asiste a la escuela  exitosamente!
# 0.0% de los registros en Población femenina de 3 a 5 años que no asiste a la escuela  son N/D
# Se omitieron los registros erroneos en Población femenina de 3 a 5 años que no asiste a la escuela  exitosamente!
# 0.0% de los registros en Población de 6 a 11 años que no asiste a la escuela son N/D
# Se omitieron los registros erroneos en Población de 6 a 11 años que no asiste a la escuela exitosamente!
# 0.0% de los registros en Población masculina de 6 a 11 años que no asiste a la escuela son N/D
# Se omitieron los registros erroneos en Población masculina de 6 a 11 años que no asiste a la escuela exitosamente!
# 0.0% de los registros en Población femenina de 6 a 11 años que no asiste a la escuela son N/D
# Se omitieron los registros erroneos en Población femenina de 6 a 11 años que no asiste a la escuela exitosamente!
# 0.0% de los registros en Población de 12 a 14 años que no asiste a la escuela son N/D
# Se omitieron los registros erroneos en Población de 12 a 14 años que no asiste a la escuela exitosamente!
# 0.0% de los registros en Población masculina de 12 a 14 años que no asiste a la escuela son N/D
# Se omitieron los registros erroneos en Población masculina de 12 a 14 años que no asiste a la escuela exitosamente!
# 0.0% de los registros en Población femenina de 12 a 14 años que no asiste a la escuela son N/D
# Se omitieron los registros erroneos en Población femenina de 12 a 14 años que no asiste a la escuela exitosamente!
# 0.0% de los registros en Población de 15 a 17 años que asiste a la escuela son N/D
# Se omitieron los registros erroneos en Población de 15 a 17 años que asiste a la escuela exitosamente!
# 0.0% de los registros en Población masculina de 15 a 17 años que asiste a la escuela son N/D
# Se omitieron los registros erroneos en Población masculina de 15 a 17 años que asiste a la escuela exitosamente!
# 0.0% de los registros en Población femenina de 15 a 17 años que asiste a la escuela son N/D
# Se omitieron los registros erroneos en Población femenina de 15 a 17 años que asiste a la escuela exitosamente!
# 0.0% de los registros en Población de 18 a 24 años que asiste a la escuela son N/D
# Se omitieron los registros erroneos en Población de 18 a 24 años que asiste a la escuela exitosamente!
# 0.0% de los registros en Población masculina de 18 a 24 años que asiste a la escuela son N/D
# Se omitieron los registros erroneos en Población masculina de 18 a 24 años que asiste a la escuela exitosamente!
# 0.0% de los registros en Población femenina de 18 a 24 años que asiste a la escuela son N/D
# Se omitieron los registros erroneos en Población femenina de 18 a 24 años que asiste a la escuela exitosamente!
# 0.0% de los registros en Población de 8 a 14 años que no saben leer y escribir son N/D
# Se omitieron los registros erroneos en Población de 8 a 14 años que no saben leer y escribir exitosamente!
# 0.0% de los registros en Población masculina de 8 a 14 años que no saben leer y escribir son N/D
# Se omitieron los registros erroneos en Población masculina de 8 a 14 años que no saben leer y escribir exitosamente!
# 0.0% de los registros en Población femenina  de 8 a 14 años que no saben leer y escribir son N/D
# Se omitieron los registros erroneos en Población femenina  de 8 a 14 años que no saben leer y escribir exitosamente!
# 0.0% de los registros en Población de 15 años y más analfabeta son N/D
# Se omitieron los registros erroneos en Población de 15 años y más analfabeta exitosamente!
# 0.0% de los registros en Población masculina de 15 años y más analfabeta son N/D
# Se omitieron los registros erroneos en Población masculina de 15 años y más analfabeta exitosamente!
# 0.0% de los registros en Población femenina de 15 años y más analfabeta son N/D
# Se omitieron los registros erroneos en Población femenina de 15 años y más analfabeta exitosamente!
# 0.0% de los registros en Población de 15 años y más sin escolaridad son N/D
# Se omitieron los registros erroneos en Población de 15 años y más sin escolaridad exitosamente!
# 0.0% de los registros en Población masculina de 15 años y más sin escolaridad son N/D
# Se omitieron los registros erroneos en Población masculina de 15 años y más sin escolaridad exitosamente!
# 0.0% de los registros en Población femenina de 15 años y más sin escolaridad son N/D
# Se omitieron los registros erroneos en Población femenina de 15 años y más sin escolaridad exitosamente!
# 0.0% de los registros en Población de 15 años y más con primaria incompleta son N/D
# Se omitieron los registros erroneos en Población de 15 años y más con primaria incompleta exitosamente!
# 0.0% de los registros en Población masculina de 15 años y más con primaria incompleta son N/D
# Se omitieron los registros erroneos en Población masculina de 15 años y más con primaria incompleta exitosamente!
# 0.0% de los registros en Población femenina de 15 años y más con primaria incompleta son N/D
# Se omitieron los registros erroneos en Población femenina de 15 años y más con primaria incompleta exitosamente!
# 0.0% de los registros en Población de 15 años y más con primaria completa son N/D
# Se omitieron los registros erroneos en Población de 15 años y más con primaria completa exitosamente!
# 0.0% de los registros en Población masculina de 15 años y más con primaria completa son N/D
# Se omitieron los registros erroneos en Población masculina de 15 años y más con primaria completa exitosamente!
# 0.0% de los registros en Población femenina de 15 años y más con primaria completa son N/D
# Se omitieron los registros erroneos en Población femenina de 15 años y más con primaria completa exitosamente!
# 0.0% de los registros en Población de 15 años y más con secundaria incompleta son N/D
# Se omitieron los registros erroneos en Población de 15 años y más con secundaria incompleta exitosamente!
# 0.0% de los registros en Población masculina de 15 años y más con secundaria incompleta son N/D
# Se omitieron los registros erroneos en Población masculina de 15 años y más con secundaria incompleta exitosamente!
# 0.0% de los registros en Población femenina de 15 años y más con secundaria incompleta son N/D
# Se omitieron los registros erroneos en Población femenina de 15 años y más con secundaria incompleta exitosamente!
# 0.0% de los registros en Población de 15 años y más con secundaria completa son N/D
# Se omitieron los registros erroneos en Población de 15 años y más con secundaria completa exitosamente!
# 0.0% de los registros en Población masculina de 15 años y más con secundaria completa son N/D
# Se omitieron los registros erroneos en Población masculina de 15 años y más con secundaria completa exitosamente!
# 0.0% de los registros en Población femenina de 15 años y más con secundaria completa son N/D
# Se omitieron los registros erroneos en Población femenina de 15 años y más con secundaria completa exitosamente!
# 0.0% de los registros en Población de 18 años y más con educación pos-básica son N/D
# Se omitieron los registros erroneos en Población de 18 años y más con educación pos-básica exitosamente!
# 0.0% de los registros en Población masculina de 18 años y más con educación pos-básica son N/D
# Se omitieron los registros erroneos en Población masculina de 18 años y más con educación pos-básica exitosamente!
# 0.0% de los registros en Población femenina de 18 años y más con educación pos-básica son N/D
# Se omitieron los registros erroneos en Población femenina de 18 años y más con educación pos-básica exitosamente!
# [['Grado promedio de escolaridad', 'N/D'],
#  ['Grado promedio de escolaridad de la población masculina', 'N/D'],
#  ['Grado promedio de escolaridad de la población femenina', 'N/D'],
#  ['Población de 0 a 2 años ', 'N/D'],
#  ['Población masculina de 0 a 2 años', 'N/D'],
#  ['Población femenina de 0 a 2 años', 'N/D'],
#  ['Población de  3 años y más', 'N/D'],
#  ['Población masculina de 3 años y más', 'N/D'],
#  ['Población femenina de 3 años y más', 'N/D'],
#  ['Población de  5 años y más', 'N/D'],
#  ['Población masculina de 5 años y más', 'N/D'],
#  ['Población femenina de 5 años y más', 'N/D'],
#  ['Población de 12 años y más', 'N/D'],
#  ['Población masculina de 12 años y más', 'N/D'],
#  ['Población femenina de 12 años y más', 'N/D'],
#  ['Población de 15 años y más', 'N/D'],
#  ['Población masculina de 15 años y más', 'N/D'],
#  ['Población femenina de 15 años y más', 'N/D'],
#  ['Población de 18 años y más', 'N/D'],
#  ['Población masculina de 18 años y más', 'N/D'],
#  ['Población femenina de 18 años y más', 'N/D'],
#  ['Población de 3 a 5 años', 'N/D'],
#  ['Población masculina de 3 a 5 años', 'N/D'],
#  ['Población femenina de 3 a 5 años', 'N/D'],
#  ['Población de 6 a 11 años', 'N/D'],
#  ['Población masculina de 6 a 11 años', 'N/D'],
#  ['Población femenina de 6 a 11 años', 'N/D'],
#  ['Población de 8 a 14 años', 'N/D'],
#  ['Población masculina de 8 a 14 años', 'N/D'],
#  ['Población femenina de 8 a 14 años', 'N/D'],
#  ['Población de 12 a 14 años', 'N/D'],
#  ['Población masculina de 12 a 14 años', 'N/D'],
#  ['Población femenina de 12 a 14 años', 'N/D'],
#  ['Población de 15 a 17 años', 'N/D'],
#  ['Población masculina de 15 a 17 años', 'N/D'],
#  ['Población femenina de 15 a 17 años', 'N/D'],
#  ['Población de 18 a 24 años', 'N/D'],
#  ['Población masculina de 18 a 24 años', 'N/D'],
#  ['Población femenina de 18 a 24 años', 'N/D'],
#  ['Población femenina de 15 a 49 años\xa0', 'N/D'],
#  ['Población de 60 años y más', 'N/D'],
#  ['Población masculina de 60 años y más', 'N/D'],
#  ['Población femenina de 60 años y más', 'N/D'],
#  ['Relación hombres-mujeres', '95.43'],
#  ['Población de cero a 14 años', 'N/D'],
#  ['Población de 15 a 64 años', 'N/D'],
#  ['Población con limitación en la actividad', 'N/D'],
#  ['Población con limitación para caminar o moverse, subir o bajar', 'N/D'],
#  ['Población con limitación para ver, aún usando lentes', 'N/D'],
#  ['Población con limitación para hablar, comunicarse o conversar', 'N/D'],
#  ['Población con limitación para escuchar', 'N/D'],
#  ['Población con limitación para vestirse, bañarse o comer', 'N/D'],
#  ['Población con limitación para poner atención o aprender cosas sencillas',
#   'N/D'],
#  ['Población con limitación mental', 'N/D'],
#  ['Población sin limitación en la actividad', 'N/D'],
#  ['Población de 3 a 5 años que no asiste a la escuela ', 'N/D'],
#  ['Población masculina de 3 a 5 años que no asiste a la escuela ', 'N/D'],
#  ['Población femenina de 3 a 5 años que no asiste a la escuela ', 'N/D'],
#  ['Población de 6 a 11 años que no asiste a la escuela', 'N/D'],
#  ['Población masculina de 6 a 11 años que no asiste a la escuela', 'N/D'],
#  ['Población femenina de 6 a 11 años que no asiste a la escuela', 'N/D'],
#  ['Población de 12 a 14 años que no asiste a la escuela', 'N/D'],
#  ['Población masculina de 12 a 14 años que no asiste a la escuela', 'N/D'],
#  ['Población femenina de 12 a 14 años que no asiste a la escuela', 'N/D'],
#  ['Población de 15 a 17 años que asiste a la escuela', 'N/D'],
#  ['Población masculina de 15 a 17 años que asiste a la escuela', 'N/D'],
#  ['Población femenina de 15 a 17 años que asiste a la escuela', 'N/D'],
#  ['Población de 18 a 24 años que asiste a la escuela', 'N/D'],
#  ['Población masculina de 18 a 24 años que asiste a la escuela', 'N/D'],
#  ['Población femenina de 18 a 24 años que asiste a la escuela', 'N/D'],
#  ['Población de 8 a 14 años que no saben leer y escribir', 'N/D'],
#  ['Población masculina de 8 a 14 años que no saben leer y escribir', 'N/D'],
#  ['Población femenina  de 8 a 14 años que no saben leer y escribir', 'N/D'],
#  ['Población de 15 años y más analfabeta', 'N/D'],
#  ['Población masculina de 15 años y más analfabeta', 'N/D'],
#  ['Población femenina de 15 años y más analfabeta', 'N/D'],
#  ['Población de 15 años y más sin escolaridad', 'N/D'],
#  ['Población masculina de 15 años y más sin escolaridad', 'N/D'],
#  ['Población femenina de 15 años y más sin escolaridad', 'N/D'],
#  ['Población de 15 años y más con primaria incompleta', 'N/D'],
#  ['Población masculina de 15 años y más con primaria incompleta', 'N/D'],
#  ['Población femenina de 15 años y más con primaria incompleta', 'N/D'],
#  ['Población de 15 años y más con primaria completa', 'N/D'],
#  ['Población masculina de 15 años y más con primaria completa', 'N/D'],
#  ['Población femenina de 15 años y más con primaria completa', 'N/D'],
#  ['Población de 15 años y más con secundaria incompleta', 'N/D'],
#  ['Población masculina de 15 años y más con secundaria incompleta', 'N/D'],
#  ['Población femenina de 15 años y más con secundaria incompleta', 'N/D'],
#  ['Población de 15 años y más con secundaria completa', 'N/D'],
#  ['Población masculina de 15 años y más con secundaria completa', 'N/D'],
#  ['Población femenina de 15 años y más con secundaria completa', 'N/D'],
#  ['Población de 18 años y más con educación pos-básica', 'N/D'],
#  ['Población masculina de 18 años y más con educación pos-básica', 'N/D'],
#  ['Población femenina de 18 años y más con educación pos-básica', 'N/D']]

# %% [markdown]
# ## 2020

# %%
df=dataframes[2]
dictionary_df=diccionarios_de_datos[1]

# %%
rename_columns=dictionary_df.columns.to_list()[:5]

# %%
def fix_encoding(text):
    return text.encode('latin1').decode('utf-8')

for column in rename_columns:
    dictionary_df[column]=dictionary_df[column].astype('str')
    dictionary_df[column]=dictionary_df[column].apply(fix_encoding)

# %%
dictionary_df=dictionary_df.drop([0,1,2])
dictionary_df=dictionary_df.reset_index(drop=True)


dictionary_df.columns=dictionary_df.loc[0]

# %%
dictionary_df=dictionary_df.drop(0)
dictionary_df=dictionary_df.reset_index(drop=True)
dictionary_df=dictionary_df[dictionary_df.columns.to_list()[:6]]

# %%
columns=[
    'Clave de entidad federativa',
 'Entidad federativa',
 'Clave de municipio o demarcación territorial',
 'Municipio o demarcación territorial',
 'Clave de localidad',
 'Localidad',
 'Longitud',
 'Latitud',
 'Altitud',
 'Población total',
 'Población femenina',
 'Población masculina',
 'Población de 0 a 2 años',
 'Población femenina de 0 a 2 años',
 'Población masculina de 0 a 2 años',
 'Población de 3 años y más',
 'Población femenina de 3 años y más',
 'Población masculina de 3 años y más',
 'Población de 5 años y más',
 'Población femenina de 5 años y más',
 'Población masculina de 5 años y más',
 'Población de 12 años y más',
 'Población femenina de 12 años y más',
 'Población masculina de 12 años y más',
 'Población de 15 años y más',
 'Población femenina de 15 años y más',
 'Población masculina de 15 años y más',
 'Población de 18 años y más',
 'Población femenina de 18 años y más',
 'Población masculina de 18 años y más',
 'Población de 3 a 5 años',
 'Población femenina de 3 a 5 años',
 'Población masculina de 3 a 5 años',
 'Población de 6 a 11 años',
 'Población femenina de 6 a 11 años',
 'Población masculina de 6 a 11 años',
 'Población de 8 a 14 años',
 'Población femenina de 8 a 14 años',
 'Población masculina de 8 a 14 años',
 'Población de 12 a 14 años',
 'Población femenina de 12 a 14 años',
 'Población masculina de 12 a 14 años',
 'Población de 15 a 17 años',
 'Población femenina de 15 a 17 años',
 'Población masculina de 15 a 17 años',
 'Población de 18 a 24 años',
 'Población femenina de 18 a 24 años',
 'Población masculina de 18 a 24 años',
 'Población femenina de 15 a 49 años',
 'Población de 60 años y más',
 'Población femenina de 60 años y más',
 'Población masculina de 60 años y más',
 'Relación hombres-mujeres',
 'Población de 0 a 14 años',
 'Población de 15 a 64 años',
 'Población de 65 años y más',
 'Población de 0 a 4 años',
 'Población femenina de 0 a 4 años',
 'Población masculina de 0 a 4 años',
 'Población de 5 a 9 años',
 'Población femenina de 5 a 9 años',
 'Población masculina de 5 a 9 años',
 'Población de 10 a 14 años',
 'Población femenina de 10 a 14 años',
 'Población masculina de 10 a 14 años',
 'Población de 15 a 19 años',
 'Población femenina de 15 a 19 años',
 'Población masculina de 15 a 19 años',
 'Población de 20 a 24 años',
 'Población femenina de 20 a 24 años',
 'Población masculina de 20 a 24 años',
 'Población de 25 a 29 años',
 'Población femenina de 25 a 29 años',
 'Población masculina de 25 a 29 años',
 'Población de 30 a 34 años',
 'Población femenina de 30 a 34 años',
 'Población masculina de 30 a 34 años',
 'Población de 35 a 39 años',
 'Población femenina de 35 a 39 años',
 'Población masculina de 35 a 39 años',
 'Población de 40 a 44 años',
 'Población femenina de 40 a 44 años',
 'Población masculina de 40 a 44 años',
 'Población de 45 a 49 años',
 'Población femenina de 45 a 49 años',
 'Población masculina de 45 a 49 años',
 'Población de 50 a 54 años',
 'Población femenina de 50 a 54 años',
 'Población masculina de 50 a 54 años',
 'Población de 55 a 59 años',
 'Población femenina de 55 a 59 años',
 'Población masculina de 55 a 59 años',
 'Población de 60 a 64 años',
 'Población femenina de 60 a 64 años',
 'Población masculina de 60 a 64 años',
 'Población de 65 a 69 años',
 'Población femenina de 65 a 69 años',
 'Población masculina de 65 a 69 años',
 'Población de 70 a 74 años',
 'Población femenina de 70 a 74 años',
 'Población masculina de 70 a 74 años',
 'Población de 75 a 79 años',



 'Población con discapacidad',
 'Población con discapacidad para hablar o comunicarse',
 'Población con discapacidad para oír, aun usando aparato auditivo',
 'Población con discapacidad para vestirse, bañarse o comer',
 'Población con discapacidad para recordar o concentrarse',
 'Población con limitación',
 'Población con limitación para caminar, subir o bajar',
 'Población con limitación para ver, aun usando lentes',
 'Población con limitación para hablar o comunicarse',
 'Población con limitación para oír, aun usando aparato auditivo',
 'Población con limitación para vestirse, bañarse o comer',
 'Población con limitación para recordar o concentrarse',
 'Población con algún problema o condición mental',
 'Población sin discapacidad, limitación, problema o condición mental',
 'Población de 3 a 5 años que no asiste a la escuela',
 'Población femenina de 3 a 5 años que no asiste a la escuela',
 'Población masculina de 3 a 5 años que no asiste a la escuela',
 'Población de 6 a 11 años que no asiste a la escuela',
 'Población femenina de 6 a 11 años que no asiste a la escuela',
 'Población masculina de 6 a 11 años que no asiste a la escuela',
 'Población de 12 a 14 años que no asiste a la escuela',
 'Población femenina de 12 a 14 años que no asiste a la escuela',
 'Población masculina de 12 a 14 años que no asiste a la escuela',
 'Población de 15 a 17 años que asiste a la escuela',
 'Población femenina de 15 a 17 años que asiste a la escuela',
 'Población masculina de 15 a 17 años que asiste a la escuela',
 'Población de 18 a 24 años que asiste a la escuela',
 'Población femenina de 18 a 24 años que asiste a la escuela',
 'Población masculina de 18 a 24 años que asiste a la escuela',
 'Población de 8 a 14 años que no sabe leer y escribir',
 'Población femenina de 8 a 14 años que no sabe leer y escribir',
 'Población masculina de 8 a 14 años que no sabe leer y escribir',
 'Población de 15 años y más analfabeta',
 'Población femenina de 15 años y más analfabeta',
 'Población masculina de 15 años y más analfabeta',
 'Población de 15 años y más sin escolaridad',
 'Población femenina de 15 años y más sin escolaridad',
 'Población masculina de 15 años y más sin escolaridad',
 'Población de 15 años y más con primaria incompleta',
 'Población femenina de 15 años y más con primaria incompleta',
 'Población masculina de 15 años y más con primaria incompleta',
 'Población de 15 años y más con primaria completa',
 'Población femenina de 15 años y más con primaria completa',
 'Población masculina de 15 años y más con primaria completa',
 'Población de 15 años y más con secundaria incompleta',
 'Población femenina de 15 años y más con secundaria incompleta',
 'Población masculina de 15 años y más con secundaria incompleta',
 'Población de 15 años y más con secundaria completa',
 'Población femenina de 15 años y más con secundaria completa',
 'Población masculina de 15 años y más con secundaria completa',
 'Población de 18 años y más con educación posbásica',
 'Población femenina de 18 años y más con educación posbásica',
 'Población masculina de 18 años y más con educación posbásica',
 'Grado promedio de escolaridad',
 'Grado promedio de escolaridad de la población femenina',
 'Grado promedio de escolaridad de la población masculina',
 'Población de 12 años y más económicamente activa',
 'Población femenina de 12 años y más económicamente activa',
 'Población masculina de 12 años y más económicamente activa',
 'Población de 12 años y más no económicamente activa',
 'Población femenina de 12 años y más no económicamente activa',
 'Población masculina de 12 años y más no económicamente activa',
 'Población de 12 años y más ocupada',
 'Población femenina de 12 años y más ocupada',
 'Población masculina de 12 años y más ocupada',
 'Población de 12 años y más desocupada',
 'Población femenina de 12 años y más desocupada',
 'Población masculina de 12 años y más desocupada',
 

 
       
         ]

string_columns=[
    'Clave de entidad federativa',
 'Entidad federativa',
 'Clave de municipio o demarcación territorial',
 'Municipio o demarcación territorial',
 'Clave de localidad',
 'Localidad',
    
     
]
float_columns=[
    'Longitud',
 'Latitud',
 'Altitud',
    'Relación hombres-mujeres',
    'Grado promedio de escolaridad',
 'Grado promedio de escolaridad de la población femenina',
 'Grado promedio de escolaridad de la población masculina'

    

]

integer_columns=[
    'Población total',
 'Población femenina',
 'Población masculina',
 'Población de 0 a 2 años',
 'Población femenina de 0 a 2 años',
 'Población masculina de 0 a 2 años',
 'Población de 3 años y más',
 'Población femenina de 3 años y más',
 'Población masculina de 3 años y más',
 'Población de 5 años y más',
 'Población femenina de 5 años y más',
 'Población masculina de 5 años y más',
 'Población de 12 años y más',
 'Población femenina de 12 años y más',
 'Población masculina de 12 años y más',
 'Población de 15 años y más',
 'Población femenina de 15 años y más',
 'Población masculina de 15 años y más',
 'Población de 18 años y más',
 'Población femenina de 18 años y más',
 'Población masculina de 18 años y más',
 'Población de 3 a 5 años',
 'Población femenina de 3 a 5 años',
 'Población masculina de 3 a 5 años',
 'Población de 6 a 11 años',
 'Población femenina de 6 a 11 años',
 'Población masculina de 6 a 11 años',
 'Población de 8 a 14 años',
 'Población femenina de 8 a 14 años',
 'Población masculina de 8 a 14 años',
 'Población de 12 a 14 años',
 'Población femenina de 12 a 14 años',
 'Población masculina de 12 a 14 años',
 'Población de 15 a 17 años',
 'Población femenina de 15 a 17 años',
 'Población masculina de 15 a 17 años',
 'Población de 18 a 24 años',
 'Población femenina de 18 a 24 años',
 'Población masculina de 18 a 24 años',
 'Población femenina de 15 a 49 años',
 'Población de 60 años y más',
 'Población femenina de 60 años y más',
 'Población masculina de 60 años y más',
 
 'Población de 0 a 14 años',
 'Población de 15 a 64 años',
 'Población de 65 años y más',
 'Población de 0 a 4 años',
 'Población femenina de 0 a 4 años',
 'Población masculina de 0 a 4 años',
 'Población de 5 a 9 años',
 'Población femenina de 5 a 9 años',
 'Población masculina de 5 a 9 años',
 'Población de 10 a 14 años',
 'Población femenina de 10 a 14 años',
 'Población masculina de 10 a 14 años',
 'Población de 15 a 19 años',
 'Población femenina de 15 a 19 años',
 'Población masculina de 15 a 19 años',
 'Población de 20 a 24 años',
 'Población femenina de 20 a 24 años',
 'Población masculina de 20 a 24 años',
 'Población de 25 a 29 años',
 'Población femenina de 25 a 29 años',
 'Población masculina de 25 a 29 años',
 'Población de 30 a 34 años',
 'Población femenina de 30 a 34 años',
 'Población masculina de 30 a 34 años',
 'Población de 35 a 39 años',
 'Población femenina de 35 a 39 años',
 'Población masculina de 35 a 39 años',
 'Población de 40 a 44 años',
 'Población femenina de 40 a 44 años',
 'Población masculina de 40 a 44 años',
 'Población de 45 a 49 años',
 'Población femenina de 45 a 49 años',
 'Población masculina de 45 a 49 años',
 'Población de 50 a 54 años',
 'Población femenina de 50 a 54 años',
 'Población masculina de 50 a 54 años',
 'Población de 55 a 59 años',
 'Población femenina de 55 a 59 años',
 'Población masculina de 55 a 59 años',
 'Población de 60 a 64 años',
 'Población femenina de 60 a 64 años',
 'Población masculina de 60 a 64 años',
 'Población de 65 a 69 años',
 'Población femenina de 65 a 69 años',
 'Población masculina de 65 a 69 años',
 'Población de 70 a 74 años',
 'Población femenina de 70 a 74 años',
 'Población masculina de 70 a 74 años',
 'Población de 75 a 79 años',
 'Población con discapacidad',
 'Población con discapacidad para hablar o comunicarse',
 'Población con discapacidad para oír, aun usando aparato auditivo',
 'Población con discapacidad para vestirse, bañarse o comer',
 'Población con discapacidad para recordar o concentrarse',
 'Población con limitación',
 'Población con limitación para caminar, subir o bajar',
 'Población con limitación para ver, aun usando lentes',
 'Población con limitación para hablar o comunicarse',
 'Población con limitación para oír, aun usando aparato auditivo',
 'Población con limitación para vestirse, bañarse o comer',
 'Población con limitación para recordar o concentrarse',
 'Población con algún problema o condición mental',
 'Población sin discapacidad, limitación, problema o condición mental',
 'Población de 3 a 5 años que no asiste a la escuela',
 'Población femenina de 3 a 5 años que no asiste a la escuela',
 'Población masculina de 3 a 5 años que no asiste a la escuela',
 'Población de 6 a 11 años que no asiste a la escuela',
 'Población femenina de 6 a 11 años que no asiste a la escuela',
 'Población masculina de 6 a 11 años que no asiste a la escuela',
 'Población de 12 a 14 años que no asiste a la escuela',
 'Población femenina de 12 a 14 años que no asiste a la escuela',
 'Población masculina de 12 a 14 años que no asiste a la escuela',
 'Población de 15 a 17 años que asiste a la escuela',
 'Población femenina de 15 a 17 años que asiste a la escuela',
 'Población masculina de 15 a 17 años que asiste a la escuela',
 'Población de 18 a 24 años que asiste a la escuela',
 'Población femenina de 18 a 24 años que asiste a la escuela',
 'Población masculina de 18 a 24 años que asiste a la escuela',
 'Población de 8 a 14 años que no sabe leer y escribir',
 'Población femenina de 8 a 14 años que no sabe leer y escribir',
 'Población masculina de 8 a 14 años que no sabe leer y escribir',
 'Población de 15 años y más analfabeta',
 'Población femenina de 15 años y más analfabeta',
 'Población masculina de 15 años y más analfabeta',
 'Población de 15 años y más sin escolaridad',
 'Población femenina de 15 años y más sin escolaridad',
 'Población masculina de 15 años y más sin escolaridad',
 'Población de 15 años y más con primaria incompleta',
 'Población femenina de 15 años y más con primaria incompleta',
 'Población masculina de 15 años y más con primaria incompleta',
 'Población de 15 años y más con primaria completa',
 'Población femenina de 15 años y más con primaria completa',
 'Población masculina de 15 años y más con primaria completa',
 'Población de 15 años y más con secundaria incompleta',
 'Población femenina de 15 años y más con secundaria incompleta',
 'Población masculina de 15 años y más con secundaria incompleta',
 'Población de 15 años y más con secundaria completa',
 'Población femenina de 15 años y más con secundaria completa',
 'Población masculina de 15 años y más con secundaria completa',
 'Población de 18 años y más con educación posbásica',
 'Población femenina de 18 años y más con educación posbásica',
 'Población masculina de 18 años y más con educación posbásica',
 'Población de 12 años y más económicamente activa',
 'Población femenina de 12 años y más económicamente activa',
 'Población masculina de 12 años y más económicamente activa',
 'Población de 12 años y más no económicamente activa',
 'Población femenina de 12 años y más no económicamente activa',
 'Población masculina de 12 años y más no económicamente activa',
 'Población de 12 años y más ocupada',
 'Población femenina de 12 años y más ocupada',
 'Población masculina de 12 años y más ocupada',
 'Población de 12 años y más desocupada',
 'Población femenina de 12 años y más desocupada',
 'Población masculina de 12 años y más desocupada',
]

format_columns={
    'string_columns':string_columns,
    'float_columns':float_columns,
    'integer_columns':integer_columns
}

# %%
dictionary_df['Mnemónico'][1]='NOM_ENT'
dictionary_df['Mnemónico'][3]='NOM_MUN'
dictionary_df['Mnemónico'][5]='NOM_LOC'
dictionary_df['Mnemónico'][6]='LONGITUD'
dictionary_df['Indicador'][48]='Población femenina de 15 a 49 años'
# Out:
# /var/folders/m5/26l5nfs54r94_664jm4k6zvr0000gn/T/ipykernel_10840/3695290884.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dictionary_df['Mnemónico'][1]='NOM_ENT'
# /var/folders/m5/26l5nfs54r94_664jm4k6zvr0000gn/T/ipykernel_10840/3695290884.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dictionary_df['Mnemónico'][3]='NOM_MUN'
# /var/folders/m5/26l5nfs54r94_664jm4k6zvr0000gn/T/ipykernel_10840/3695290884.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dictionary_df['Mnemónico'][5]='NOM_LOC'
# /var/folders/m5/26l5nfs54r94_664jm4k6zvr0000gn/T/ipykernel_10840/3695290884.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dictionary_df['Mnemónico'][6]='LONGITUD'
# /var/folders/m5/26l5nfs54r94_664jm4k6zvr0000gn/T/ipykernel_10840/3695290884.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dictionary_df['Indicador'][48]='Población femenina de 15 a 49 años'

# %%
rename_dictionary={}
for index,row in dictionary_df.iterrows():
        old_column_name=row['Mnemónico']
        new_column_name=row['Indicador']
        rename_dictionary[old_column_name] = new_column_name

df=df.rename(columns=rename_dictionary)
df=df[columns]

# %%
revision_nulos(df)
# Out:
# 3.1841% de los registros en Longitud son nulos
# 3.1841% de los registros en Latitud son nulos
# 3.1841% de los registros en Altitud son nulos
# 0.1094% de los registros en Relación hombres-mujeres son nulos

# %%
formato_columnas(df,format_columns)
# Out:
# 0.0% de los registros en Longitud son 102°17\
# 0.0% de los registros en Latitud son 21°52\
# 0.0% de los registros en Altitud son 00-2
# 42.0% de los registros en Relación hombres-mujeres son *
# 42.0% de los registros en Grado promedio de escolaridad son *
# 42.0% de los registros en Grado promedio de escolaridad de la población femenina son *
# 42.0% de los registros en Grado promedio de escolaridad de la población masculina son *
# 42.0% de los registros en Población femenina son *
# 42.0% de los registros en Población masculina son *
# 42.0% de los registros en Población de 0 a 2 años son *
# 42.0% de los registros en Población femenina de 0 a 2 años son *
# 42.0% de los registros en Población masculina de 0 a 2 años son *
# 42.0% de los registros en Población de 3 años y más son *
# 42.0% de los registros en Población femenina de 3 años y más son *
# 42.0% de los registros en Población masculina de 3 años y más son *
# 42.0% de los registros en Población de 5 años y más son *
# 42.0% de los registros en Población femenina de 5 años y más son *
# 42.0% de los registros en Población masculina de 5 años y más son *
# 42.0% de los registros en Población de 12 años y más son *
# 42.0% de los registros en Población femenina de 12 años y más son *
# 42.0% de los registros en Población masculina de 12 años y más son *
# 42.0% de los registros en Población de 15 años y más son *
# 42.0% de los registros en Población femenina de 15 años y más son *
# 42.0% de los registros en Población masculina de 15 años y más son *
# 42.0% de los registros en Población de 18 años y más son *
# 42.0% de los registros en Población femenina de 18 años y más son *
# 42.0% de los registros en Población masculina de 18 años y más son *
# 42.0% de los registros en Población de 3 a 5 años son *
# 42.0% de los registros en Población femenina de 3 a 5 años son *
# 42.0% de los registros en Población masculina de 3 a 5 años son *
# 42.0% de los registros en Población de 6 a 11 años son *
# 42.0% de los registros en Población femenina de 6 a 11 años son *
# 42.0% de los registros en Población masculina de 6 a 11 años son *
# 42.0% de los registros en Población de 8 a 14 años son *
# 42.0% de los registros en Población femenina de 8 a 14 años son *
# 42.0% de los registros en Población masculina de 8 a 14 años son *
# 42.0% de los registros en Población de 12 a 14 años son *
# 42.0% de los registros en Población femenina de 12 a 14 años son *
# 42.0% de los registros en Población masculina de 12 a 14 años son *
# 42.0% de los registros en Población de 15 a 17 años son *
# 42.0% de los registros en Población femenina de 15 a 17 años son *
# 42.0% de los registros en Población masculina de 15 a 17 años son *
# 42.0% de los registros en Población de 18 a 24 años son *
# 42.0% de los registros en Población femenina de 18 a 24 años son *
# 42.0% de los registros en Población masculina de 18 a 24 años son *
# 42.0% de los registros en Población femenina de 15 a 49 años son *
# 42.0% de los registros en Población de 60 años y más son *
# 42.0% de los registros en Población femenina de 60 años y más son *
# 42.0% de los registros en Población masculina de 60 años y más son *
# 42.0% de los registros en Población de 0 a 14 años son *
# 42.0% de los registros en Población de 15 a 64 años son *
# 42.0% de los registros en Población de 65 años y más son *
# 42.0% de los registros en Población de 0 a 4 años son *
# 42.0% de los registros en Población femenina de 0 a 4 años son *
# 42.0% de los registros en Población masculina de 0 a 4 años son *
# 42.0% de los registros en Población de 5 a 9 años son *
# 42.0% de los registros en Población femenina de 5 a 9 años son *
# 42.0% de los registros en Población masculina de 5 a 9 años son *
# 42.0% de los registros en Población de 10 a 14 años son *
# 42.0% de los registros en Población femenina de 10 a 14 años son *
# 42.0% de los registros en Población masculina de 10 a 14 años son *
# 42.0% de los registros en Población de 15 a 19 años son *
# 42.0% de los registros en Población femenina de 15 a 19 años son *
# 42.0% de los registros en Población masculina de 15 a 19 años son *
# 42.0% de los registros en Población de 20 a 24 años son *
# 42.0% de los registros en Población femenina de 20 a 24 años son *
# 42.0% de los registros en Población masculina de 20 a 24 años son *
# 42.0% de los registros en Población de 25 a 29 años son *
# 42.0% de los registros en Población femenina de 25 a 29 años son *
# 42.0% de los registros en Población masculina de 25 a 29 años son *
# 42.0% de los registros en Población de 30 a 34 años son *
# 42.0% de los registros en Población femenina de 30 a 34 años son *
# 42.0% de los registros en Población masculina de 30 a 34 años son *
# 42.0% de los registros en Población de 35 a 39 años son *
# 42.0% de los registros en Población femenina de 35 a 39 años son *
# 42.0% de los registros en Población masculina de 35 a 39 años son *
# 42.0% de los registros en Población de 40 a 44 años son *
# 42.0% de los registros en Población femenina de 40 a 44 años son *
# 42.0% de los registros en Población masculina de 40 a 44 años son *
# 42.0% de los registros en Población de 45 a 49 años son *
# 42.0% de los registros en Población femenina de 45 a 49 años son *
# 42.0% de los registros en Población masculina de 45 a 49 años son *
# 42.0% de los registros en Población de 50 a 54 años son *
# 42.0% de los registros en Población femenina de 50 a 54 años son *
# 42.0% de los registros en Población masculina de 50 a 54 años son *
# 42.0% de los registros en Población de 55 a 59 años son *
# 42.0% de los registros en Población femenina de 55 a 59 años son *
# 42.0% de los registros en Población masculina de 55 a 59 años son *
# 42.0% de los registros en Población de 60 a 64 años son *
# 42.0% de los registros en Población femenina de 60 a 64 años son *
# 42.0% de los registros en Población masculina de 60 a 64 años son *
# 42.0% de los registros en Población de 65 a 69 años son *
# 42.0% de los registros en Población femenina de 65 a 69 años son *
# 42.0% de los registros en Población masculina de 65 a 69 años son *
# 42.0% de los registros en Población de 70 a 74 años son *
# 42.0% de los registros en Población femenina de 70 a 74 años son *
# 42.0% de los registros en Población masculina de 70 a 74 años son *
# 42.0% de los registros en Población de 75 a 79 años son *
# 42.0% de los registros en Población con discapacidad son *
# 42.0% de los registros en Población con discapacidad para hablar o comunicarse son *
# 42.0% de los registros en Población con discapacidad para oír, aun usando aparato auditivo son *
# 42.0% de los registros en Población con discapacidad para vestirse, bañarse o comer son *
# 42.0% de los registros en Población con discapacidad para recordar o concentrarse son *
# 42.0% de los registros en Población con limitación son *
# 42.0% de los registros en Población con limitación para caminar, subir o bajar son *
# 42.0% de los registros en Población con limitación para ver, aun usando lentes son *
# 42.0% de los registros en Población con limitación para hablar o comunicarse son *
# 42.0% de los registros en Población con limitación para oír, aun usando aparato auditivo son *
# 42.0% de los registros en Población con limitación para vestirse, bañarse o comer son *
# 42.0% de los registros en Población con limitación para recordar o concentrarse son *
# 42.0% de los registros en Población con algún problema o condición mental son *
# 42.0% de los registros en Población sin discapacidad, limitación, problema o condición mental son *
# 42.0% de los registros en Población de 3 a 5 años que no asiste a la escuela son *
# 42.0% de los registros en Población femenina de 3 a 5 años que no asiste a la escuela son *
# 42.0% de los registros en Población masculina de 3 a 5 años que no asiste a la escuela son *
# 42.0% de los registros en Población de 6 a 11 años que no asiste a la escuela son *
# 42.0% de los registros en Población femenina de 6 a 11 años que no asiste a la escuela son *
# 42.0% de los registros en Población masculina de 6 a 11 años que no asiste a la escuela son *
# 42.0% de los registros en Población de 12 a 14 años que no asiste a la escuela son *
# 42.0% de los registros en Población femenina de 12 a 14 años que no asiste a la escuela son *
# 42.0% de los registros en Población masculina de 12 a 14 años que no asiste a la escuela son *
# 42.0% de los registros en Población de 15 a 17 años que asiste a la escuela son *
# 42.0% de los registros en Población femenina de 15 a 17 años que asiste a la escuela son *
# 42.0% de los registros en Población masculina de 15 a 17 años que asiste a la escuela son *
# 42.0% de los registros en Población de 18 a 24 años que asiste a la escuela son *
# 42.0% de los registros en Población femenina de 18 a 24 años que asiste a la escuela son *
# 42.0% de los registros en Población masculina de 18 a 24 años que asiste a la escuela son *
# 42.0% de los registros en Población de 8 a 14 años que no sabe leer y escribir son *
# 42.0% de los registros en Población femenina de 8 a 14 años que no sabe leer y escribir son *
# 42.0% de los registros en Población masculina de 8 a 14 años que no sabe leer y escribir son *
# 42.0% de los registros en Población de 15 años y más analfabeta son *
# 42.0% de los registros en Población femenina de 15 años y más analfabeta son *
# 42.0% de los registros en Población masculina de 15 años y más analfabeta son *
# 42.0% de los registros en Población de 15 años y más sin escolaridad son *
# 42.0% de los registros en Población femenina de 15 años y más sin escolaridad son *
# 42.0% de los registros en Población masculina de 15 años y más sin escolaridad son *
# 42.0% de los registros en Población de 15 años y más con primaria incompleta son *
# 42.0% de los registros en Población femenina de 15 años y más con primaria incompleta son *
# 42.0% de los registros en Población masculina de 15 años y más con primaria incompleta son *
# 42.0% de los registros en Población de 15 años y más con primaria completa son *
# 42.0% de los registros en Población femenina de 15 años y más con primaria completa son *
# 42.0% de los registros en Población masculina de 15 años y más con primaria completa son *
# 42.0% de los registros en Población de 15 años y más con secundaria incompleta son *
# 42.0% de los registros en Población femenina de 15 años y más con secundaria incompleta son *
# 42.0% de los registros en Población masculina de 15 años y más con secundaria incompleta son *
# 42.0% de los registros en Población de 15 años y más con secundaria completa son *
# 42.0% de los registros en Población femenina de 15 años y más con secundaria completa son *
# 42.0% de los registros en Población masculina de 15 años y más con secundaria completa son *
# 42.0% de los registros en Población de 18 años y más con educación posbásica son *
# 42.0% de los registros en Población femenina de 18 años y más con educación posbásica son *
# 42.0% de los registros en Población masculina de 18 años y más con educación posbásica son *
# 42.0% de los registros en Población de 12 años y más económicamente activa son *
# 42.0% de los registros en Población femenina de 12 años y más económicamente activa son *
# 42.0% de los registros en Población masculina de 12 años y más económicamente activa son *
# 42.0% de los registros en Población de 12 años y más no económicamente activa son *
# 42.0% de los registros en Población femenina de 12 años y más no económicamente activa son *
# 42.0% de los registros en Población masculina de 12 años y más no económicamente activa son *
# 42.0% de los registros en Población de 12 años y más ocupada son *
# 42.0% de los registros en Población femenina de 12 años y más ocupada son *
# 42.0% de los registros en Población masculina de 12 años y más ocupada son *
# 42.0% de los registros en Población de 12 años y más desocupada son *
# 42.0% de los registros en Población femenina de 12 años y más desocupada son *
# 42.0% de los registros en Población masculina de 12 años y más desocupada son *
# [['Longitud', '102°17\\'],
#  ['Latitud', '21°52\\'],
#  ['Altitud', '00-2'],
#  ['Relación hombres-mujeres', '*'],
#  ['Grado promedio de escolaridad', '*'],
#  ['Grado promedio de escolaridad de la población femenina', '*'],
#  ['Grado promedio de escolaridad de la población masculina', '*'],
#  ['Población femenina', '*'],
#  ['Población masculina', '*'],
#  ['Población de 0 a 2 años', '*'],
#  ['Población femenina de 0 a 2 años', '*'],
#  ['Población masculina de 0 a 2 años', '*'],
#  ['Población de 3 años y más', '*'],
#  ['Población femenina de 3 años y más', '*'],
#  ['Población masculina de 3 años y más', '*'],
#  ['Población de 5 años y más', '*'],
#  ['Población femenina de 5 años y más', '*'],
#  ['Población masculina de 5 años y más', '*'],
#  ['Población de 12 años y más', '*'],
#  ['Población femenina de 12 años y más', '*'],
#  ['Población masculina de 12 años y más', '*'],
#  ['Población de 15 años y más', '*'],
#  ['Población femenina de 15 años y más', '*'],
#  ['Población masculina de 15 años y más', '*'],
#  ['Población de 18 años y más', '*'],
#  ['Población femenina de 18 años y más', '*'],
#  ['Población masculina de 18 años y más', '*'],
#  ['Población de 3 a 5 años', '*'],
#  ['Población femenina de 3 a 5 años', '*'],
#  ['Población masculina de 3 a 5 años', '*'],
#  ['Población de 6 a 11 años', '*'],
#  ['Población femenina de 6 a 11 años', '*'],
#  ['Población masculina de 6 a 11 años', '*'],
#  ['Población de 8 a 14 años', '*'],
#  ['Población femenina de 8 a 14 años', '*'],
#  ['Población masculina de 8 a 14 años', '*'],
#  ['Población de 12 a 14 años', '*'],
#  ['Población femenina de 12 a 14 años', '*'],
#  ['Población masculina de 12 a 14 años', '*'],
#  ['Población de 15 a 17 años', '*'],
#  ['Población femenina de 15 a 17 años', '*'],
#  ['Población masculina de 15 a 17 años', '*'],
#  ['Población de 18 a 24 años', '*'],
#  ['Población femenina de 18 a 24 años', '*'],
#  ['Población masculina de 18 a 24 años', '*'],
#  ['Población femenina de 15 a 49 años', '*'],
#  ['Población de 60 años y más', '*'],
#  ['Población femenina de 60 años y más', '*'],
#  ['Población masculina de 60 años y más', '*'],
#  ['Población de 0 a 14 años', '*'],
#  ['Población de 15 a 64 años', '*'],
#  ['Población de 65 años y más', '*'],
#  ['Población de 0 a 4 años', '*'],
#  ['Población femenina de 0 a 4 años', '*'],
#  ['Población masculina de 0 a 4 años', '*'],
#  ['Población de 5 a 9 años', '*'],
#  ['Población femenina de 5 a 9 años', '*'],
#  ['Población masculina de 5 a 9 años', '*'],
#  ['Población de 10 a 14 años', '*'],
#  ['Población femenina de 10 a 14 años', '*'],
#  ['Población masculina de 10 a 14 años', '*'],
#  ['Población de 15 a 19 años', '*'],
#  ['Población femenina de 15 a 19 años', '*'],
#  ['Población masculina de 15 a 19 años', '*'],
#  ['Población de 20 a 24 años', '*'],
#  ['Población femenina de 20 a 24 años', '*'],
#  ['Población masculina de 20 a 24 años', '*'],
#  ['Población de 25 a 29 años', '*'],
#  ['Población femenina de 25 a 29 años', '*'],
#  ['Población masculina de 25 a 29 años', '*'],
#  ['Población de 30 a 34 años', '*'],
#  ['Población femenina de 30 a 34 años', '*'],
#  ['Población masculina de 30 a 34 años', '*'],
#  ['Población de 35 a 39 años', '*'],
#  ['Población femenina de 35 a 39 años', '*'],
#  ['Población masculina de 35 a 39 años', '*'],
#  ['Población de 40 a 44 años', '*'],
#  ['Población femenina de 40 a 44 años', '*'],
#  ['Población masculina de 40 a 44 años', '*'],
#  ['Población de 45 a 49 años', '*'],
#  ['Población femenina de 45 a 49 años', '*'],
#  ['Población masculina de 45 a 49 años', '*'],
#  ['Población de 50 a 54 años', '*'],
#  ['Población femenina de 50 a 54 años', '*'],
#  ['Población masculina de 50 a 54 años', '*'],
#  ['Población de 55 a 59 años', '*'],
#  ['Población femenina de 55 a 59 años', '*'],
#  ['Población masculina de 55 a 59 años', '*'],
#  ['Población de 60 a 64 años', '*'],
#  ['Población femenina de 60 a 64 años', '*'],
#  ['Población masculina de 60 a 64 años', '*'],
#  ['Población de 65 a 69 años', '*'],
#  ['Población femenina de 65 a 69 años', '*'],
#  ['Población masculina de 65 a 69 años', '*'],
#  ['Población de 70 a 74 años', '*'],
#  ['Población femenina de 70 a 74 años', '*'],
#  ['Población masculina de 70 a 74 años', '*'],
#  ['Población de 75 a 79 años', '*'],
#  ['Población con discapacidad', '*'],
#  ['Población con discapacidad para hablar o comunicarse', '*'],
#  ['Población con discapacidad para oír, aun usando aparato auditivo', '*'],
#  ['Población con discapacidad para vestirse, bañarse o comer', '*'],
#  ['Población con discapacidad para recordar o concentrarse', '*'],
#  ['Población con limitación', '*'],
#  ['Población con limitación para caminar, subir o bajar', '*'],
#  ['Población con limitación para ver, aun usando lentes', '*'],
#  ['Población con limitación para hablar o comunicarse', '*'],
#  ['Población con limitación para oír, aun usando aparato auditivo', '*'],
#  ['Población con limitación para vestirse, bañarse o comer', '*'],
#  ['Población con limitación para recordar o concentrarse', '*'],
#  ['Población con algún problema o condición mental', '*'],
#  ['Población sin discapacidad, limitación, problema o condición mental', '*'],
#  ['Población de 3 a 5 años que no asiste a la escuela', '*'],
#  ['Población femenina de 3 a 5 años que no asiste a la escuela', '*'],
#  ['Población masculina de 3 a 5 años que no asiste a la escuela', '*'],
#  ['Población de 6 a 11 años que no asiste a la escuela', '*'],
#  ['Población femenina de 6 a 11 años que no asiste a la escuela', '*'],
#  ['Población masculina de 6 a 11 años que no asiste a la escuela', '*'],
#  ['Población de 12 a 14 años que no asiste a la escuela', '*'],
#  ['Población femenina de 12 a 14 años que no asiste a la escuela', '*'],
#  ['Población masculina de 12 a 14 años que no asiste a la escuela', '*'],
#  ['Población de 15 a 17 años que asiste a la escuela', '*'],
#  ['Población femenina de 15 a 17 años que asiste a la escuela', '*'],
#  ['Población masculina de 15 a 17 años que asiste a la escuela', '*'],
#  ['Población de 18 a 24 años que asiste a la escuela', '*'],
#  ['Población femenina de 18 a 24 años que asiste a la escuela', '*'],
#  ['Población masculina de 18 a 24 años que asiste a la escuela', '*'],
#  ['Población de 8 a 14 años que no sabe leer y escribir', '*'],
#  ['Población femenina de 8 a 14 años que no sabe leer y escribir', '*'],
#  ['Población masculina de 8 a 14 años que no sabe leer y escribir', '*'],
#  ['Población de 15 años y más analfabeta', '*'],
#  ['Población femenina de 15 años y más analfabeta', '*'],
#  ['Población masculina de 15 años y más analfabeta', '*'],
#  ['Población de 15 años y más sin escolaridad', '*'],
#  ['Población femenina de 15 años y más sin escolaridad', '*'],
#  ['Población masculina de 15 años y más sin escolaridad', '*'],
#  ['Población de 15 años y más con primaria incompleta', '*'],
#  ['Población femenina de 15 años y más con primaria incompleta', '*'],
#  ['Población masculina de 15 años y más con primaria incompleta', '*'],
#  ['Población de 15 años y más con primaria completa', '*'],
#  ['Población femenina de 15 años y más con primaria completa', '*'],
#  ['Población masculina de 15 años y más con primaria completa', '*'],
#  ['Población de 15 años y más con secundaria incompleta', '*'],
#  ['Población femenina de 15 años y más con secundaria incompleta', '*'],
#  ['Población masculina de 15 años y más con secundaria incompleta', '*'],
#  ['Población de 15 años y más con secundaria completa', '*'],
#  ['Población femenina de 15 años y más con secundaria completa', '*'],
#  ['Población masculina de 15 años y más con secundaria completa', '*'],
#  ['Población de 18 años y más con educación posbásica', '*'],
#  ['Población femenina de 18 años y más con educación posbásica', '*'],
#  ['Población masculina de 18 años y más con educación posbásica', '*'],
#  ['Población de 12 años y más económicamente activa', '*'],
#  ['Población femenina de 12 años y más económicamente activa', '*'],
#  ['Población masculina de 12 años y más económicamente activa', '*'],
#  ['Población de 12 años y más no económicamente activa', '*'],
#  ['Población femenina de 12 años y más no económicamente activa', '*'],
#  ['Población masculina de 12 años y más no económicamente activa', '*'],
#  ['Población de 12 años y más ocupada', '*'],
#  ['Población femenina de 12 años y más ocupada', '*'],
#  ['Población masculina de 12 años y más ocupada', '*'],
#  ['Población de 12 años y más desocupada', '*'],
#  ['Población femenina de 12 años y más desocupada', '*'],
#  ['Población masculina de 12 años y más desocupada', '*']]

# %%
df=df[~(df['Grado promedio de escolaridad']=='*')]

# %%
formato_columnas(df,format_columns)
# Out:
# 0.0% de los registros en Longitud son 102°17\
# 0.0% de los registros en Latitud son 21°52\
# 0.0% de los registros en Altitud son 00-1
# 0.0% de los registros en Relación hombres-mujeres son N/D
# 0.0% de los registros en Grado promedio de escolaridad son N/D
# 0.0% de los registros en Grado promedio de escolaridad de la población femenina son N/D
# 0.0% de los registros en Grado promedio de escolaridad de la población masculina son N/D
# 0.0% de los registros en Población de 0 a 2 años son N/D
# 0.0% de los registros en Población femenina de 0 a 2 años son N/D
# 0.0% de los registros en Población masculina de 0 a 2 años son N/D
# 0.0% de los registros en Población de 3 años y más son N/D
# 0.0% de los registros en Población femenina de 3 años y más son N/D
# 0.0% de los registros en Población masculina de 3 años y más son N/D
# 0.0% de los registros en Población de 5 años y más son N/D
# 0.0% de los registros en Población femenina de 5 años y más son N/D
# 0.0% de los registros en Población masculina de 5 años y más son N/D
# 0.0% de los registros en Población de 12 años y más son N/D
# 0.0% de los registros en Población femenina de 12 años y más son N/D
# 0.0% de los registros en Población masculina de 12 años y más son N/D
# 0.0% de los registros en Población de 15 años y más son N/D
# 0.0% de los registros en Población femenina de 15 años y más son N/D
# 0.0% de los registros en Población masculina de 15 años y más son N/D
# 0.0% de los registros en Población de 18 años y más son N/D
# 0.0% de los registros en Población femenina de 18 años y más son N/D
# 0.0% de los registros en Población masculina de 18 años y más son N/D
# 0.0% de los registros en Población de 3 a 5 años son N/D
# 0.0% de los registros en Población femenina de 3 a 5 años son N/D
# 0.0% de los registros en Población masculina de 3 a 5 años son N/D
# 0.0% de los registros en Población de 6 a 11 años son N/D
# 0.0% de los registros en Población femenina de 6 a 11 años son N/D
# 0.0% de los registros en Población masculina de 6 a 11 años son N/D
# 0.0% de los registros en Población de 8 a 14 años son N/D
# 0.0% de los registros en Población femenina de 8 a 14 años son N/D
# 0.0% de los registros en Población masculina de 8 a 14 años son N/D
# 0.0% de los registros en Población de 12 a 14 años son N/D
# 0.0% de los registros en Población femenina de 12 a 14 años son N/D
# 0.0% de los registros en Población masculina de 12 a 14 años son N/D
# 0.0% de los registros en Población de 15 a 17 años son N/D
# 0.0% de los registros en Población femenina de 15 a 17 años son N/D
# 0.0% de los registros en Población masculina de 15 a 17 años son N/D
# 0.0% de los registros en Población de 18 a 24 años son N/D
# 0.0% de los registros en Población femenina de 18 a 24 años son N/D
# 0.0% de los registros en Población masculina de 18 a 24 años son N/D
# 0.0% de los registros en Población femenina de 15 a 49 años son N/D
# 0.0% de los registros en Población de 60 años y más son N/D
# 0.0% de los registros en Población femenina de 60 años y más son N/D
# 0.0% de los registros en Población masculina de 60 años y más son N/D
# 0.0% de los registros en Población de 0 a 14 años son N/D
# 0.0% de los registros en Población de 15 a 64 años son N/D
# 0.0% de los registros en Población de 65 años y más son N/D
# 0.0% de los registros en Población de 0 a 4 años son N/D
# 0.0% de los registros en Población femenina de 0 a 4 años son N/D
# 0.0% de los registros en Población masculina de 0 a 4 años son N/D
# 0.0% de los registros en Población de 5 a 9 años son N/D
# 0.0% de los registros en Población femenina de 5 a 9 años son N/D
# 0.0% de los registros en Población masculina de 5 a 9 años son N/D
# 0.0% de los registros en Población de 10 a 14 años son N/D
# 0.0% de los registros en Población femenina de 10 a 14 años son N/D
# 0.0% de los registros en Población masculina de 10 a 14 años son N/D
# 0.0% de los registros en Población de 15 a 19 años son N/D
# 0.0% de los registros en Población femenina de 15 a 19 años son N/D
# 0.0% de los registros en Población masculina de 15 a 19 años son N/D
# 0.0% de los registros en Población de 20 a 24 años son N/D
# 0.0% de los registros en Población femenina de 20 a 24 años son N/D
# 0.0% de los registros en Población masculina de 20 a 24 años son N/D
# 0.0% de los registros en Población de 25 a 29 años son N/D
# 0.0% de los registros en Población femenina de 25 a 29 años son N/D
# 0.0% de los registros en Población masculina de 25 a 29 años son N/D
# 0.0% de los registros en Población de 30 a 34 años son N/D
# 0.0% de los registros en Población femenina de 30 a 34 años son N/D
# 0.0% de los registros en Población masculina de 30 a 34 años son N/D
# 0.0% de los registros en Población de 35 a 39 años son N/D
# 0.0% de los registros en Población femenina de 35 a 39 años son N/D
# 0.0% de los registros en Población masculina de 35 a 39 años son N/D
# 0.0% de los registros en Población de 40 a 44 años son N/D
# 0.0% de los registros en Población femenina de 40 a 44 años son N/D
# 0.0% de los registros en Población masculina de 40 a 44 años son N/D
# 0.0% de los registros en Población de 45 a 49 años son N/D
# 0.0% de los registros en Población femenina de 45 a 49 años son N/D
# 0.0% de los registros en Población masculina de 45 a 49 años son N/D
# 0.0% de los registros en Población de 50 a 54 años son N/D
# 0.0% de los registros en Población femenina de 50 a 54 años son N/D
# 0.0% de los registros en Población masculina de 50 a 54 años son N/D
# 0.0% de los registros en Población de 55 a 59 años son N/D
# 0.0% de los registros en Población femenina de 55 a 59 años son N/D
# 0.0% de los registros en Población masculina de 55 a 59 años son N/D
# 0.0% de los registros en Población de 60 a 64 años son N/D
# 0.0% de los registros en Población femenina de 60 a 64 años son N/D
# 0.0% de los registros en Población masculina de 60 a 64 años son N/D
# 0.0% de los registros en Población de 65 a 69 años son N/D
# 0.0% de los registros en Población femenina de 65 a 69 años son N/D
# 0.0% de los registros en Población masculina de 65 a 69 años son N/D
# 0.0% de los registros en Población de 70 a 74 años son N/D
# 0.0% de los registros en Población femenina de 70 a 74 años son N/D
# 0.0% de los registros en Población masculina de 70 a 74 años son N/D
# 0.0% de los registros en Población de 75 a 79 años son N/D
# 0.0% de los registros en Población con discapacidad son N/D
# 0.0% de los registros en Población con discapacidad para hablar o comunicarse son N/D
# 0.0% de los registros en Población con discapacidad para oír, aun usando aparato auditivo son N/D
# 0.0% de los registros en Población con discapacidad para vestirse, bañarse o comer son N/D
# 0.0% de los registros en Población con discapacidad para recordar o concentrarse son N/D
# 0.0% de los registros en Población con limitación son N/D
# 0.0% de los registros en Población con limitación para caminar, subir o bajar son N/D
# 0.0% de los registros en Población con limitación para ver, aun usando lentes son N/D
# 0.0% de los registros en Población con limitación para hablar o comunicarse son N/D
# 0.0% de los registros en Población con limitación para oír, aun usando aparato auditivo son N/D
# 0.0% de los registros en Población con limitación para vestirse, bañarse o comer son N/D
# 0.0% de los registros en Población con limitación para recordar o concentrarse son N/D
# 0.0% de los registros en Población con algún problema o condición mental son N/D
# 0.0% de los registros en Población sin discapacidad, limitación, problema o condición mental son N/D
# 0.0% de los registros en Población de 3 a 5 años que no asiste a la escuela son N/D
# 0.0% de los registros en Población femenina de 3 a 5 años que no asiste a la escuela son N/D
# 0.0% de los registros en Población masculina de 3 a 5 años que no asiste a la escuela son N/D
# 0.0% de los registros en Población de 6 a 11 años que no asiste a la escuela son N/D
# 0.0% de los registros en Población femenina de 6 a 11 años que no asiste a la escuela son N/D
# 0.0% de los registros en Población masculina de 6 a 11 años que no asiste a la escuela son N/D
# 0.0% de los registros en Población de 12 a 14 años que no asiste a la escuela son N/D
# 0.0% de los registros en Población femenina de 12 a 14 años que no asiste a la escuela son N/D
# 0.0% de los registros en Población masculina de 12 a 14 años que no asiste a la escuela son N/D
# 0.0% de los registros en Población de 15 a 17 años que asiste a la escuela son N/D
# 0.0% de los registros en Población femenina de 15 a 17 años que asiste a la escuela son N/D
# 0.0% de los registros en Población masculina de 15 a 17 años que asiste a la escuela son N/D
# 0.0% de los registros en Población de 18 a 24 años que asiste a la escuela son N/D
# 0.0% de los registros en Población femenina de 18 a 24 años que asiste a la escuela son N/D
# 0.0% de los registros en Población masculina de 18 a 24 años que asiste a la escuela son N/D
# 0.0% de los registros en Población de 8 a 14 años que no sabe leer y escribir son N/D
# 0.0% de los registros en Población femenina de 8 a 14 años que no sabe leer y escribir son N/D
# 0.0% de los registros en Población masculina de 8 a 14 años que no sabe leer y escribir son N/D
# 0.0% de los registros en Población de 15 años y más analfabeta son N/D
# 0.0% de los registros en Población femenina de 15 años y más analfabeta son N/D
# 0.0% de los registros en Población masculina de 15 años y más analfabeta son N/D
# 0.0% de los registros en Población de 15 años y más sin escolaridad son N/D
# 0.0% de los registros en Población femenina de 15 años y más sin escolaridad son N/D
# 0.0% de los registros en Población masculina de 15 años y más sin escolaridad son N/D
# 0.0% de los registros en Población de 15 años y más con primaria incompleta son N/D
# 0.0% de los registros en Población femenina de 15 años y más con primaria incompleta son N/D
# 0.0% de los registros en Población masculina de 15 años y más con primaria incompleta son N/D
# 0.0% de los registros en Población de 15 años y más con primaria completa son N/D
# 0.0% de los registros en Población femenina de 15 años y más con primaria completa son N/D
# 0.0% de los registros en Población masculina de 15 años y más con primaria completa son N/D
# 0.0% de los registros en Población de 15 años y más con secundaria incompleta son N/D
# 0.0% de los registros en Población femenina de 15 años y más con secundaria incompleta son N/D
# 0.0% de los registros en Población masculina de 15 años y más con secundaria incompleta son N/D
# 0.0% de los registros en Población de 15 años y más con secundaria completa son N/D
# 0.0% de los registros en Población femenina de 15 años y más con secundaria completa son N/D
# 0.0% de los registros en Población masculina de 15 años y más con secundaria completa son N/D
# 0.0% de los registros en Población de 18 años y más con educación posbásica son N/D
# 0.0% de los registros en Población femenina de 18 años y más con educación posbásica son N/D
# 0.0% de los registros en Población masculina de 18 años y más con educación posbásica son N/D
# 0.0% de los registros en Población de 12 años y más económicamente activa son N/D
# 0.0% de los registros en Población femenina de 12 años y más económicamente activa son N/D
# 0.0% de los registros en Población masculina de 12 años y más económicamente activa son N/D
# 0.0% de los registros en Población de 12 años y más no económicamente activa son N/D
# 0.0% de los registros en Población femenina de 12 años y más no económicamente activa son N/D
# 0.0% de los registros en Población masculina de 12 años y más no económicamente activa son N/D
# 0.0% de los registros en Población de 12 años y más ocupada son N/D
# 0.0% de los registros en Población femenina de 12 años y más ocupada son N/D
# 0.0% de los registros en Población masculina de 12 años y más ocupada son N/D
# 0.0% de los registros en Población de 12 años y más desocupada son N/D
# 0.0% de los registros en Población femenina de 12 años y más desocupada son N/D
# 0.0% de los registros en Población masculina de 12 años y más desocupada son N/D
# [['Longitud', '102°17\\'],
#  ['Latitud', '21°52\\'],
#  ['Altitud', '00-1'],
#  ['Relación hombres-mujeres', 'N/D'],
#  ['Grado promedio de escolaridad', 'N/D'],
#  ['Grado promedio de escolaridad de la población femenina', 'N/D'],
#  ['Grado promedio de escolaridad de la población masculina', 'N/D'],
#  ['Población de 0 a 2 años', 'N/D'],
#  ['Población femenina de 0 a 2 años', 'N/D'],
#  ['Población masculina de 0 a 2 años', 'N/D'],
#  ['Población de 3 años y más', 'N/D'],
#  ['Población femenina de 3 años y más', 'N/D'],
#  ['Población masculina de 3 años y más', 'N/D'],
#  ['Población de 5 años y más', 'N/D'],
#  ['Población femenina de 5 años y más', 'N/D'],
#  ['Población masculina de 5 años y más', 'N/D'],
#  ['Población de 12 años y más', 'N/D'],
#  ['Población femenina de 12 años y más', 'N/D'],
#  ['Población masculina de 12 años y más', 'N/D'],
#  ['Población de 15 años y más', 'N/D'],
#  ['Población femenina de 15 años y más', 'N/D'],
#  ['Población masculina de 15 años y más', 'N/D'],
#  ['Población de 18 años y más', 'N/D'],
#  ['Población femenina de 18 años y más', 'N/D'],
#  ['Población masculina de 18 años y más', 'N/D'],
#  ['Población de 3 a 5 años', 'N/D'],
#  ['Población femenina de 3 a 5 años', 'N/D'],
#  ['Población masculina de 3 a 5 años', 'N/D'],
#  ['Población de 6 a 11 años', 'N/D'],
#  ['Población femenina de 6 a 11 años', 'N/D'],
#  ['Población masculina de 6 a 11 años', 'N/D'],
#  ['Población de 8 a 14 años', 'N/D'],
#  ['Población femenina de 8 a 14 años', 'N/D'],
#  ['Población masculina de 8 a 14 años', 'N/D'],
#  ['Población de 12 a 14 años', 'N/D'],
#  ['Población femenina de 12 a 14 años', 'N/D'],
#  ['Población masculina de 12 a 14 años', 'N/D'],
#  ['Población de 15 a 17 años', 'N/D'],
#  ['Población femenina de 15 a 17 años', 'N/D'],
#  ['Población masculina de 15 a 17 años', 'N/D'],
#  ['Población de 18 a 24 años', 'N/D'],
#  ['Población femenina de 18 a 24 años', 'N/D'],
#  ['Población masculina de 18 a 24 años', 'N/D'],
#  ['Población femenina de 15 a 49 años', 'N/D'],
#  ['Población de 60 años y más', 'N/D'],
#  ['Población femenina de 60 años y más', 'N/D'],
#  ['Población masculina de 60 años y más', 'N/D'],
#  ['Población de 0 a 14 años', 'N/D'],
#  ['Población de 15 a 64 años', 'N/D'],
#  ['Población de 65 años y más', 'N/D'],
#  ['Población de 0 a 4 años', 'N/D'],
#  ['Población femenina de 0 a 4 años', 'N/D'],
#  ['Población masculina de 0 a 4 años', 'N/D'],
#  ['Población de 5 a 9 años', 'N/D'],
#  ['Población femenina de 5 a 9 años', 'N/D'],
#  ['Población masculina de 5 a 9 años', 'N/D'],
#  ['Población de 10 a 14 años', 'N/D'],
#  ['Población femenina de 10 a 14 años', 'N/D'],
#  ['Población masculina de 10 a 14 años', 'N/D'],
#  ['Población de 15 a 19 años', 'N/D'],
#  ['Población femenina de 15 a 19 años', 'N/D'],
#  ['Población masculina de 15 a 19 años', 'N/D'],
#  ['Población de 20 a 24 años', 'N/D'],
#  ['Población femenina de 20 a 24 años', 'N/D'],
#  ['Población masculina de 20 a 24 años', 'N/D'],
#  ['Población de 25 a 29 años', 'N/D'],
#  ['Población femenina de 25 a 29 años', 'N/D'],
#  ['Población masculina de 25 a 29 años', 'N/D'],
#  ['Población de 30 a 34 años', 'N/D'],
#  ['Población femenina de 30 a 34 años', 'N/D'],
#  ['Población masculina de 30 a 34 años', 'N/D'],
#  ['Población de 35 a 39 años', 'N/D'],
#  ['Población femenina de 35 a 39 años', 'N/D'],
#  ['Población masculina de 35 a 39 años', 'N/D'],
#  ['Población de 40 a 44 años', 'N/D'],
#  ['Población femenina de 40 a 44 años', 'N/D'],
#  ['Población masculina de 40 a 44 años', 'N/D'],
#  ['Población de 45 a 49 años', 'N/D'],
#  ['Población femenina de 45 a 49 años', 'N/D'],
#  ['Población masculina de 45 a 49 años', 'N/D'],
#  ['Población de 50 a 54 años', 'N/D'],
#  ['Población femenina de 50 a 54 años', 'N/D'],
#  ['Población masculina de 50 a 54 años', 'N/D'],
#  ['Población de 55 a 59 años', 'N/D'],
#  ['Población femenina de 55 a 59 años', 'N/D'],
#  ['Población masculina de 55 a 59 años', 'N/D'],
#  ['Población de 60 a 64 años', 'N/D'],
#  ['Población femenina de 60 a 64 años', 'N/D'],
#  ['Población masculina de 60 a 64 años', 'N/D'],
#  ['Población de 65 a 69 años', 'N/D'],
#  ['Población femenina de 65 a 69 años', 'N/D'],
#  ['Población masculina de 65 a 69 años', 'N/D'],
#  ['Población de 70 a 74 años', 'N/D'],
#  ['Población femenina de 70 a 74 años', 'N/D'],
#  ['Población masculina de 70 a 74 años', 'N/D'],
#  ['Población de 75 a 79 años', 'N/D'],
#  ['Población con discapacidad', 'N/D'],
#  ['Población con discapacidad para hablar o comunicarse', 'N/D'],
#  ['Población con discapacidad para oír, aun usando aparato auditivo', 'N/D'],
#  ['Población con discapacidad para vestirse, bañarse o comer', 'N/D'],
#  ['Población con discapacidad para recordar o concentrarse', 'N/D'],
#  ['Población con limitación', 'N/D'],
#  ['Población con limitación para caminar, subir o bajar', 'N/D'],
#  ['Población con limitación para ver, aun usando lentes', 'N/D'],
#  ['Población con limitación para hablar o comunicarse', 'N/D'],
#  ['Población con limitación para oír, aun usando aparato auditivo', 'N/D'],
#  ['Población con limitación para vestirse, bañarse o comer', 'N/D'],
#  ['Población con limitación para recordar o concentrarse', 'N/D'],
#  ['Población con algún problema o condición mental', 'N/D'],
#  ['Población sin discapacidad, limitación, problema o condición mental',
#   'N/D'],
#  ['Población de 3 a 5 años que no asiste a la escuela', 'N/D'],
#  ['Población femenina de 3 a 5 años que no asiste a la escuela', 'N/D'],
#  ['Población masculina de 3 a 5 años que no asiste a la escuela', 'N/D'],
#  ['Población de 6 a 11 años que no asiste a la escuela', 'N/D'],
#  ['Población femenina de 6 a 11 años que no asiste a la escuela', 'N/D'],
#  ['Población masculina de 6 a 11 años que no asiste a la escuela', 'N/D'],
#  ['Población de 12 a 14 años que no asiste a la escuela', 'N/D'],
#  ['Población femenina de 12 a 14 años que no asiste a la escuela', 'N/D'],
#  ['Población masculina de 12 a 14 años que no asiste a la escuela', 'N/D'],
#  ['Población de 15 a 17 años que asiste a la escuela', 'N/D'],
#  ['Población femenina de 15 a 17 años que asiste a la escuela', 'N/D'],
#  ['Población masculina de 15 a 17 años que asiste a la escuela', 'N/D'],
#  ['Población de 18 a 24 años que asiste a la escuela', 'N/D'],
#  ['Población femenina de 18 a 24 años que asiste a la escuela', 'N/D'],
#  ['Población masculina de 18 a 24 años que asiste a la escuela', 'N/D'],
#  ['Población de 8 a 14 años que no sabe leer y escribir', 'N/D'],
#  ['Población femenina de 8 a 14 años que no sabe leer y escribir', 'N/D'],
#  ['Población masculina de 8 a 14 años que no sabe leer y escribir', 'N/D'],
#  ['Población de 15 años y más analfabeta', 'N/D'],
#  ['Población femenina de 15 años y más analfabeta', 'N/D'],
#  ['Población masculina de 15 años y más analfabeta', 'N/D'],
#  ['Población de 15 años y más sin escolaridad', 'N/D'],
#  ['Población femenina de 15 años y más sin escolaridad', 'N/D'],
#  ['Población masculina de 15 años y más sin escolaridad', 'N/D'],
#  ['Población de 15 años y más con primaria incompleta', 'N/D'],
#  ['Población femenina de 15 años y más con primaria incompleta', 'N/D'],
#  ['Población masculina de 15 años y más con primaria incompleta', 'N/D'],
#  ['Población de 15 años y más con primaria completa', 'N/D'],
#  ['Población femenina de 15 años y más con primaria completa', 'N/D'],
#  ['Población masculina de 15 años y más con primaria completa', 'N/D'],
#  ['Población de 15 años y más con secundaria incompleta', 'N/D'],
#  ['Población femenina de 15 años y más con secundaria incompleta', 'N/D'],
#  ['Población masculina de 15 años y más con secundaria incompleta', 'N/D'],
#  ['Población de 15 años y más con secundaria completa', 'N/D'],
#  ['Población femenina de 15 años y más con secundaria completa', 'N/D'],
#  ['Población masculina de 15 años y más con secundaria completa', 'N/D'],
#  ['Población de 18 años y más con educación posbásica', 'N/D'],
#  ['Población femenina de 18 años y más con educación posbásica', 'N/D'],
#  ['Población masculina de 18 años y más con educación posbásica', 'N/D'],
#  ['Población de 12 años y más económicamente activa', 'N/D'],
#  ['Población femenina de 12 años y más económicamente activa', 'N/D'],
#  ['Población masculina de 12 años y más económicamente activa', 'N/D'],
#  ['Población de 12 años y más no económicamente activa', 'N/D'],
#  ['Población femenina de 12 años y más no económicamente activa', 'N/D'],
#  ['Población masculina de 12 años y más no económicamente activa', 'N/D'],
#  ['Población de 12 años y más ocupada', 'N/D'],
#  ['Población femenina de 12 años y más ocupada', 'N/D'],
#  ['Población masculina de 12 años y más ocupada', 'N/D'],
#  ['Población de 12 años y más desocupada', 'N/D'],
#  ['Población femenina de 12 años y más desocupada', 'N/D'],
#  ['Población masculina de 12 años y más desocupada', 'N/D']]
